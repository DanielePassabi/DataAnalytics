# %% [markdown]
# # Creo un nuovo dataset

# %% [markdown]
# ---
# ## Analisi dei commenti di un ristorante
#
# ### Pierluigi - Lazio
#
# URL di riferimento: https://www.tripadvisor.it/Restaurant_Review-g187791-d716359-Reviews-Pierluigi-Rome_Lazio.html
#
# Home --> Ristoranti --> Firenze --> Best_ranking--> SENZ_ALTRO_Bistrot

# %%
# IMPORT NECESSARI
import requests
from bs4 import BeautifulSoup

print("Imported")
# Out:
# Imported

# %%
page_URL = "https://www.tripadvisor.it/Restaurant_Review-g187791-d716359-Reviews-Pierluigi-Rome_Lazio.html"

data = requests.get(page_URL)
clear_data = BeautifulSoup(data.content, "lxml")

print("Done")
# Out:
# Done

# %% [markdown]
# ---
# ### STRUTTURA HTML DEL SITO
#
# #### REVIEW
# `<p class="partial_entry"> qui c'è la review </p>`
#
# #### N° TOTALE DI REVIEWS
# `<a data-page-number="25" ...>
#     25
#  </a>`
#
# #### NAMES
# `<span class="expand_inline scrname" …>AlexandraCapeTown</span>`
#
# #### RATINGS
# `<span class="ui_bubble_rating bubble_30"></span>`

# %% [markdown]
# ---
# ### PRIMO SCRAPING (sulla prima pagina)
#
# Ottengo i nomi, i commenti, le review e da dove è stato scritto il commento per quanto rigurda la prima pagina. Ciò è necessario, in quanto, dalla seconda in poi l'URL cambia, permettendoci di iterare.

# %%
# OTTENGO UNA LISTA DI DIV CHE CONTENGONO NOME, RECENSIONE E VOTO

all_reviews = []
all_names = []
all_ratings = []
all_mobile = []

review_container = clear_data.findAll("div", attrs={"class":"review-container"})

for container in review_container:
  
    ### REVIEW ###
    review = container.find('p', attrs={'class': 'partial_entry'})
    if review:
        all_reviews.append(review.text)
        
    ### NAME ###
    name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
    if name:
      all_names.append(name.text)
    else:
      all_names.append('NO_NAME')
    
    ### RATING ###
    rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
    all_ratings.append(rating['class'][1][7:8])
    
    ### MOBILE ###
    mobile = container.find('span', attrs={'class': 'viaMobile'})
    if mobile:
      all_mobile.append('Mobile')
    else:
      all_mobile.append('PC')
    
    
################################################################################################################################
        
print("Executed")
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# Nomi:  10
# Commenti:  10
# Voti:  10
# Scritto da:  10

# %% [markdown]
# ### SECONDO SCRAPING (dalla seconda pagina in poi)
#
# Notiamo dall'URL che è possibile iterare sulle pagine, ottenendo i dati!

# %%
from tqdm import tqdm

URL_COMPLETO = 'https://www.tripadvisor.it/Restaurant_Review-g187791-d716359-Reviews-or10-Pierluigi-Rome_Lazio.html'

URL_p1 = 'https://www.tripadvisor.it/Restaurant_Review-g187791-d716359-Reviews-or'
URL_p2 = '0-Pierluigi-Rome_Lazio.html'
    
# OTTENGO I COMMENTI, NOMI E VOTI DALLA SECONDA PAGINA IN POI

total_pages = int(clear_data.select("a.pageNum.last.taLnk")[0].text) # 25 come intero

# per iterare dobbiamo partire dalla seconda pagina dei commenti, così nell'URL compaiono le cifre che ci servono
for r in tqdm(range(1,total_pages)):

    # OTTENGO L'URL DELLA PAGINA
    URL_temp = URL_p1 + str(r) + URL_p2

    # OTTENGO I DATI E CI APPLICO BEATIFULSOUP
    data = requests.get(URL_temp)
    clear_data = BeautifulSoup(data.content, "lxml")
    

    review_container = clear_data.findAll("div", attrs={"class":"review-container"})

    for container in review_container:
  
      ### REVIEW ###
      review = container.find('p', attrs={'class': 'partial_entry'})
      if review:
          all_reviews.append(review.text)

      ### NAME ###
      name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
      if name:
        all_names.append(name.text)
      else:
        all_names.append('NO_NAME')

      ### RATING ###
      rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
      all_ratings.append(rating['class'][1][7:8])

      ### MOBILE ###
      mobile = container.find('span', attrs={'class': 'viaMobile'})
      if mobile:
        all_mobile.append('Mobile')
      else:
        all_mobile.append('PC')
    
        
################################################################################################################################
        
print("Executed")
print('total_pages: ', total_pages)
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_mobile))
# Out:
# 100%|██████████| 119/119 [02:43<00:00,  1.40s/it]
# Executed
# total_pages:  120
# Nomi:  1195
# Commenti:  1195
# Voti:  1195
# Scritto da:  1195

# %%
# display(all_reviews)

# %%
# print(all_names)

# %%
#print(all_ratings, '\n')
#print(len(all_ratings))

# %%
#display(all_mobile)

# %% [markdown]
# #### Problema recensioni troppo lunghe
# Alla fine di alcune recensioni troviamo un '...Più', che non possiamo espandere. Data la mole di dati, decidiamo dunque di non considerarle.

# %%
all_reviews_filtered = []
counter_reviews_scartate = 0;
counter_reviews_da_usare = 0;

for review in all_reviews:
    if '...Più' in review:
        all_reviews_filtered.append('RECENSIONE_TROPPO_LUNGA')
        counter_reviews_scartate+=1;
    else:
        all_reviews_filtered.append(review)
        counter_reviews_da_usare+=1;
        
        
print(
    'Totale recensioni:', counter_reviews_scartate + counter_reviews_da_usare, '\n',
    'Recensioni analizzabili:', counter_reviews_da_usare, '\n',
    'Recensioni scartate:', counter_reviews_scartate, '\n')

display(all_reviews_filtered[:10])
# Out:
# Totale recensioni: 1195
#  Recensioni analizzabili: 814
#  Recensioni scartate: 381
# ['RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Qualità del pesce eccellente, piatti perfetti, personale gentile e disponibile, frequentato bene, prezzi importanti ma in linea con la qualità (essendo a Roma) merita sicuramente una visita.']

# %% [markdown]
# ---
# ### Analisi dei nomi
# Cerchiamo di capire se chi ha commentato è un uomo (M) o una donna (F).

# %% [markdown]
# #### Elimino spazi e numeri
# Ho bisogno di tenere solo le informazioni riguardanti il nome, elimino il resto.

# %%
import re

all_names_filtered = []

regex = re.compile('[^a-zA-Z]')

for name in all_names:
    
    if ' ' in name:                           # se c'è uno spazio nel nome
        space = name.index(' ')               # ne trovo l'indice
        name = regex.sub('', name[:space])    # effettuo un controllo su tutto ciò che non è alfabeto fino a quell'indice
        all_names_filtered.append(name)       # e aggiungo la stringa
        
    else:
        name = regex.sub('', name)            # in caso contrario effettuo un controllo su tutto ciò che non è alfabeto
        all_names_filtered.append(name)       # e aggiungo la stringa
        
print(all_names, '\n')
print(all_names_filtered)
# Out:
# ['NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'GuglielmoG85', 'KnightChevalier', 'Emanuele M', 'Consuelo N', 'MLuisaRav', 'nick_cassiusclay', 'maestroprimoconventi', 'ducagio', 'diegobon2013', 'michelebU4879RP', 'laviniap2014', 'Gian Luca Attol... A', 'Giovanna V', 'Bratislao', 'ottacarlotta', 'Alessandro P', 'MatteaV', 'Amarillide1', 'mgabriellam2017', 'Abrahamkatt', 'Cinziaver', 'giorgione1971', 'Ivanaxxx', 'roberto m', 'jamiarri', 'L0rdn40', 'laura m', 'brightly60', 'serdavi1', 'piedone51', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Giuseppe P', 'Andrea G', 'dadahtml-687', 'Bestgustibus', 'maxigigliucci', 'francescomarzo68', 'EMMAT01', '854enricoz', '388Catherine388', 'Brunogrjjfjdnfjfj', 'Apicio82', 'maracaterina', 'Carlox92', 'gioRome', 'W5356PQclaudiab', 'massimo506', 'Ale_Sa_75', 'Filippo R', 'Asia16488', 'Andrea R', 'mafriroma', '254vierad', 'Bollechou', 'N8650FCgiuseppec', 'scorpiov70', 'Ciccioerpiccoletto', 'Francisco D', 'La Staffa S', 'Alina D', 'Franchini1956', 'Fantasma237', 'Simone F', 'J7442ILmariom', 'Maurizio368', 'jules_giugiu', 'E245MTalicec', '465darias', 'Giramonda79', '5768raffaelep', 'Bari1969', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Picchiolo', 'CharlotteNY', 'Silvia S', 'fly69ch', 'Angela T', 'frapa9', '42travelasmuchIcan', 'zgianlu', 'kiphenry', 'LaFra79', 'Majirelle', 'argania', 'Fabrizio L', '164robertap', 'Luca P', 'CARLO G', 'nexus55', 'GINTONIC1015', 'gian1063', 'ema2002', 'federicob831', 'Skyattaman', 'Prinex', 'Michelina_12', 'IreneMARKETERs', 'Anna R', '57stefaniae', 'Federico B', 'Mario M', 'silaroma', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'FoodLa16', 'mirko2011', 'pietro r', 'silviabon', 'Pecluca', 'Lola D', 'annamariadeluca', '664brunellam', 'StefanoD461', 'VitoFernandoD', 'Domenico D', 'Ornella C', '547AndreaV547', 'wfiorde', 'andreafabia12', 'Vito P', 'rinoNapoli', 'Olga S', 'headluk', 'Maria Chiara L', 'Edoardo D', 'Martina131102', 'Margherita D', 'nicolabW7955YM', 'anna d', 'Viketta', 'Andrea R', 'ragnetti68', 'RaffaeleM72', 'Hamosguetta', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Claudio R', 'inamor55', 'faro1984', 'Maverick900', 'sesee', 'Egomet33', 'Mikamale M', 'Paola635', '465darias', 'garpix', 'Giramonda79', 'rB1975', 'Arianna G', 'Aeago', 'Sarinag_13', 'Flower402', 'Flavio P', 'loredanac604', 'alcuomo', 'lucianardi', 'iGigius', 'Periscop', 'Alessandro V', 'marco_p_catone', 'francescaTmi', 'AUDI6666', 'Marco27x', '533lucaf', 'cecile b', 'ily59', 'avvocatoRoma', '989massi', 'soulrestaurant', 'Veronica G', 'Zino Z', 'rocha7', 'GingerandThelma', 'Tizianog_12', 'francesco789', 'MarianaNogravity', 'SuperMaC_Milano', 'Giuppa_12', 'Giovanni A', 'gardenmi', 'ferdinandom115', 'Gennaro N', 'pippob128', '341elianar', 'Nuria P', 'alessio b', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Claudio80Riga', 'Kingmille', 'dadap2014', 'mario v', 'GIOVANNI F', 'gardenmi', 'gioviale60', 'Dante G', 'annamariadeluca', 'Juventusfan', 'Mattia C', 'T1088FPfrancescob', 'Eirenector', '56carlop', 'gdc-cortomaltese', 'Francesco R', 'MonyDavi', 'Antonio V', 'DebbyCoppari', 'Crocco48', 'Raniero M', 'esperna', 'lella l', 'MADDALENA M', 'paolo l', 'corradol955', 'Alix2000', 'Luiggi2019', 'Marcella70Roma', 'Massimo A', 'Alessandro M', '966carlob', 'Ettore Z', 'umbertoimagine', 'frunko', 'arenopac', 'beatrice80', 'pucellandro', 'massimot10', 'singincla', 'furiopa', 'AriStid', 'Mirtilla67', 'Tizia ...
#
# ['NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'GuglielmoG', 'KnightChevalier', 'Emanuele', 'Consuelo', 'MLuisaRav', 'nickcassiusclay', 'maestroprimoconventi', 'ducagio', 'diegobon', 'michelebURP', 'laviniap', 'Gian', 'Giovanna', 'Bratislao', 'ottacarlotta', 'Alessandro', 'MatteaV', 'Amarillide', 'mgabriellam', 'Abrahamkatt', 'Cinziaver', 'giorgione', 'Ivanaxxx', 'roberto', 'jamiarri', 'Lrdn', 'laura', 'brightly', 'serdavi', 'piedone', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Giuseppe', 'Andrea', 'dadahtml', 'Bestgustibus', 'maxigigliucci', 'francescomarzo', 'EMMAT', 'enricoz', 'Catherine', 'Brunogrjjfjdnfjfj', 'Apicio', 'maracaterina', 'Carlox', 'gioRome', 'WPQclaudiab', 'massimo', 'AleSa', 'Filippo', 'Asia', 'Andrea', 'mafriroma', 'vierad', 'Bollechou', 'NFCgiuseppec', 'scorpiov', 'Ciccioerpiccoletto', 'Francisco', 'La', 'Alina', 'Franchini', 'Fantasma', 'Simone', 'JILmariom', 'Maurizio', 'julesgiugiu', 'EMTalicec', 'darias', 'Giramonda', 'raffaelep', 'Bari', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Picchiolo', 'CharlotteNY', 'Silvia', 'flych', 'Angela', 'frapa', 'travelasmuchIcan', 'zgianlu', 'kiphenry', 'LaFra', 'Majirelle', 'argania', 'Fabrizio', 'robertap', 'Luca', 'CARLO', 'nexus', 'GINTONIC', 'gian', 'ema', 'federicob', 'Skyattaman', 'Prinex', 'Michelina', 'IreneMARKETERs', 'Anna', 'stefaniae', 'Federico', 'Mario', 'silaroma', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'FoodLa', 'mirko', 'pietro', 'silviabon', 'Pecluca', 'Lola', 'annamariadeluca', 'brunellam', 'StefanoD', 'VitoFernandoD', 'Domenico', 'Ornella', 'AndreaV', 'wfiorde', 'andreafabia', 'Vito', 'rinoNapoli', 'Olga', 'headluk', 'Maria', 'Edoardo', 'Martina', 'Margherita', 'nicolabWYM', 'anna', 'Viketta', 'Andrea', 'ragnetti', 'RaffaeleM', 'Hamosguetta', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Claudio', 'inamor', 'faro', 'Maverick', 'sesee', 'Egomet', 'Mikamale', 'Paola', 'darias', 'garpix', 'Giramonda', 'rB', 'Arianna', 'Aeago', 'Sarinag', 'Flower', 'Flavio', 'loredanac', 'alcuomo', 'lucianardi', 'iGigius', 'Periscop', 'Alessandro', 'marcopcatone', 'francescaTmi', 'AUDI', 'Marcox', 'lucaf', 'cecile', 'ily', 'avvocatoRoma', 'massi', 'soulrestaurant', 'Veronica', 'Zino', 'rocha', 'GingerandThelma', 'Tizianog', 'francesco', 'MarianaNogravity', 'SuperMaCMilano', 'Giuppa', 'Giovanni', 'gardenmi', 'ferdinandom', 'Gennaro', 'pippob', 'elianar', 'Nuria', 'alessio', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'ClaudioRiga', 'Kingmille', 'dadap', 'mario', 'GIOVANNI', 'gardenmi', 'gioviale', 'Dante', 'annamariadeluca', 'Juventusfan', 'Mattia', 'TFPfrancescob', 'Eirenector', 'carlop', 'gdccortomaltese', 'Francesco', 'MonyDavi', 'Antonio', 'DebbyCoppari', 'Crocco', 'Raniero', 'esperna', 'lella', 'MADDALENA', 'paolo', 'corradol', 'Alix', 'Luiggi', 'MarcellaRoma', 'Massimo', 'Alessandro', 'carlob', 'Ettore', 'umbertoimagine', 'frunko', 'arenopac', 'beatrice', 'pucellandro', 'massimot', 'singincla', 'furiopa', 'AriStid', 'Mirtilla', 'TizianaZed', 'Ghigo', 'Sara', 'enricob', 'Cla', 'Laviniadodi', 'yorky', 'Pititta', 'Luisa', 'Marina', 'serendipity', 'alberto', 'Antonio', 'Sf', 'NikBon', 'hoibaffi', 'massifusion', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'antonio', 'Ghiottonefriulano', 'Cricola', 'GRaffaella', 'Mikamale', 'GABRIES', 'Umberto', 'Simone', 'DgSar', 'Maxxx', 'Chiarachiarina', 'stefanos', 'patriziaveratti', 'mgiornet', 'giamma', 'ale', 'GstarRoma', 'esperna', 'StefanoDM ...

# %% [markdown]
# #### Utilizzo gender_guesser
# Infine, posso utilizzare la libreria gender_guesser.
#
# NB: Genderize ti permette di analizzare 1000 nomi al giorno.

# %%
# !pip install gender_guesser
# Out:
# Requirement already satisfied: gender_guesser in /usr/local/lib/python3.6/dist-packages (0.4.0)

# %%
import gender_guesser.detector as gender
d = gender.Detector()

names_with_gender = []

for name in all_names_filtered:
    temp_gender = d.get_gender(name)
    names_with_gender.append(temp_gender)
  
print(names_with_gender)
# Out:
# ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'female', 'male', 'female', 'female', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'mostly_female', 'unknown', 'unknown', 'male', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown',  ...

# %%
all_genders = []
i = 0

for guess in names_with_gender:
    if guess == 'male' or guess == 'mostly_male':
        all_genders.append('M')
    elif guess == 'female' or guess == 'mostly_female':
        all_genders.append('F')
    else:
        all_genders.append('UNKNOWN')

    
print(all_genders)
# Out:
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'M', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', ' ...

# %% [markdown]
# ---
# ## Salviamo ora i dati ottenuti in una tabella Excel
# Così non dovremo ogni volta rieseguire tutto il codice

# %% [markdown]
# ### Controlliamo che ci siano lo stesso numero di dati
# Potremo così creare una tabella sfruttando Pandas

# %%
print('Nomi: ', len(all_names_filtered))
print('Commenti: ', len(all_reviews_filtered))
print('Voti: ', len(all_ratings))
print('Mobile: ', len(all_mobile))
# Out:
# Nomi:  1195
# Commenti:  1195
# Voti:  1195
# Mobile:  1195

# %% [markdown]
# ### Eliminiamo le recensioni troppo lunghe e quelle di cui non sappiamo il genere del commentatore
# Creo una lista di liste [ ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ... ]

# %%
complete_list = []

i = len(all_names_filtered)

for indice in range(i):
  if all_genders[indice] != 'UNKNOWN' and all_reviews_filtered[indice] != 'RECENSIONE_TROPPO_LUNGA':
    temp = [all_names_filtered[indice], all_genders[indice], all_reviews_filtered[indice], all_ratings[indice], all_mobile[indice]]
    complete_list.append(temp)
    
print('DATI ANALIZZABILI: ', len(complete_list))
display(complete_list[:5])
# Out:
# DATI ANALIZZABILI:  172
# [['Giuseppe',
#   'M',
#   "Consiglio di prenotare. Storico ristorante, assai gradevole anche all'aperto, nella piazza pedonale. Ottimo pesce, con porzioni regolari con servizio decisamente professionale. Piatti tutti ben elaborati e di alta qualità. Una chicca finale inperdibile: carpaccio di ananas.",
#   '4',
#   'Mobile'],
#  ['Catherine',
#   'F',
#   'Ottimo ristorante, pesce freschissimo, lista dei vini notevole e staff preparatissimo e amichevole. Consiglio vivamente la catalana di gamberi...la migliore che abbia mai mangiato!!!!',
#   '5',
#   'Mobile'],
#  ['Maurizio',
#   'M',
#   'Cenato in questo locale alla fine di tre intensi giorni di lavoro. Conosciuto il titolare e fatte quattro chiacchere molto ma molto interessanti ed utili. Lorenzo e’ persona intelligente e di una disponibilita’ unica. Location elegante, grande cantina e cucina ottima. Veramente molto positivo. Bravi.',
#   '5',
#   'Mobile'],
#  ['Angela',
#   'F',
#   'Siamo ritornati di recente in questo ristorante e ancora una volta abbiamo soddisfatto le nostre aspettative. Qualità ottima. Professionalità e cortesia eccellenti. Bella location. Cosa desiderare di più?',
#   '5',
#   'Mobile'],
#  ['Michelina',
#   'F',
#   "Cibo assolutamente ordinario, servizio lento e intermittente, conto salato ... Inoltre ci hanno messo a mangiare fuori nonostante il freddo...avrebbero dovuto esserci le pomposamente definite pashmine ( in realta' modestissime coperte di paille ) ma non ne avevano a sufficienza ...esperienza del tutto negativa.",
#   '1',
#   'PC']]

# %% [markdown]
# ### Creiamo la tabella

# %%
# !pip install pandas
# !pip install xlsxwriter
import pandas as pd

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame({'Nomi': [elemento[0] for elemento in complete_list], 
                   'Genere': [elemento[1] for elemento in complete_list], 
                   'Recensioni': [elemento[2] for elemento in complete_list],
                   'Voti': [elemento[3] for elemento in complete_list],
                   'Scritta da': [elemento[4] for elemento in complete_list]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RISTORANTE_16.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
partial_dataframe = pd.read_excel("RISTORANTE_16.xlsx")

display(partial_dataframe)
# Out:
#     Genere        Nomi                                         Recensioni  \
# 0        M    Giuseppe  Consiglio di prenotare. Storico ristorante, as...
# 1        F   Catherine  Ottimo ristorante, pesce freschissimo, lista d...
# 2        M    Maurizio  Cenato in questo locale alla fine di tre inten...
# 3        F      Angela  Siamo ritornati di recente in questo ristorant...
# 4        F   Michelina  Cibo assolutamente ordinario, servizio lento e...
# 5        M    Federico  buoni i crudi,ottimo il vino. Critico sulla pa...
# 6        M    Domenico  Ho detto tutto nel titolo, abbiamo mangiato be...
# 7        M        Vito  Sono stato a cena con la mia compagna. Ambient...
# 8        F  Margherita  Pierluigi è il ristorante!!! Tutti i crudi di ...
# 9        F       Paola  Location stupenda nella cinquecentesca piazza ...
# 10       M      Flavio  non c'è che dire.. la classe, l'attenzione al ...
# 11       M        Zino  il cibo è buono come pure la qualità, lascia a...
# 12       M       Dante  La location risulta eccezionale, la cucina ott...
# 13       M     Antonio  Ottimi i primi. Vi consiglio di provare la "Ma...
# 14       M      Ettore  ottimo posto dove degustare un ottimo fiore di...
# 15       F        Sara  La cucina è davvero il top!!!\nNel centro di R...
# 16       F       Luisa  Ottimo pesce e locale molto bello.magnifico d'...
# 17       M     Antonio  Antipasto e primo molto buoni. Servizio impecc...
# 18       M     Umberto  Bel locale, esteticamente più carino di quanto...
# 19       F      Simone  Il posto a Roma tra i più buoni dove poter gus...
# 20       M       Fabio  Location incantevole nel cuore di Roma! Bellis...
# 21       F      Marina  Questo locale sarà una tappa obbligata nei mie...
# 22       M    Domenico  E' forse l'unico ristorante del centro storico...
# 23       M        Mike  Cenato benissimo. Fanno le cose semplice. Otti...
# 24       M       Fabio  Bella location, accogliente ed elegante piazza...
# 25       F       Nadia  Tre amiche sempre alla ricerca di cose buone e...
# 26       M    Emiliano  uno dei pochi ristoranti al centro di roma dov...
# 27       M       Carlo  ho avuto la fortuna di cenare nella stessa ser...
# 28       M      Enrico  la location è fantastica, da frequentare nel p...
# 29       F   Valentina  Ambiente semplice e raffinato, ingredienti di ...
# ..     ...         ...                                                ...
# 142      F       Linda  Dopo aver letto tutte le recensioni per l'ulti...
# 143      M       Randy  Questo ristorante è stato consigliato dalla no...
# 144      F       Katie  Molte persone consigliato questo ristorante a ...
# 145      M        Jack  Non scrivere recensioni in genere, ma il servi...
# 146      M     Charles  Questo ristorante ci è stato vivamente consigl...
# 147      F        Kate  Abbiamo iniziato con uno spuntino delizioso di...
# 148      M     Charlie  Questo ristorante è stato consigliato da amici...
# 149      F        Gail  Il cibo qui era terribile. I nostri antipasti ...
# 150      M        Rory  Abbiamo trovato Pierluigi da chance dopo una l...
# 151      F     Pauline  Ci hanno mandato qui dal nostro autista person...
# 152      F      Tamara  Io e mio marito abbiamo trascorso una piacevol...
# 153      M      Sanjay  Un pasto di 5 portate a Pierluigi's ha due eff...
# 154      M      Thomas  Pierluigi è dotato di una raccomandazione Mich...
# 155      F   Genevieve  Siamo andati a Pierluigi per la nostra notte u...
# 156      M       Craig  Io e mia moglie abbiamo davvero apprezzato la ...
# 157      F        Lola  Il cibo era buono, ma state attenti quando si ...
# 158      F    Jeannine  Pier Luigi's è sempre stato uno di mio marito ...
# 159      M     William  Situato in una piccola piazza lontano dalle st...
# 160      F       Irina  E' piuttosto un ristorante acclamato a Roma, e...
# 161      F     Kathryn  Abbiamo alloggiato in un Campo di Fiori area e...
# 162      F        Olga  Zuccini fiori e pesce - raw, grigliate cotte. ...
# 163      F         Amy  Questo ristorante è stato consigliato a me e m...
# 164      F       Brook  Pierluigi ha un grande patio esterno che abbia...
# 165      M       Peter  Mentre il cibo era buono e il servizio era ter...
# 166      F     Lindsay  Pierluigi ha pesce fresco e piatti raffinati! ...
# 167      F      Amanda  Per il mio primo viaggio a Roma mi è stato det...
# 168      M        Drew  Mentre pieno di turisti, uno non si sente ques...
# 169      M        Rory  Consigliato da un amico, dal momento in cui si...
# 170      M      Stuart  Siamo andati a Peirluigis per la prima volta i...
# 171      F        Anne  Meraviglioso pasto in una tranquilla piazza vi...
#
#     Scritta da  Voti
# 0       Mobile     4
# 1       Mobile     5
# 2       Mobile     5
# 3       Mobile     5
# 4           PC     1
# 5           PC     5
# 6       Mobile     4
# 7           PC     1
# 8       Mobile     5
# 9           PC     4
# 10          PC     5
# 11          PC     4
# 12      Mobile     4
# 13      Mobile     5
# 14      Mobile     5
# 15      Mobile     5
# 16          PC     5
# 17      Mobile     5
# 18          PC     3
# 19      Mobile     5
# 20          PC     5
# 21      Mobile     5
# 22          PC     5
# 23          PC     5
# 24          PC     2
# 25          PC     3
# 26          PC     5
# 27          PC     5
# 28          PC     4
# 29          PC     5
# ..         ...   ...
# 142     Mobile     5
# 143         PC     5
# 144         PC     3
# 145         PC     2
# 146         PC     1
# 147         PC     3
# 148         PC     1
# 149         PC     1
# 150         PC     3
# 151         PC     5
# 152     Mobile     5
# 153         PC     5
# 154         PC     3
# 155         PC     5
# 156         PC     4
# 157         PC     3
# 158         PC     1
# 159         PC     4
# 160         PC     3
# 161         PC     2
# 162         PC     5
# 163         PC     4
# 164         PC     5
# 165         PC     1
# 166         PC     5
# 167         PC     5
# 168         PC     5
# 169         PC     5
# 170         PC     4
# 171         PC     5
#
# [172 rows x 5 columns]
