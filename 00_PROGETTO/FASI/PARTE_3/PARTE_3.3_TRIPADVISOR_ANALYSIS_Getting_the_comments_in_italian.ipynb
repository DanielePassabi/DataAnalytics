# %% [markdown]
# # Creo un nuovo dataset

# %% [markdown]
# ---
# ## Analisi dei commenti di un ristorante
#
# ### Regina Elena - Abruzzo
#
# URL di riferimento: https://www.tripadvisor.it/Restaurant_Review-g187770-d1769947-Reviews-Regina_Elena-Pescara_Province_of_Pescara_Abruzzo.html
#
# Home --> Ristoranti --> Firenze --> Best_ranking--> SENZ_ALTRO_Bistrot

# %%
# IMPORT NECESSARI
import requests
from bs4 import BeautifulSoup

print("Imported")
# Out:
# Imported

# %%
page_URL = "https://www.tripadvisor.it/Restaurant_Review-g187770-d1769947-Reviews-Regina_Elena-Pescara_Province_of_Pescara_Abruzzo.html"

data = requests.get(page_URL)
clear_data = BeautifulSoup(data.content, "lxml")

print("Done")
# Out:
# Done

# %% [markdown]
# ---
# ### STRUTTURA HTML DEL SITO
#
# #### REVIEW
# `<p class="partial_entry"> qui c'è la review </p>`
#
# #### N° TOTALE DI REVIEWS
# `<a data-page-number="25" ...>
#     25
#  </a>`
#
# #### NAMES
# `<span class="expand_inline scrname" …>AlexandraCapeTown</span>`
#
# #### RATINGS
# `<span class="ui_bubble_rating bubble_30"></span>`

# %% [markdown]
# ---
# ### PRIMO SCRAPING (sulla prima pagina)
#
# Ottengo i nomi, i commenti, le review e da dove è stato scritto il commento per quanto rigurda la prima pagina. Ciò è necessario, in quanto, dalla seconda in poi l'URL cambia, permettendoci di iterare.

# %%
# OTTENGO UNA LISTA DI DIV CHE CONTENGONO NOME, RECENSIONE E VOTO

all_reviews = []
all_names = []
all_ratings = []
all_mobile = []

review_container = clear_data.findAll("div", attrs={"class":"review-container"})

for container in review_container:
  
    ### REVIEW ###
    review = container.find('p', attrs={'class': 'partial_entry'})
    if review:
        all_reviews.append(review.text)
        
    ### NAME ###
    name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
    if name:
      all_names.append(name.text)
    else:
      all_names.append('NO_NAME')
    
    ### RATING ###
    rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
    all_ratings.append(rating['class'][1][7:8])
    
    ### MOBILE ###
    mobile = container.find('span', attrs={'class': 'viaMobile'})
    if mobile:
      all_mobile.append('Mobile')
    else:
      all_mobile.append('PC')
    
    
################################################################################################################################
        
print("Executed")
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# Nomi:  10
# Commenti:  10
# Voti:  10
# Scritto da:  10

# %% [markdown]
# ### SECONDO SCRAPING (dalla seconda pagina in poi)
#
# Notiamo dall'URL che è possibile iterare sulle pagine, ottenendo i dati!

# %%
URL_COMPLETO = 'https://www.tripadvisor.it/Restaurant_Review-g187770-d1769947-Reviews-or10-Regina_Elena-Pescara_Province_of_Pescara_Abruzzo.html'

URL_p1 = 'https://www.tripadvisor.it/Restaurant_Review-g187770-d1769947-Reviews-or'
URL_p2 = '0-Regina_Elena-Pescara_Province_of_Pescara_Abruzzo.html'
    
# OTTENGO I COMMENTI, NOMI E VOTI DALLA SECONDA PAGINA IN POI

total_pages = int(clear_data.select("a.pageNum.last.taLnk")[0].text) # 25 come intero

# per iterare dobbiamo partire dalla seconda pagina dei commenti, così nell'URL compaiono le cifre che ci servono
for r in range(1,total_pages):

    # OTTENGO L'URL DELLA PAGINA
    URL_temp = URL_p1 + str(r) + URL_p2

    # OTTENGO I DATI E CI APPLICO BEATIFULSOUP
    data = requests.get(URL_temp)
    clear_data = BeautifulSoup(data.content, "lxml")
    

    review_container = clear_data.findAll("div", attrs={"class":"review-container"})

    for container in review_container:
  
      ### REVIEW ###
      review = container.find('p', attrs={'class': 'partial_entry'})
      if review:
          all_reviews.append(review.text)

      ### NAME ###
      name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
      if name:
        all_names.append(name.text)
      else:
        all_names.append('NO_NAME')

      ### RATING ###
      rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
      all_ratings.append(rating['class'][1][7:8])

      ### MOBILE ###
      mobile = container.find('span', attrs={'class': 'viaMobile'})
      if mobile:
        all_mobile.append('Mobile')
      else:
        all_mobile.append('PC')
    
        
################################################################################################################################
        
print("Executed")
print('total_pages: ', total_pages)
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# total_pages:  152
# Nomi:  1517
# Commenti:  1517
# Voti:  1517
# Scritto da:  1517

# %%
# display(all_reviews)

# %%
# print(all_names)

# %%
#print(all_ratings, '\n')
#print(len(all_ratings))

# %%
#display(all_mobile)

# %% [markdown]
# #### Problema recensioni troppo lunghe
# Alla fine di alcune recensioni troviamo un '...Più', che non possiamo espandere. Data la mole di dati, decidiamo dunque di non considerarle.

# %%
all_reviews_filtered = []
counter_reviews_scartate = 0;
counter_reviews_da_usare = 0;

for review in all_reviews:
    if '...Più' in review:
        all_reviews_filtered.append('RECENSIONE_TROPPO_LUNGA')
        counter_reviews_scartate+=1;
    else:
        all_reviews_filtered.append(review)
        counter_reviews_da_usare+=1;
        
        
print(
    'Totale recensioni:', counter_reviews_scartate + counter_reviews_da_usare, '\n',
    'Recensioni analizzabili:', counter_reviews_da_usare, '\n',
    'Recensioni scartate:', counter_reviews_scartate, '\n')

display(all_reviews_filtered[:10])
# Out:
# Totale recensioni: 1517
#  Recensioni analizzabili: 780
#  Recensioni scartate: 737
# ['RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Esperienza aldilà delle nostre aspettative, buon cibo e servizio disponibile ma non invadente. Più che approvato!',
#  'RECENSIONE_TROPPO_LUNGA',
#  "Sono andata in questo ristorante spinta da tutti i commenti positivi ma sono rimasta un po' delusa... gli antipasti non mi hanno entusiasmata.. già visti... poco conditi. Rapporto qualità prezzo un po' altino.",
#  'Come al solito il top! Antipasti delicati,primi sfiziosi e servizio impeccabile! Vini eccellenti e la simpatia unica del direttore!',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA']

# %% [markdown]
# ---
# ### Analisi dei nomi
# Cerchiamo di capire se chi ha commentato è un uomo (M) o una donna (F).

# %% [markdown]
# #### Elimino spazi e numeri
# Ho bisogno di tenere solo le informazioni riguardanti il nome, elimino il resto.

# %%
import re

all_names_filtered = []

regex = re.compile('[^a-zA-Z]')

for name in all_names:
    
    if ' ' in name:                           # se c'è uno spazio nel nome
        space = name.index(' ')               # ne trovo l'indice
        name = regex.sub('', name[:space])    # effettuo un controllo su tutto ciò che non è alfabeto fino a quell'indice
        all_names_filtered.append(name)       # e aggiungo la stringa
        
    else:
        name = regex.sub('', name)            # in caso contrario effettuo un controllo su tutto ciò che non è alfabeto
        all_names_filtered.append(name)       # e aggiungo la stringa
        
print(all_names, '\n')
print(all_names_filtered)
# Out:
# ['NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'angelod303', 'Companion40312203695', 'Chiara S', 'Coastal53216702414', 'guglielmoc613', 'Rolando B', 'Karin123123123', '_eleonorax94', 'michelepF4746OT', 'Tiziana R', 'LLDD', 'simoneo675', '23ariannad', '1carmined', 'AlbertoRJ', 'Lucy74Roma', 'simonesG7119NN', 'sergioferre', 'Gianmarco G', 'Andrebo86', 'MarziAndre', 'Cholo68', '804paolos', 'Michaela S', 'AleSpada96', 'gaetanov514', 'alessio d', 'Ed0ard003', 'Vincenzo P', 'ippdom', 'Rita L', 'Box43', '007delGusto', 'Giuseppe G', 'Z953RBpaolor', 'Fabio T', 'Rino10marzo', 'ventodipassione', 'TommasoColomba', '201dorianad', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'CurvaSudBn', 'Massimiliano S', 'Angelo262', 'Viaggiamigo', '_mariapg80', 'Jiulia28', 'pippottobello', 'KrizelleGacayan', 'angelod303', 'ann820', 'walter6203', 'flavia771974', 'infodimonte', 'Mirko V', 'Vincenzo P', 'marcellot437', 'Collu85', 'Monica_Gotto', 'Manuela P', 'Francesco A', '619patriziag', 'danielebC2628YO', 'R3156JValessandrod', 'StarMichelins', 'adriantonaci52', 'Giuseppe L', 'gioc701', '284ivanag', 'paoladg', 'LavignaGiuseppe', 'Raffaele V', 'giodimarzio', 'Lino D', 'Pietro S', 'michelap1808', 'ippdom', 'Laura G', '14gianfrancol', 'PAOLO S', 'noecld', 'LittlePalomino', 'Anna P', 'alexpe85', 'Claudio C', 'bibyman67', 'domenico2571BO', 'gabrieles154', 'Fabri V', 'Aniello_Stay_Rock', 'Luca79Pescara', 'FrancaD122', 'totonno_12', 'Chiaramos', '9BSJL1', 'Federica R', 'R5674ZRandreap', 'Yaryna1212', 'Darioriolinobriatore', 'thaurturiono', '986marcoo', 'Viaggiochehobby', 'lady20182018', 'P8837ZBgiudiceimparz', 'pasqualef140', 'FarfallaV0lante', 'Arturo S', 'Alessandra F', 'G2745GPfrancescod', 'Giuseppe L', '79leonardobt', 'domenicomZ7255UU', 'Navarro68', 'Ottavio M', 'cillone1975', 'Lollos1977', 'charlotteking85', 'giulio007', 'blue_eyesPesaro', 'simyzag', 'PIMPETTO', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'maxsi', 'Alessio_Paniccia', 'Orangebutterfly28', 'Viaggiochehobby', '108maricar', 'MRdada', 'Mattinno', 'guidocam66', 'antocarota', 'teate90', 'rangerpol77', 'leope2015', 'Fabxtra', 'Antonio I', '581ciroc', 'Francescasupino', 'Giuseppe S', 'suffredlisabetta', 'Michele C', 'pinkfloyd1989', 'Enzo G', 'ippdom', 'Ansmarte', 'Y605LNdanieled', 'simolemon84', 'rinforzo', 'antony256', '118silviac', '1980carlo', 'Bis81', '369CarloS', 'Silviadnc', 'nnnnnnfff', 'pietro s', 'Sabrina D', 'Melania590', 'Sofia Elena S', 'donatoc912', 'Barbara G', 'Vincenzo G', 'uragano084', 'raffyraffy84', 'giovannio870', 'Lousalome M', 'adifg', 'Nico_Robin_92', 'arajsan', 'LorenzaB249', 'joeypotterannare', 'Lisippo1003', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'deborahdS3193UC', 'lapina30', 'gina l', 'Fabrifio', 'maryesigente', 'Max S', 'Alessandro_19682014', 'lucabrigante', 'antoniopolycar', 'Gessica C', 'achitasi', 'MOTORARMY58', 'Francesca S', 'ramark63', 'Gioia0022', 'W5332TRsandraf', 'dennypassat', 'ilFustigato', 'pietro996', 'vala22003', 'Mariangela_1984_2014', 'Luigi D', 'roccov69', 'Rosi2765', 'Ciro P', 'Alessia T', 'Giuseppe B', 'Carolina P', 'armando173158', 'Debora D', 'AntonChecov', 'angelod303', 'serpente1976', 'shedevil76', 'Pedrito77', 'Alessandro D', 'WilliamTT_12', 'Vincenzo F', '63claudiab', 'Gabrianna', 'Beatrice P', 'bia86', 'Federica D', 'Stefanobucci', 'lucianonoce', 'robertobA5816HM', 'Antonio D', 'bombolo2013', 'fvissali', 'BIGODINO1952', 'Patrizia L', 'chiara82sp', 'GiuseppeS263', 'fradipalma', 'Mariquita88', 'cicored22', 'LoreDif', 'Piterigno', 'coccaupi', 'Claudio F', 'RecyBS', '250chiarad', 'Giulia M', 'ron80', 'sergio t', 'edogig', 'piastra91', 'Antonio P', 'Marco R', 'DomPerignon70', 'salvatorei482', 'Alessandra C', 'Pierluigi S', 'Alefilo2004', 'FilippoL986', 'macchiag76', 'gabriel7474', 'detola ...
#
# ['NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'angelod', 'Companion', 'Chiara', 'Coastal', 'guglielmoc', 'Rolando', 'Karin', 'eleonorax', 'michelepFOT', 'Tiziana', 'LLDD', 'simoneo', 'ariannad', 'carmined', 'AlbertoRJ', 'LucyRoma', 'simonesGNN', 'sergioferre', 'Gianmarco', 'Andrebo', 'MarziAndre', 'Cholo', 'paolos', 'Michaela', 'AleSpada', 'gaetanov', 'alessio', 'Edard', 'Vincenzo', 'ippdom', 'Rita', 'Box', 'delGusto', 'Giuseppe', 'ZRBpaolor', 'Fabio', 'Rinomarzo', 'ventodipassione', 'TommasoColomba', 'dorianad', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'CurvaSudBn', 'Massimiliano', 'Angelo', 'Viaggiamigo', 'mariapg', 'Jiulia', 'pippottobello', 'KrizelleGacayan', 'angelod', 'ann', 'walter', 'flavia', 'infodimonte', 'Mirko', 'Vincenzo', 'marcellot', 'Collu', 'MonicaGotto', 'Manuela', 'Francesco', 'patriziag', 'danielebCYO', 'RJValessandrod', 'StarMichelins', 'adriantonaci', 'Giuseppe', 'gioc', 'ivanag', 'paoladg', 'LavignaGiuseppe', 'Raffaele', 'giodimarzio', 'Lino', 'Pietro', 'michelap', 'ippdom', 'Laura', 'gianfrancol', 'PAOLO', 'noecld', 'LittlePalomino', 'Anna', 'alexpe', 'Claudio', 'bibyman', 'domenicoBO', 'gabrieles', 'Fabri', 'AnielloStayRock', 'LucaPescara', 'FrancaD', 'totonno', 'Chiaramos', 'BSJL', 'Federica', 'RZRandreap', 'Yaryna', 'Darioriolinobriatore', 'thaurturiono', 'marcoo', 'Viaggiochehobby', 'lady', 'PZBgiudiceimparz', 'pasqualef', 'FarfallaVlante', 'Arturo', 'Alessandra', 'GGPfrancescod', 'Giuseppe', 'leonardobt', 'domenicomZUU', 'Navarro', 'Ottavio', 'cillone', 'Lollos', 'charlotteking', 'giulio', 'blueeyesPesaro', 'simyzag', 'PIMPETTO', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'maxsi', 'AlessioPaniccia', 'Orangebutterfly', 'Viaggiochehobby', 'maricar', 'MRdada', 'Mattinno', 'guidocam', 'antocarota', 'teate', 'rangerpol', 'leope', 'Fabxtra', 'Antonio', 'ciroc', 'Francescasupino', 'Giuseppe', 'suffredlisabetta', 'Michele', 'pinkfloyd', 'Enzo', 'ippdom', 'Ansmarte', 'YLNdanieled', 'simolemon', 'rinforzo', 'antony', 'silviac', 'carlo', 'Bis', 'CarloS', 'Silviadnc', 'nnnnnnfff', 'pietro', 'Sabrina', 'Melania', 'Sofia', 'donatoc', 'Barbara', 'Vincenzo', 'uragano', 'raffyraffy', 'giovannio', 'Lousalome', 'adifg', 'NicoRobin', 'arajsan', 'LorenzaB', 'joeypotterannare', 'Lisippo', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'deborahdSUC', 'lapina', 'gina', 'Fabrifio', 'maryesigente', 'Max', 'Alessandro', 'lucabrigante', 'antoniopolycar', 'Gessica', 'achitasi', 'MOTORARMY', 'Francesca', 'ramark', 'Gioia', 'WTRsandraf', 'dennypassat', 'ilFustigato', 'pietro', 'vala', 'Mariangela', 'Luigi', 'roccov', 'Rosi', 'Ciro', 'Alessia', 'Giuseppe', 'Carolina', 'armando', 'Debora', 'AntonChecov', 'angelod', 'serpente', 'shedevil', 'Pedrito', 'Alessandro', 'WilliamTT', 'Vincenzo', 'claudiab', 'Gabrianna', 'Beatrice', 'bia', 'Federica', 'Stefanobucci', 'lucianonoce', 'robertobAHM', 'Antonio', 'bombolo', 'fvissali', 'BIGODINO', 'Patrizia', 'chiarasp', 'GiuseppeS', 'fradipalma', 'Mariquita', 'cicored', 'LoreDif', 'Piterigno', 'coccaupi', 'Claudio', 'RecyBS', 'chiarad', 'Giulia', 'ron', 'sergio', 'edogig', 'piastra', 'Antonio', 'Marco', 'DomPerignon', 'salvatorei', 'Alessandra', 'Pierluigi', 'Alefilo', 'FilippoL', 'macchiag', 'gabriel', 'detolandia', 'MarcoV', 'Martina', 'FabioG', 'fortyforty', 'BonifacioVIII', 'angelobBTV', 'Federica', 'mamalanalu', 'caffo', 'teo', 'Gasupallo', 'ippdom', 'Meorigh', '', 'francoa', 'Singi', 'GABRIELE', 'tarassa', 'Massimiliano', 'SciutoSat', 'OHBstefanod', 'Spadaccini', 'Silvia', 'pennastik', 'Ilaria', 'alfredo', 'CarloDur', 'LucyRoma', 'Enza', 'Sabrina', 'AntonelloCampanelli', 'stediluzio', 'Ruggerodec', 'gcapuano', 'gasparec', 'NINOLIDIA', 'vincenzo', 'egon', 'Michele', 'Pixi', 'AndreaB', 'GiuseppeD', 'danieleniddu', 'geric', 'guglielmodorange', 'mrsambo', 'mattiap', 'Katia ...

# %% [markdown]
# #### Utilizzo gender_guesser
# Infine, posso utilizzare la libreria gender_guesser.
#
# NB: Genderize ti permette di analizzare 1000 nomi al giorno.

# %%
# !pip install gender_guesser
# Out:
# Requirement already satisfied: gender_guesser in /usr/local/lib/python3.6/dist-packages (0.4.0)

# %%
import gender_guesser.detector as gender
d = gender.Detector()

names_with_gender = []

for name in all_names_filtered:
    temp_gender = d.get_gender(name)
    names_with_gender.append(temp_gender)
  
print(names_with_gender)
# Out:
# ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'female', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'female', 'male', 'female', 'male', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'u ...

# %%
all_genders = []
i = 0

for guess in names_with_gender:
    if guess == 'male' or guess == 'mostly_male':
        all_genders.append('M')
    elif guess == 'female' or guess == 'mostly_female':
        all_genders.append('F')
    else:
        all_genders.append('UNKNOWN')

    
print(all_genders)
# Out:
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'F', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'F', 'M', 'F', 'M', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...

# %% [markdown]
# ---
# ## Salviamo ora i dati ottenuti in una tabella Excel
# Così non dovremo ogni volta rieseguire tutto il codice

# %% [markdown]
# ### Controlliamo che ci siano lo stesso numero di dati
# Potremo così creare una tabella sfruttando Pandas

# %%
print('Nomi: ', len(all_names_filtered))
print('Commenti: ', len(all_reviews_filtered))
print('Voti: ', len(all_ratings))
print('Mobile: ', len(all_mobile))
# Out:
# Nomi:  1517
# Commenti:  1517
# Voti:  1517
# Mobile:  1517

# %% [markdown]
# ### Eliminiamo le recensioni troppo lunghe e quelle di cui non sappiamo il genere del commentatore
# Creo una lista di liste [ ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ... ]

# %%
complete_list = []

i = len(all_names_filtered)

for indice in range(i):
  if all_genders[indice] != 'UNKNOWN' and all_reviews_filtered[indice] != 'RECENSIONE_TROPPO_LUNGA':
    temp = [all_names_filtered[indice], all_genders[indice], all_reviews_filtered[indice], all_ratings[indice], all_mobile[indice]]
    complete_list.append(temp)
    
print('DATI ANALIZZABILI: ', len(complete_list))
display(complete_list[:5])
# Out:
# DATI ANALIZZABILI:  162
# [['Karin',
#   'F',
#   'Un ambiente fine curato nei minimi dettagli. Servizio ottimo, personale gentilissimo e cibo oltre le aspettative. Per una serata romantica, rilassante e gustosa qui è il posto in cui andare. Assolutamente da non perdere.',
#   '5',
#   'Mobile'],
#  ['Tiziana',
#   'F',
#   'Torno sempre volentieri in questo splendido posto. Cucina sempre ad alti livelli, sapori raffinati e abbinamenti sempre originali ma il tutto con grande gusto e con grande attenzione anche alla presentazione. Personale attento e gentile. Che dire tutti superbravi.',
#   '5',
#   'Mobile'],
#  ['Vincenzo',
#   'M',
#   'Regina Elena si conferma una certezza assoluta nel panorama della ristorazione di livello. Menù arricchito con tante novità sempre di altissimo livello. Il direttore Gianni è sempre gentile disponibile e preparatissimo e attentissimo al benessere dei suoi clienti. Numero 1 assoluto!',
#   '5',
#   'Mobile'],
#  ['Giuseppe',
#   'M',
#   'Telegraficamente...ma non per questo riduttivo...tutto ottimo...dalla location al servizio e al cibo,tutto equilibrato che lascia un "retrogusto "che invita a tornarci.Complimenti.',
#   '5',
#   'Mobile'],
#  ['Fabio',
#   'M',
#   'Ci siamo fidati delle recensioni.\nOttimo.\nIl direttore una persona squisita.\nIl personale di sala preparato.\nI piatti elaborati al punti giusto.\nInsomma ci siamo trovati benissimo.\nSicuramente ci ritorneremo.',
#   '5',
#   'Mobile']]

# %% [markdown]
# ### Creiamo la tabella

# %%
# !pip install pandas
# !pip install xlsxwriter
import pandas as pd

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame({'Nomi': [elemento[0] for elemento in complete_list], 
                   'Genere': [elemento[1] for elemento in complete_list], 
                   'Recensioni': [elemento[2] for elemento in complete_list],
                   'Voti': [elemento[3] for elemento in complete_list],
                   'Scritta da': [elemento[4] for elemento in complete_list]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RISTORANTE_3.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
partial_dataframe = pd.read_excel("RISTORANTE_3.xlsx")

display(partial_dataframe)
# Out:
#     Genere        Nomi                                         Recensioni  \
# 0        F       Karin  Un ambiente fine curato nei minimi dettagli. S...
# 1        F     Tiziana  Torno sempre volentieri in questo splendido po...
# 2        M    Vincenzo  Regina Elena si conferma una certezza assoluta...
# 3        M    Giuseppe  Telegraficamente...ma non per questo riduttivo...
# 4        M       Fabio  Ci siamo fidati delle recensioni.\nOttimo.\nIl...
# 5        M    Vincenzo  Regina Elena si conferma il miglior ristorante...
# 6        F     Manuela  Location bella ed elegante, pesce freschissimo...
# 7        M    Giuseppe  Abbiamo pranzato in questo ristorante tanto de...
# 8        M    Raffaele  Ristorante in centro molto Accogliente pesce f...
# 9        M        Lino  Ristorante dove le bontà sono infinite,la deli...
# 10       F        Anna  Bellissimo posto incantevo e buonissimo cibo c...
# 11       M     Claudio  A due passi dal litorale si trova questo risor...
# 12       F    Federica  Pesce freschissimo, accompagnato da ottimi con...
# 13       M      Arturo  Scoperto tramite questo sito, siamo stati a pr...
# 14       F  Alessandra  Per noi uno dei migliori ristoranti di pescara...
# 15       M     Antonio  Posto grazioso ottimamente gestito dal Diretto...
# 16       M    Giuseppe  Locale che crea un'atmosfera ideale per cene e...
# 17       M        Enzo  Una cucina ben curata con particolare attenzio...
# 18       F       Sofia  siamo capitati per un pranzo che non era progr...
# 19       M         Max  Ristorante eccellente sotto ogni aspetto. Il s...
# 20       F     Gessica  Bella atmosfera ottimi i crudi freschissimo e ...
# 21       F   Francesca  Senza dubbio uno dei migliori ristoranti di pe...
# 22       F       Gioia  Ho festeggiato la mia laurea in questo belliss...
# 23       F        Rosi  Servizio impeccabile, molto molto buono.\nPicc...
# 24       F     Alessia  Ristorante consigliatissimo per i suoi piatti ...
# 25       F      Debora  Locale molto curato nell’arredamento e nel ser...
# 26       M  Alessandro  eccellente cena con amici\npersonale professio...
# 27       F    Beatrice  Un ottimo ristorante per coppie o famiglie, co...
# 28       F    Federica  Il locale è molto raffinato ed il servizio è o...
# 29       M     Antonio  Sono stato più volte in questo locale. Sono se...
# ..     ...         ...                                                ...
# 132      F       Patty  Raffinatezza, eleganza, gentilezza e ottimo ci...
# 133      M       Mario  Semplicemente ottimo sotto ogni punto di vista...
# 134      F     Michela  Tutto molto buono, pesce fresco e piatti sfizi...
# 135      F       Sonia  Qualità, cortesia del personale, ottima carta ...
# 136      M      Sergio  Ho cenato i primi di gennaio e ritengo di esse...
# 137      F       Carla  Ottimo !!!! Cucina raffinata, servizio impecca...
# 138      F        Dudu  Abbiamo festeggiato oggi stesso il battesimo d...
# 139      M     Stefano  Atmosfera e servizio impeccabili, cucina ottim...
# 140      M        Gian  Piacevole ristorante dove si può degustare del...
# 141      M       Fabio  Accoglienza eccellente come il servizio. Profe...
# 142      M        Enzo  Tutto molto buono servizio impeccabile.persona...
# 143      M    Giovanni  BRAVI detto da chi mangia in ristoranti tutti ...
# 144      F     Michele  Grande cucina marinara con i giusti sapori del...
# 145      F     Manuela  Per il pesce a pescara.... solo alla Regina :)...
# 146      M      Felipe  Ottimo ristorante con servizio cortese e profe...
# 147      F    Annalisa  Il ristorante, che già conoscevo per l'ottimo ...
# 148      F  Martinella  Siamo stati in questo splendido ristorante ogg...
# 149      M     Luciano  L'ambiente molto accogliente è il preludio per...
# 150      M         Gad  Ambiente elegante ma informale, servizio corte...
# 151      F    Fabrizia  In assoluto il miglior ristorante di Pescara. ...
# 152      M     Roberto  Il ristorante e' molto carino ed il servizio e...
# 153      F   Francesca  Un menù eccellente, con piatti gustosi e ben p...
# 154      F      Marina  Locale sobrio ma elegante, cura impeccabile da...
# 155      F       Sofia  Una fantastica esperienza vera una prima notte...
# 156      F     Barbara  . Buona posizione, molto ben posizionato e gla...
# 157      M        Tony  Ho ordinato il Top menù che era eccellente, in...
# 158      F      Tricia  Abbiamo cenato qui per pranzo oggi. Il servizi...
# 159      F       Jamie  Il cibo era fantastico, ottima atmosfera e ser...
# 160      F   Christine  Siamo stati qui in due occasioni, e siamo rima...
# 161      F       Manon  Essendo il numero 1 ristorante a Pescara erava...
#
#     Scritta da  Voti
# 0       Mobile     5
# 1       Mobile     5
# 2       Mobile     5
# 3       Mobile     5
# 4       Mobile     5
# 5       Mobile     5
# 6       Mobile     5
# 7           PC     3
# 8       Mobile     5
# 9       Mobile     5
# 10      Mobile     5
# 11      Mobile     5
# 12      Mobile     5
# 13          PC     5
# 14      Mobile     5
# 15          PC     5
# 16      Mobile     4
# 17          PC     3
# 18      Mobile     4
# 19      Mobile     5
# 20      Mobile     4
# 21      Mobile     5
# 22      Mobile     5
# 23      Mobile     5
# 24      Mobile     4
# 25      Mobile     5
# 26          PC     5
# 27      Mobile     5
# 28      Mobile     3
# 29      Mobile     4
# ..         ...   ...
# 132         PC     5
# 133     Mobile     5
# 134     Mobile     5
# 135         PC     5
# 136         PC     4
# 137     Mobile     5
# 138         PC     5
# 139         PC     5
# 140         PC     4
# 141         PC     5
# 142         PC     5
# 143         PC     4
# 144         PC     5
# 145         PC     4
# 146         PC     5
# 147         PC     5
# 148         PC     5
# 149         PC     5
# 150         PC     5
# 151         PC     5
# 152     Mobile     5
# 153         PC     5
# 154         PC     5
# 155     Mobile     5
# 156     Mobile     4
# 157         PC     4
# 158     Mobile     4
# 159     Mobile     5
# 160         PC     5
# 161     Mobile     5
#
# [162 rows x 5 columns]
