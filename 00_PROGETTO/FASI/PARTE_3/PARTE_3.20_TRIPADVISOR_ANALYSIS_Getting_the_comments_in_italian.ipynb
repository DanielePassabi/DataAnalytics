# %% [markdown]
# # Creo un nuovo dataset

# %% [markdown]
# ---
# ## Analisi dei commenti di un ristorante
#
# ### Sorbillo - Campania
#
# URL di riferimento: https://www.tripadvisor.it/Restaurant_Review-g187785-d1034513-Reviews-Sorbillo-Naples_Province_of_Naples_Campania.html
#
# Home --> Ristoranti --> Firenze --> Best_ranking--> SENZ_ALTRO_Bistrot

# %%
# IMPORT NECESSARI
import requests
from bs4 import BeautifulSoup

print("Imported")
# Out:
# Imported

# %%
page_URL = "https://www.tripadvisor.it/Restaurant_Review-g187785-d1034513-Reviews-Sorbillo-Naples_Province_of_Naples_Campania.html"

data = requests.get(page_URL)
clear_data = BeautifulSoup(data.content, "lxml")

print("Done")
# Out:
# Done

# %% [markdown]
# ---
# ### STRUTTURA HTML DEL SITO
#
# #### REVIEW
# `<p class="partial_entry"> qui c'è la review </p>`
#
# #### N° TOTALE DI REVIEWS
# `<a data-page-number="25" ...>
#     25
#  </a>`
#
# #### NAMES
# `<span class="expand_inline scrname" …>AlexandraCapeTown</span>`
#
# #### RATINGS
# `<span class="ui_bubble_rating bubble_30"></span>`

# %% [markdown]
# ---
# ### PRIMO SCRAPING (sulla prima pagina)
#
# Ottengo i nomi, i commenti, le review e da dove è stato scritto il commento per quanto rigurda la prima pagina. Ciò è necessario, in quanto, dalla seconda in poi l'URL cambia, permettendoci di iterare.

# %%
# OTTENGO UNA LISTA DI DIV CHE CONTENGONO NOME, RECENSIONE E VOTO

all_reviews = []
all_names = []
all_ratings = []
all_mobile = []

review_container = clear_data.findAll("div", attrs={"class":"review-container"})

for container in review_container:
  
    ### REVIEW ###
    review = container.find('p', attrs={'class': 'partial_entry'})
    if review:
        all_reviews.append(review.text)
        
    ### NAME ###
    name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
    if name:
      all_names.append(name.text)
    else:
      all_names.append('NO_NAME')
    
    ### RATING ###
    rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
    all_ratings.append(rating['class'][1][7:8])
    
    ### MOBILE ###
    mobile = container.find('span', attrs={'class': 'viaMobile'})
    if mobile:
      all_mobile.append('Mobile')
    else:
      all_mobile.append('PC')
    
    
################################################################################################################################
        
print("Executed")
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# Nomi:  10
# Commenti:  10
# Voti:  10
# Scritto da:  10

# %% [markdown]
# ### SECONDO SCRAPING (dalla seconda pagina in poi)
#
# Notiamo dall'URL che è possibile iterare sulle pagine, ottenendo i dati!

# %%
from tqdm import tqdm

URL_COMPLETO = 'https://www.tripadvisor.it/Restaurant_Review-g187785-d1034513-Reviews-or10-Sorbillo-Naples_Province_of_Naples_Campania.html'

URL_p1 = 'https://www.tripadvisor.it/Restaurant_Review-g187785-d1034513-Reviews-or'
URL_p2 = '0-Sorbillo-Naples_Province_of_Naples_Campania.html'
    
# OTTENGO I COMMENTI, NOMI E VOTI DALLA SECONDA PAGINA IN POI

total_pages = int(clear_data.select("a.pageNum.last.taLnk")[0].text) # 25 come intero

# per iterare dobbiamo partire dalla seconda pagina dei commenti, così nell'URL compaiono le cifre che ci servono
for r in tqdm(range(1,total_pages)):

    # OTTENGO L'URL DELLA PAGINA
    URL_temp = URL_p1 + str(r) + URL_p2

    # OTTENGO I DATI E CI APPLICO BEATIFULSOUP
    data = requests.get(URL_temp)
    clear_data = BeautifulSoup(data.content, "lxml")
    

    review_container = clear_data.findAll("div", attrs={"class":"review-container"})

    for container in review_container:
  
      ### REVIEW ###
      review = container.find('p', attrs={'class': 'partial_entry'})
      if review:
          all_reviews.append(review.text)

      ### NAME ###
      name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
      if name:
        all_names.append(name.text)
      else:
        all_names.append('NO_NAME')

      ### RATING ###
      rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
      all_ratings.append(rating['class'][1][7:8])

      ### MOBILE ###
      mobile = container.find('span', attrs={'class': 'viaMobile'})
      if mobile:
        all_mobile.append('Mobile')
      else:
        all_mobile.append('PC')
    
        
################################################################################################################################
        
print("Executed")
print('total_pages: ', total_pages)
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_mobile))
# Out:
# 100%|██████████| 1369/1369 [27:30<00:00,  1.37s/it]
# Executed
# total_pages:  1370
# Nomi:  13695
# Commenti:  13695
# Voti:  13695
# Scritto da:  13695

# %%
# display(all_reviews)

# %%
# print(all_names)

# %%
#print(all_ratings, '\n')
#print(len(all_ratings))

# %%
#display(all_mobile)

# %% [markdown]
# #### Problema recensioni troppo lunghe
# Alla fine di alcune recensioni troviamo un '...Più', che non possiamo espandere. Data la mole di dati, decidiamo dunque di non considerarle.

# %%
all_reviews_filtered = []
counter_reviews_scartate = 0;
counter_reviews_da_usare = 0;

for review in all_reviews:
    if '...Più' in review:
        all_reviews_filtered.append('RECENSIONE_TROPPO_LUNGA')
        counter_reviews_scartate+=1;
    else:
        all_reviews_filtered.append(review)
        counter_reviews_da_usare+=1;
        
        
print(
    'Totale recensioni:', counter_reviews_scartate + counter_reviews_da_usare, '\n',
    'Recensioni analizzabili:', counter_reviews_da_usare, '\n',
    'Recensioni scartate:', counter_reviews_scartate, '\n')

display(all_reviews_filtered[:10])
# Out:
# Totale recensioni: 13695
#  Recensioni analizzabili: 7672
#  Recensioni scartate: 6023
# ['da sobillo bisogna assolutamente andare almeno una volta nella vita. pizza fritta super, ma super super. buonissima. in questi giorni code infinite, ma ne valeva la pena. non fatevela scappare',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Semplicemente questa non è pizza. È LA pizza, mai privato qualcosa di simile prima d’ora! Peccato ci sia molto da attendere, ma ne vale assolutamente la pena',
#  "La fama di questo locale non è infondata... Pizza buonissima! L'attesa per entrare è inevitabile ma ne vale la pena. Personale cordialissimo.",
#  'Noi napoletani lo conosciamo Ora tocca a voi conoscerlo non potete farvi mancare la Pizzeria Sorbillo una vera pizza napoletana',
#  'RECENSIONE_TROPPO_LUNGA',
#  "Ingredienti di qualità ottima, cottura quasi perfetta e ambiente gradevole e accogliente per una pizza che ripaga generosamente dell'attesa. Da non perdere."]

# %% [markdown]
# ---
# ### Analisi dei nomi
# Cerchiamo di capire se chi ha commentato è un uomo (M) o una donna (F).

# %% [markdown]
# #### Elimino spazi e numeri
# Ho bisogno di tenere solo le informazioni riguardanti il nome, elimino il resto.

# %%
import re

all_names_filtered = []

regex = re.compile('[^a-zA-Z]')

for name in all_names:
    
    if ' ' in name:                           # se c'è uno spazio nel nome
        space = name.index(' ')               # ne trovo l'indice
        name = regex.sub('', name[:space])    # effettuo un controllo su tutto ciò che non è alfabeto fino a quell'indice
        all_names_filtered.append(name)       # e aggiungo la stringa
        
    else:
        name = regex.sub('', name)            # in caso contrario effettuo un controllo su tutto ciò che non è alfabeto
        all_names_filtered.append(name)       # e aggiungo la stringa
        
print(all_names, '\n')
print(all_names_filtered)
# Out:
# ['luigina b', 'gionnibi', 'Alessandro T', 'Lorenzo F', '642raffaellap', 'genn_rogue', 'AncillaM3', 'Tullio F', 'Porcocane', 'babo62', 'Ivanadellasenna', 'eddibat', 'Niccolo76', 'Grigionero', 'ivanab302', 'perserosi', 'fabiovassallo', 'Cris260507', 'deboraf75', 'FrancescoM227', 'Simonavp', 'gianbartolo c', 'gmasini2014', '839gabriellaa', 'pinof316', 'zanba', 'pettorruso', 'yoettore', 'superstani', 'steydel', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Loryiole2018', 'T7507VNpaoloc', 'albertomorrone', 'domenicof768', 'Meander573064', 'AnnettePav', 'rick-bosk', '923beatricem', 'marcou376', 'rosa m', 'Elena M', 'luciaritanu', 'danielaronza', 'fulvio1947', 'leonildaf633', 'alls2019', 'marilenam732', 'lareginarosssa', 'papoz64', 'ELRONCA', 'angelagW9763VU', 'GIOVANNI p', 'davidesmile', 'Anna M', 'Arianna M', 'mariannao750', 'SabinaHet', 'giorgiab593', 'EmanueleModenato', 'chilli81', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'silvialat72', 'pinopacelli', 'AntonioTrombetta', 'ferdinandoo709', '696PaoloR', 'sergiosu88', 'Marco P', 'carocicca', 'caio1046', 'Maria Antoniett... F', 'Oreste S', 'Giubbattisti', 'gemellina75', 'Global713815', 'travelgiuseppe', '11andreanac', 'Marco P', 'LeoG2305', 'Debora T', 'Mary_Ricc', 'EllyA530', 'gfil', 'Imol72', 'gianniRNAP', 'Matteo A', 'Saralorikyra', 'lucabD5288PI', 'VaMaBaCa', 'caraibica', 'E6253QGelenab', 'cirop984', '894asiat', 'MarcelloN90', 'Ottagonstefan', '888francescad', 'Nicolò Claudio ... C', 'caogenny', 'Tiffany9117', 'MimmoA83', 'ester_morgia', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'azzurrina69', 'Giorgia R', 'BiagioC993', 'GoPlaces664641', 'grays24', 'Giovanni S', 'Mattiabo95', 'Giacy93', 'Salvatore P', 'MimmiNinne', 'aletraveller', 'B456USsilviav', '0307lella', 'antoniomB1416GN', 'mikelaelina', 'carlopI6319GR', 'Mastinoss', 'caterina l', 'koko092', 'Ridipagliaccio', 'chiaracit', 'danielasE1740OQ', 'leonardobW5779AU', 'paola t', 'Lodiceali', 'SilviaS3887', '19690111', 'tramsal', 'Paolo E Aurora M', 'dasiur', 'paoloabbate23', 'Ele1980the', 'Dori B', 'roberto s', 'queenbey88', 'Marctiell89', 'NotoChef', 'sailormax2016', 'lions719026', 'vampires77', '1972_andrea', '733paolar', 'agincourts', 'qwertyroby', 'MariaCoppola70', 'Ciacco94', 'apiciogoloso', '57Massimiliano', 'claudiadL757LX', 'GiulianoBizioli', 'Monica C', 'Lucy F', 'dgd83', 'mtilli', 'Nola N', 'lorena m', 'Antonella G', 'Tonyucci', 'saveriou2016', 'Matteo M', 'chiarafes', 'frusciodifoglie', 'aleeeeexia', 'umbertom865', 'Banktraveler', 'Maverick772013', 'm0qc', 'EnzoR87', 'Paolo P', 'Alesgue', 'Doctoraid', 'Valina_9217', 'AntonioNa82', 'titti_ferdi2018', 'MaxColognesi', 'morganella1709', 'ewaoff', 'MattiaL1703', 'matteoperroni', 'Concetta C', 'gcasero53', 'Eleonora C', 'Lorenzo_lan', 'Pinklily3', 'akakus2000', 'Daniela M', '238ilariam', 'luciot9', 'Silvia9494', 'giovannilV6123TH', 'chiaragrizzu', 'Alesssandrina', 'FranciSara', 'Primaprova2020', '202salvatoref', 'nodosenoatriale', 'deatk', 'cataldol233', 'danielaY4016MS', 'pio958', 'securlav', 'estherattems', 'carmelaperone1969', '521manny_a', 'leda p', 'pezzolisergio', 'Dream36347491365', 'N9465MFsabrinab', 'poerodoc', 'MicheleWids', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Marilena C', 'forzatore1', 'Rita R', 'DimitriR890', 'carminei841', 'Brigze', 'gaiettta10', 'claudia24salenti', 'menzulli', 'Antonio R', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Covelli', 'Sara_Veneziano', 'ciro t', 'FrancescoS765', 'Tonino R', 'sellygherardi', 'BallaConLeMarmotte', 'mmdiana', 'enzod249', 'L2925LOrosab', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Francesca M', 'Riccardo B', 'Morhg', 'B389 ...
#
# ['luigina', 'gionnibi', 'Alessandro', 'Lorenzo', 'raffaellap', 'gennrogue', 'AncillaM', 'Tullio', 'Porcocane', 'babo', 'Ivanadellasenna', 'eddibat', 'Niccolo', 'Grigionero', 'ivanab', 'perserosi', 'fabiovassallo', 'Cris', 'deboraf', 'FrancescoM', 'Simonavp', 'gianbartolo', 'gmasini', 'gabriellaa', 'pinof', 'zanba', 'pettorruso', 'yoettore', 'superstani', 'steydel', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Loryiole', 'TVNpaoloc', 'albertomorrone', 'domenicof', 'Meander', 'AnnettePav', 'rickbosk', 'beatricem', 'marcou', 'rosa', 'Elena', 'luciaritanu', 'danielaronza', 'fulvio', 'leonildaf', 'alls', 'marilenam', 'lareginarosssa', 'papoz', 'ELRONCA', 'angelagWVU', 'GIOVANNI', 'davidesmile', 'Anna', 'Arianna', 'mariannao', 'SabinaHet', 'giorgiab', 'EmanueleModenato', 'chilli', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'silvialat', 'pinopacelli', 'AntonioTrombetta', 'ferdinandoo', 'PaoloR', 'sergiosu', 'Marco', 'carocicca', 'caio', 'Maria', 'Oreste', 'Giubbattisti', 'gemellina', 'Global', 'travelgiuseppe', 'andreanac', 'Marco', 'LeoG', 'Debora', 'MaryRicc', 'EllyA', 'gfil', 'Imol', 'gianniRNAP', 'Matteo', 'Saralorikyra', 'lucabDPI', 'VaMaBaCa', 'caraibica', 'EQGelenab', 'cirop', 'asiat', 'MarcelloN', 'Ottagonstefan', 'francescad', 'Nicol', 'caogenny', 'Tiffany', 'MimmoA', 'estermorgia', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'azzurrina', 'Giorgia', 'BiagioC', 'GoPlaces', 'grays', 'Giovanni', 'Mattiabo', 'Giacy', 'Salvatore', 'MimmiNinne', 'aletraveller', 'BUSsilviav', 'lella', 'antoniomBGN', 'mikelaelina', 'carlopIGR', 'Mastinoss', 'caterina', 'koko', 'Ridipagliaccio', 'chiaracit', 'danielasEOQ', 'leonardobWAU', 'paola', 'Lodiceali', 'SilviaS', '', 'tramsal', 'Paolo', 'dasiur', 'paoloabbate', 'Elethe', 'Dori', 'roberto', 'queenbey', 'Marctiell', 'NotoChef', 'sailormax', 'lions', 'vampires', 'andrea', 'paolar', 'agincourts', 'qwertyroby', 'MariaCoppola', 'Ciacco', 'apiciogoloso', 'Massimiliano', 'claudiadLLX', 'GiulianoBizioli', 'Monica', 'Lucy', 'dgd', 'mtilli', 'Nola', 'lorena', 'Antonella', 'Tonyucci', 'saveriou', 'Matteo', 'chiarafes', 'frusciodifoglie', 'aleeeeexia', 'umbertom', 'Banktraveler', 'Maverick', 'mqc', 'EnzoR', 'Paolo', 'Alesgue', 'Doctoraid', 'Valina', 'AntonioNa', 'tittiferdi', 'MaxColognesi', 'morganella', 'ewaoff', 'MattiaL', 'matteoperroni', 'Concetta', 'gcasero', 'Eleonora', 'Lorenzolan', 'Pinklily', 'akakus', 'Daniela', 'ilariam', 'luciot', 'Silvia', 'giovannilVTH', 'chiaragrizzu', 'Alesssandrina', 'FranciSara', 'Primaprova', 'salvatoref', 'nodosenoatriale', 'deatk', 'cataldol', 'danielaYMS', 'pio', 'securlav', 'estherattems', 'carmelaperone', 'mannya', 'leda', 'pezzolisergio', 'Dream', 'NMFsabrinab', 'poerodoc', 'MicheleWids', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Marilena', 'forzatore', 'Rita', 'DimitriR', 'carminei', 'Brigze', 'gaiettta', 'claudiasalenti', 'menzulli', 'Antonio', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Covelli', 'SaraVeneziano', 'ciro', 'FrancescoS', 'Tonino', 'sellygherardi', 'BallaConLeMarmotte', 'mmdiana', 'enzod', 'LLOrosab', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Francesca', 'Riccardo', 'Morhg', 'BRJfabiob', 'kayscarpetta', 'mario', 'dacrima', 'GennaroTravel', 'Tomas', 'agori', 'filomenap', 'gaetanoraiti', 'ari', 'paolas', 'FrancescoSavP', 'fs', 'simonem', 'RosariaN', 'lisav', 'aciccolo', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Ivano', 'FRANCESCA', 'frafio', 'EnricoVeronica', 'elisasSPN', 'Giulio', 'Pietro', 'carlottab', 'Claudia', 'marieholms', 'Cinzia', 'theicemer', 'marti', 'FedericoAround', 'fileo', 'ilene', 'DayTrip', 'psimmy', 'Manbeli', 'Mariata', 'NONAME', 'NONAM ...

# %% [markdown]
# #### Utilizzo gender_guesser
# Infine, posso utilizzare la libreria gender_guesser.
#
# NB: Genderize ti permette di analizzare 1000 nomi al giorno.

# %%
# !pip install gender_guesser
# Out:
# Collecting gender_guesser
#   Downloading https://files.pythonhosted.org/packages/13/fb/3f2aac40cd2421e164cab1668e0ca10685fcf896bd6b3671088f8aab356e/gender_guesser-0.4.0-py2.py3-none-any.whl (379kB)
#     100% |████████████████████████████████| 389kB 21.9MB/s
# Installing collected packages: gender-guesser
# Successfully installed gender-guesser-0.4.0

# %%
import gender_guesser.detector as gender
d = gender.Detector()

names_with_gender = []

for name in all_names_filtered:
    temp_gender = d.get_gender(name)
    names_with_gender.append(temp_gender)
  
print(names_with_gender)
# Out:
# ['unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'un ...

# %%
all_genders = []
i = 0

for guess in names_with_gender:
    if guess == 'male' or guess == 'mostly_male':
        all_genders.append('M')
    elif guess == 'female' or guess == 'mostly_female':
        all_genders.append('F')
    else:
        all_genders.append('UNKNOWN')

    
print(all_genders)
# Out:
# ['UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN',  ...

# %% [markdown]
# ---
# ## Salviamo ora i dati ottenuti in una tabella Excel
# Così non dovremo ogni volta rieseguire tutto il codice

# %% [markdown]
# ### Controlliamo che ci siano lo stesso numero di dati
# Potremo così creare una tabella sfruttando Pandas

# %%
print('Nomi: ', len(all_names_filtered))
print('Commenti: ', len(all_reviews_filtered))
print('Voti: ', len(all_ratings))
print('Mobile: ', len(all_mobile))
# Out:
# Nomi:  13695
# Commenti:  13695
# Voti:  13695
# Mobile:  13695

# %% [markdown]
# ### Eliminiamo le recensioni troppo lunghe e quelle di cui non sappiamo il genere del commentatore
# Creo una lista di liste [ ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ... ]

# %%
complete_list = []

i = len(all_names_filtered)

for indice in range(i):
  if all_genders[indice] != 'UNKNOWN' and all_reviews_filtered[indice] != 'RECENSIONE_TROPPO_LUNGA':
    temp = [all_names_filtered[indice], all_genders[indice], all_reviews_filtered[indice], all_ratings[indice], all_mobile[indice]]
    complete_list.append(temp)
    
print('DATI ANALIZZABILI: ', len(complete_list))
display(complete_list[:5])
# Out:
# DATI ANALIZZABILI:  1772
# [['Tullio',
#   'M',
#   'Noi napoletani lo conosciamo Ora tocca a voi conoscerlo non potete farvi mancare la Pizzeria Sorbillo una vera pizza napoletana',
#   '5',
#   'Mobile'],
#  ['Oreste',
#   'M',
#   'una buona pizza. porta la napoletanità ed il prodotto in giro per il mondo. fa piacere essere apprezzati per un prodotto di eccellenza.',
#   '5',
#   'PC'],
#  ['Salvatore',
#   'M',
#   'Sono stato oggi in questa pizzeria dove in passato avevo sempre mangiato pizze stupende.Non so cosa sia successo negli ultimi mese ma di certo oggi ho mangiato una delle peggiori pizze della mia vita.',
#   '2',
#   'PC'],
#  ['Paolo',
#   'M',
#   'Appena arrivati a Napoli la prima tappa è stata la pizza fritta! Paese che vai street food che trovi!',
#   '5',
#   'Mobile'],
#  ['Dori',
#   'F',
#   "Sono stata oggi a pranzo e ho mangiato una buona pizza napoletana. Abbiamo fatto un po' di fila per entrare ma quando si entra il servizio è super veloce. Complimenti",
#   '5',
#   'PC']]

# %% [markdown]
# ### Creiamo la tabella

# %%
# !pip install pandas
# !pip install xlsxwriter
import pandas as pd
# Out:
# Collecting xlsxwriter
#   Downloading https://files.pythonhosted.org/packages/3d/1b/4caecd4efde1d41ba3bef1a81027032a7a6dff7d5112e1731f232c0addb9/XlsxWriter-1.1.2-py2.py3-none-any.whl (142kB)
#     100% |████████████████████████████████| 143kB 9.7MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-1.1.2

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame({'Nomi': [elemento[0] for elemento in complete_list], 
                   'Genere': [elemento[1] for elemento in complete_list], 
                   'Recensioni': [elemento[2] for elemento in complete_list],
                   'Voti': [elemento[3] for elemento in complete_list],
                   'Scritta da': [elemento[4] for elemento in complete_list]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RISTORANTE_20.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
partial_dataframe = pd.read_excel("RISTORANTE_20.xlsx")

display(partial_dataframe)
# Out:
#      Genere         Nomi                                         Recensioni  \
# 0         M       Tullio  Noi napoletani lo conosciamo Ora tocca a voi c...
# 1         M       Oreste  una buona pizza. porta la napoletanità ed il p...
# 2         M    Salvatore  Sono stato oggi in questa pizzeria dove in pas...
# 3         M        Paolo  Appena arrivati a Napoli la prima tappa è stat...
# 4         F         Dori  Sono stata oggi a pranzo e ho mangiato una buo...
# 5         F       Monica  Poesia pura....e a prezzo ottimo....la vera es...
# 6         F         Lucy  Pizza all'altezza delle aspettative!ottima. Gi...
# 7         F         Nola  Fantastico, un mito.\nLa fila per entrare ha v...
# 8         F    Antonella  Sorbillo un nome una garanzia per me una delle...
# 9         M     Maverick  Un po’ di coda per entrare ma ne è valsa assol...
# 10        F     Concetta  X oltre 100 volte mi sono recata presso questo...
# 11        F     Eleonora  Servizio ottimo, camerieri simpatici, locale c...
# 12        F     Marilena  Ottima pizza! Nonostante l'attesa interminabil...
# 13        F         Rita  Non si può descrivere la bontà di questa pizza...
# 14        M      Antonio  Immerso nel cuore della tipica napoli un local...
# 15        M       Tonino  Non c'è nulla da dire. Pizza all'altezza della...
# 16        F    Francesca  Famiglia storica e locale tipico . Pizza napol...
# 17        M        Ivano  Una pizza ottima, tanta coda. La fama precede ...
# 18        M       Pietro  Molto buona, servizio di asporto veloce nonost...
# 19        F       Cinzia  La pizza è veramente fantastica..le aspettativ...
# 20        F      Daniela  La pizza era veramente buona, ma la cosa che c...
# 21        M     Pasquale  Ci siamo avventurati nella coda per entrare in...
# 22        M       Jacopo  Secondo il mio punto di vista e secondo i miei...
# 23        F       Giulia  Si sta na favola,si mangia da dio, posto calor...
# 24        M     Giuseppe  Passeggiando per la zona dei tribunali incontr...
# 25        F     Federica  La pizza degna di essere chiamata pizza.....de...
# 26        M       Gianni  Non posso dire che abbia mangiato una brutta p...
# 27        F   Elisabetta  Antipasti ottimi..i primi piatti di ottima qua...
# 28        M   Alessandro  Incuriosito di provare la vera pizza napoletan...
# 29        M     Vittorio  Locale molto carino nel centro storico di napo...
# ...     ...          ...                                                ...
# 1742      F     Caroline  Ogni napoletano vi dirà che è la migliore pizz...
# 1743      M      Michael  E' un posto di Pizza che ha sempre una linea d...
# 1744      M       Eliseo  Sì, questo è il posto dove si deve andare a ma...
# 1745      F        Danna  Una delle migliori pizze che abbia mai mangiat...
# 1746      M      Michael  Pizza media a mio parere. Io e mia moglie abbi...
# 1747      F      Melanie  Il posto era jumping, le pizze leggermente fis...
# 1748      M          Tim  Sorbillo pizza è un ottimo rapporto qualità-pr...
# 1749      M  Christopher  Era proprio quello di cui avevamo bisogno per ...
# 1750      M      Placido  Esperienza tipica pizza napoletana! Non ho amo...
# 1751      F    Elizabeth  A piedi attraversando napoli ci abbiamo visto ...
# 1752      M       Ronnie  Ero lì a 12 o'clock di apertura sul puntino! N...
# 1753      M     Benjamin  Questo non deve essere confuso con il ristoran...
# 1754      M       Philip  Io e la mia nuova moglie aveva deciso per un v...
# 1755      M         Mike  Siamo arrivati presto dopo una raccomandazione...
# 1756      M       Andrew  Una delle migliori pizze che abbia mai mangiat...
# 1757      M        David  Quello che avevamo una deliziosa pizza! E così...
# 1758      M         Gary  Abbiamo aspettato un'ora per arrivare in, ma l...
# 1759      M       George  Gino Sorbillo un padrone di casa perfetto ! E ...
# 1760      F        Helen  La pizza migliore che abbia mai mangiato. Gorg...
# 1761      F    Elizabeth  In aggiunta al margarita standard, abbiamo chi...
# 1762      M          Tim  È aperto per il pranzo e la cena. Se è la cena...
# 1763      M      Ghassan  Ci siamo stati la scorsa estate e la loro pizz...
# 1764      F        Kathy  Avevamo avuto un buon drink presso il bar loca...
# 1765      M         Alex  Servizio veloce, prezzi buoni e pizza di deliz...
# 1766      F         Ella  Yum! Mi piace la pizza, e abbiamo mangiato una...
# 1767      M       Morgan  Dopo le raccomandazioni suscitato di internet,...
# 1768      F         Jenn  È difficile trovare una pizza pessima a Napoli...
# 1769      F     Stefania  Ottima pizza, tante varietà - tutto ottimo. Ab...
# 1770      M      Michael  È possibile raggiungere facilmente anche dire ...
# 1771      M         Dave  Top Pizza, rilassato stile. Vino rosso bella. ...
#
#      Scritta da  Voti
# 0        Mobile     5
# 1            PC     5
# 2            PC     2
# 3        Mobile     5
# 4            PC     5
# 5        Mobile     5
# 6        Mobile     5
# 7        Mobile     5
# 8        Mobile     5
# 9        Mobile     5
# 10           PC     5
# 11       Mobile     5
# 12       Mobile     5
# 13       Mobile     5
# 14           PC     5
# 15       Mobile     5
# 16       Mobile     4
# 17       Mobile     5
# 18       Mobile     5
# 19       Mobile     5
# 20           PC     5
# 21       Mobile     3
# 22       Mobile     5
# 23       Mobile     5
# 24           PC     5
# 25       Mobile     5
# 26       Mobile     3
# 27       Mobile     4
# 28       Mobile     4
# 29       Mobile     5
# ...         ...   ...
# 1742         PC     5
# 1743         PC     4
# 1744         PC     5
# 1745         PC     5
# 1746     Mobile     2
# 1747         PC     4
# 1748     Mobile     4
# 1749         PC     5
# 1750         PC     5
# 1751         PC     4
# 1752         PC     3
# 1753         PC     5
# 1754         PC     1
# 1755         PC     5
# 1756         PC     5
# 1757         PC     5
# 1758         PC     5
# 1759         PC     4
# 1760         PC     5
# 1761         PC     5
# 1762         PC     5
# 1763         PC     5
# 1764         PC     3
# 1765         PC     5
# 1766         PC     5
# 1767         PC     4
# 1768         PC     5
# 1769         PC     5
# 1770         PC     3
# 1771         PC     4
#
# [1772 rows x 5 columns]
