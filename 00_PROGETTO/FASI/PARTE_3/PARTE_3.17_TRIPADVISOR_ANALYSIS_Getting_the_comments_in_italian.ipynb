# %% [markdown]
# # Creo un nuovo dataset

# %% [markdown]
# ---
# ## Analisi dei commenti di un ristorante
#
# ### Madre - Lazio
#
# URL di riferimento: https://www.tripadvisor.it/Restaurant_Review-g187791-d10598456-Reviews-Madre-Rome_Lazio.html
#
# Home --> Ristoranti --> Firenze --> Best_ranking--> SENZ_ALTRO_Bistrot

# %%
# IMPORT NECESSARI
import requests
from bs4 import BeautifulSoup

print("Imported")
# Out:
# Imported

# %%
page_URL = "https://www.tripadvisor.it/Restaurant_Review-g187791-d10598456-Reviews-Madre-Rome_Lazio.html"

data = requests.get(page_URL)
clear_data = BeautifulSoup(data.content, "lxml")

print("Done")
# Out:
# Done

# %% [markdown]
# ---
# ### STRUTTURA HTML DEL SITO
#
# #### REVIEW
# `<p class="partial_entry"> qui c'è la review </p>`
#
# #### N° TOTALE DI REVIEWS
# `<a data-page-number="25" ...>
#     25
#  </a>`
#
# #### NAMES
# `<span class="expand_inline scrname" …>AlexandraCapeTown</span>`
#
# #### RATINGS
# `<span class="ui_bubble_rating bubble_30"></span>`

# %% [markdown]
# ---
# ### PRIMO SCRAPING (sulla prima pagina)
#
# Ottengo i nomi, i commenti, le review e da dove è stato scritto il commento per quanto rigurda la prima pagina. Ciò è necessario, in quanto, dalla seconda in poi l'URL cambia, permettendoci di iterare.

# %%
# OTTENGO UNA LISTA DI DIV CHE CONTENGONO NOME, RECENSIONE E VOTO

all_reviews = []
all_names = []
all_ratings = []
all_mobile = []

review_container = clear_data.findAll("div", attrs={"class":"review-container"})

for container in review_container:
  
    ### REVIEW ###
    review = container.find('p', attrs={'class': 'partial_entry'})
    if review:
        all_reviews.append(review.text)
        
    ### NAME ###
    name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
    if name:
      all_names.append(name.text)
    else:
      all_names.append('NO_NAME')
    
    ### RATING ###
    rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
    all_ratings.append(rating['class'][1][7:8])
    
    ### MOBILE ###
    mobile = container.find('span', attrs={'class': 'viaMobile'})
    if mobile:
      all_mobile.append('Mobile')
    else:
      all_mobile.append('PC')
    
    
################################################################################################################################
        
print("Executed")
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# Nomi:  10
# Commenti:  10
# Voti:  10
# Scritto da:  10

# %% [markdown]
# ### SECONDO SCRAPING (dalla seconda pagina in poi)
#
# Notiamo dall'URL che è possibile iterare sulle pagine, ottenendo i dati!

# %%
from tqdm import tqdm

URL_COMPLETO = 'https://www.tripadvisor.it/Restaurant_Review-g187791-d10598456-Reviews-or10-Madre-Rome_Lazio.html'

URL_p1 = 'https://www.tripadvisor.it/Restaurant_Review-g187791-d10598456-Reviews-or'
URL_p2 = '0-Madre-Rome_Lazio.html'
    
# OTTENGO I COMMENTI, NOMI E VOTI DALLA SECONDA PAGINA IN POI

total_pages = int(clear_data.select("a.pageNum.last.taLnk")[0].text) # 25 come intero

# per iterare dobbiamo partire dalla seconda pagina dei commenti, così nell'URL compaiono le cifre che ci servono
for r in tqdm(range(1,total_pages)):

    # OTTENGO L'URL DELLA PAGINA
    URL_temp = URL_p1 + str(r) + URL_p2

    # OTTENGO I DATI E CI APPLICO BEATIFULSOUP
    data = requests.get(URL_temp)
    clear_data = BeautifulSoup(data.content, "lxml")
    

    review_container = clear_data.findAll("div", attrs={"class":"review-container"})

    for container in review_container:
  
      ### REVIEW ###
      review = container.find('p', attrs={'class': 'partial_entry'})
      if review:
          all_reviews.append(review.text)

      ### NAME ###
      name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
      if name:
        all_names.append(name.text)
      else:
        all_names.append('NO_NAME')

      ### RATING ###
      rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
      all_ratings.append(rating['class'][1][7:8])

      ### MOBILE ###
      mobile = container.find('span', attrs={'class': 'viaMobile'})
      if mobile:
        all_mobile.append('Mobile')
      else:
        all_mobile.append('PC')
    
        
################################################################################################################################
        
print("Executed")
print('total_pages: ', total_pages)
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_mobile))
# Out:
# 100%|██████████| 65/65 [01:27<00:00,  1.29s/it]
# Executed
# total_pages:  66
# Nomi:  656
# Commenti:  656
# Voti:  656
# Scritto da:  656

# %%
# display(all_reviews)

# %%
# print(all_names)

# %%
#print(all_ratings, '\n')
#print(len(all_ratings))

# %%
#display(all_mobile)

# %% [markdown]
# #### Problema recensioni troppo lunghe
# Alla fine di alcune recensioni troviamo un '...Più', che non possiamo espandere. Data la mole di dati, decidiamo dunque di non considerarle.

# %%
all_reviews_filtered = []
counter_reviews_scartate = 0;
counter_reviews_da_usare = 0;

for review in all_reviews:
    if '...Più' in review:
        all_reviews_filtered.append('RECENSIONE_TROPPO_LUNGA')
        counter_reviews_scartate+=1;
    else:
        all_reviews_filtered.append(review)
        counter_reviews_da_usare+=1;
        
        
print(
    'Totale recensioni:', counter_reviews_scartate + counter_reviews_da_usare, '\n',
    'Recensioni analizzabili:', counter_reviews_da_usare, '\n',
    'Recensioni scartate:', counter_reviews_scartate, '\n')

display(all_reviews_filtered[:10])
# Out:
# Totale recensioni: 656
#  Recensioni analizzabili: 232
#  Recensioni scartate: 424
# ['Location ok molto particolare ma per il resto niente di che ..la pizza forse buona ma non buonissima ..per quello che si spende non ne vale la pena .',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Location molto bella e curata nel centro storico di Roma.\nSono stata in questo posto con amici a pranzo, per cui il locale non era affollato.\nPersonale molto attento e disponibile.\nCibo buono.\nPrezzi non eccessivi.',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Visitato una volta e ritornato: volte si a volte no, qualcosa si qualcosa no. Conto superiore a quanto ci aspettavamo.',
#  'RECENSIONE_TROPPO_LUNGA']

# %% [markdown]
# ---
# ### Analisi dei nomi
# Cerchiamo di capire se chi ha commentato è un uomo (M) o una donna (F).

# %% [markdown]
# #### Elimino spazi e numeri
# Ho bisogno di tenere solo le informazioni riguardanti il nome, elimino il resto.

# %%
import re

all_names_filtered = []

regex = re.compile('[^a-zA-Z]')

for name in all_names:
    
    if ' ' in name:                           # se c'è uno spazio nel nome
        space = name.index(' ')               # ne trovo l'indice
        name = regex.sub('', name[:space])    # effettuo un controllo su tutto ciò che non è alfabeto fino a quell'indice
        all_names_filtered.append(name)       # e aggiungo la stringa
        
    else:
        name = regex.sub('', name)            # in caso contrario effettuo un controllo su tutto ciò che non è alfabeto
        all_names_filtered.append(name)       # e aggiungo la stringa
        
print(all_names, '\n')
print(all_names_filtered)
# Out:
# ['Flyer739413', 'LAURA D', 'rominak785', 'O4700KIlorenzos', 'ESMERALDA28', 'PaoloRiccardoCarrara', 'my_little_snail', 'Peppe F', 'corrado51lecce', 'Sightseer71500', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'ilariam789', 'Giuliana1968', 'Martina1294', 'Michela P', 'Aenne76', 'SwaMI89', 'Manugiorgia', 'catia l', 'merenderocarl', 'Patrizia S', 'Roam770587', 'O3599ZKsaram', 'Carloalvise', 'DeCichis', 'corrado51lecce', 'J1144ZBrobertoc', 'andreatM8525KM', 'gionniv445', '583biagioc', 'W9057CZrobertob', 'emaloli94', 'DoraEmanuele', 'D3537XGclaudiac', 'MartyeFra', 'luca2013', 'filippa83', 'E7353VMsarac', 'priscilla_collacchi', 'Andrea196666', 'cnssra', 'erduce', 'Francesco S', 'Barbara D', 'DanielePascale_922', 'RobertoR67', 'newrita', 'Lucia Q', 'lauragb52', 'Mauro F', 'misscappy11', 'federicospruz', 'LiviaA90', 'P8329KEriccardos', 'prl7', 'ipzs91', 'fradalessa', 'Z9008IHbarbarac', 'Lanfranco R', 'cocchic', '708edoardom', 'carminegatti90', 'coccinella38', 'ornitorinco76', '576beatricea', 'carli0s', 'Mrk_Twa', 'FraGianca75', '123giusepped', 'antonio_de_pascali', 'cmenna85', 'cazannella', 'Silia F', 'Speranza C', 'frankpE8488XB', '743lucreziav', 'Samuele D', 'Sbandi71', 'marcodS9455UK', 'axelrome', 'alessiaizzo20', 'Daydream785754', 'Elena S', 'Alessia T', 'mytinypaw', 'Micky T', 'genys', 'Valentina S', 'Eusebio B', 'nickoff365', 'tripselector_F', 'massimo d', 'GiadaCcc', 'Lea_photo01', 'savoiardi77', 'berenice472', 'LaPry81', 'CarloM515', 'emilianofranci', 'turbotanzo', 'Die876', 'Coimbra B', 'mattiafosti', 'matteopE6137VR', 'torello80', 'riccardos846', 'lawyer1971', 'Iamroccopuopolo', 'Antonella L', 'Itaheart70', 'Fruscy', 'Viviviviviviviv', 'Solee233', 'VDM78', 'Anna B', 'Francesca M', 'ZAc f', 'francescablo', 'niente_moine', 'Cirocchia', 'Carlotta C', 'eliacca', 'alepersichetti', 'GstarRoma', 'Roberto I', 'ANREBECC', 'Elisabetta F', 'marcomarchetti1976', 'Piera A', 'Tiziana T', 'sanoegoista', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Raffaella C', 'FalabellaParis', 'Gattoreste', 'Brambi59', 'TMassimo', 'loryN76', 'Giovanni R', 'paolagiack', '324danilac', 'giocarmic2016', 'manuelsJ9904RU', 'TinaGix', '346gianlucap', 'Giulio O', 'Ilaria P', 'massimog241', 'federica1906', 'argio65', 'Pennnny', 'GstarRoma', 'saratag84', 'flazzo88', '542michelac', 'Donato-45', 'debbyjack', 'GiulioT1973', 'gliaffamati333', 'danielefrosinone', 'Connector748860', 'gratf', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'ElenaZiveri', 'PepitoRoma', '836CG', 'Anna Diandra S', 'NicSBK', '223giuliaf', 'Backstage2013', 'Chiara R', 'Lucio P', 'Cibospeciale', 'Amichedelbar', 'massimiliano l', 'lulliramacci', 'MartaVu', 'barbarasR7731RC', 'Cleo0513', 'gamberoro', 'A8756OQalicec', 'SusannaM44', 'sara c', 'Damichella', 'GiorgioRoby', 'Chiara D', 'Ginevra G', '533darias', '23fe', 'lostrys', 'Marco A', 'JforJopelandic', 'AdeleP158', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Mirella Z', 'ferdinandom115', '485SabinaM', 'eleonorarossi', 'IlGamberoGrasso', 'liciabinda', 'PippangaReal', 'francesco f', 'Mafalda16021970', 'Tannaztm', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Bobione', 'Giuli-all', 'Gattomattacchione', 'emanuelebike73', 'Gia1976', 'Barbara D', 'marco f', 'Federico B', 'IvanP869', 'gladius68', 'francescodd93', 'serater', 'Domenico L', 'jonathanp911', 'Loreno C', 'LucamarcelloR', 'Claudio S', 'Gippigi', 'MJordano', 'Lepaole', 'Di M', 'MARIANGELA F', 'Sara F', 'Andipa', 'ElaLaLei', 'carmain69', 'serelichi', 'dudu1956', 'travel8080', 'Toniapa', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Randomind', 'marcellos712', 'Fabiobsl', 'criandfra', 'Elena R', 'Eleonorarctl', ...
#
# ['Flyer', 'LAURA', 'rominak', 'OKIlorenzos', 'ESMERALDA', 'PaoloRiccardoCarrara', 'mylittlesnail', 'Peppe', 'corradolecce', 'Sightseer', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'ilariam', 'Giuliana', 'Martina', 'Michela', 'Aenne', 'SwaMI', 'Manugiorgia', 'catia', 'merenderocarl', 'Patrizia', 'Roam', 'OZKsaram', 'Carloalvise', 'DeCichis', 'corradolecce', 'JZBrobertoc', 'andreatMKM', 'gionniv', 'biagioc', 'WCZrobertob', 'emaloli', 'DoraEmanuele', 'DXGclaudiac', 'MartyeFra', 'luca', 'filippa', 'EVMsarac', 'priscillacollacchi', 'Andrea', 'cnssra', 'erduce', 'Francesco', 'Barbara', 'DanielePascale', 'RobertoR', 'newrita', 'Lucia', 'lauragb', 'Mauro', 'misscappy', 'federicospruz', 'LiviaA', 'PKEriccardos', 'prl', 'ipzs', 'fradalessa', 'ZIHbarbarac', 'Lanfranco', 'cocchic', 'edoardom', 'carminegatti', 'coccinella', 'ornitorinco', 'beatricea', 'carlis', 'MrkTwa', 'FraGianca', 'giusepped', 'antoniodepascali', 'cmenna', 'cazannella', 'Silia', 'Speranza', 'frankpEXB', 'lucreziav', 'Samuele', 'Sbandi', 'marcodSUK', 'axelrome', 'alessiaizzo', 'Daydream', 'Elena', 'Alessia', 'mytinypaw', 'Micky', 'genys', 'Valentina', 'Eusebio', 'nickoff', 'tripselectorF', 'massimo', 'GiadaCcc', 'Leaphoto', 'savoiardi', 'berenice', 'LaPry', 'CarloM', 'emilianofranci', 'turbotanzo', 'Die', 'Coimbra', 'mattiafosti', 'matteopEVR', 'torello', 'riccardos', 'lawyer', 'Iamroccopuopolo', 'Antonella', 'Itaheart', 'Fruscy', 'Viviviviviviviv', 'Solee', 'VDM', 'Anna', 'Francesca', 'ZAc', 'francescablo', 'nientemoine', 'Cirocchia', 'Carlotta', 'eliacca', 'alepersichetti', 'GstarRoma', 'Roberto', 'ANREBECC', 'Elisabetta', 'marcomarchetti', 'Piera', 'Tiziana', 'sanoegoista', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Raffaella', 'FalabellaParis', 'Gattoreste', 'Brambi', 'TMassimo', 'loryN', 'Giovanni', 'paolagiack', 'danilac', 'giocarmic', 'manuelsJRU', 'TinaGix', 'gianlucap', 'Giulio', 'Ilaria', 'massimog', 'federica', 'argio', 'Pennnny', 'GstarRoma', 'saratag', 'flazzo', 'michelac', 'Donato', 'debbyjack', 'GiulioT', 'gliaffamati', 'danielefrosinone', 'Connector', 'gratf', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'ElenaZiveri', 'PepitoRoma', 'CG', 'Anna', 'NicSBK', 'giuliaf', 'Backstage', 'Chiara', 'Lucio', 'Cibospeciale', 'Amichedelbar', 'massimiliano', 'lulliramacci', 'MartaVu', 'barbarasRRC', 'Cleo', 'gamberoro', 'AOQalicec', 'SusannaM', 'sara', 'Damichella', 'GiorgioRoby', 'Chiara', 'Ginevra', 'darias', 'fe', 'lostrys', 'Marco', 'JforJopelandic', 'AdeleP', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Mirella', 'ferdinandom', 'SabinaM', 'eleonorarossi', 'IlGamberoGrasso', 'liciabinda', 'PippangaReal', 'francesco', 'Mafalda', 'Tannaztm', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Bobione', 'Giuliall', 'Gattomattacchione', 'emanuelebike', 'Gia', 'Barbara', 'marco', 'Federico', 'IvanP', 'gladius', 'francescodd', 'serater', 'Domenico', 'jonathanp', 'Loreno', 'LucamarcelloR', 'Claudio', 'Gippigi', 'MJordano', 'Lepaole', 'Di', 'MARIANGELA', 'Sara', 'Andipa', 'ElaLaLei', 'carmain', 'serelichi', 'dudu', 'travel', 'Toniapa', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Randomind', 'marcellos', 'Fabiobsl', 'criandfra', 'Elena', 'Eleonorarctl', 'Eleonora', 'elena', 'poppyroberta', 'Veritas', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Antonella', 'robertam', 'tesors', 'AlessandraRoma', 'fedemicky', 'Andrea', 'losanica', 'decdec', 'Trippapino', 'mamoluse', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Ivanaxxx', 'Giulia', 'amelia', 'Valentina', 'dannnnniiiii', 'Valerieee', 'Palina', 'Clo', 'claudiacal', 'Giulio', 'andreamulargia' ...

# %% [markdown]
# #### Utilizzo gender_guesser
# Infine, posso utilizzare la libreria gender_guesser.
#
# NB: Genderize ti permette di analizzare 1000 nomi al giorno.

# %%
# !pip install gender_guesser
# Out:
# Requirement already satisfied: gender_guesser in /usr/local/lib/python3.6/dist-packages (0.4.0)

# %%
import gender_guesser.detector as gender
d = gender.Detector()

names_with_gender = []

for name in all_names_filtered:
    temp_gender = d.get_gender(name)
    names_with_gender.append(temp_gender)
  
print(names_with_gender)
# Out:
# ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'male', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'mostly_female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'female', 'female', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unkno ...

# %%
all_genders = []
i = 0

for guess in names_with_gender:
    if guess == 'male' or guess == 'mostly_male':
        all_genders.append('M')
    elif guess == 'female' or guess == 'mostly_female':
        all_genders.append('F')
    else:
        all_genders.append('UNKNOWN')

    
print(all_genders)
# Out:
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', ' ...

# %% [markdown]
# ---
# ## Salviamo ora i dati ottenuti in una tabella Excel
# Così non dovremo ogni volta rieseguire tutto il codice

# %% [markdown]
# ### Controlliamo che ci siano lo stesso numero di dati
# Potremo così creare una tabella sfruttando Pandas

# %%
print('Nomi: ', len(all_names_filtered))
print('Commenti: ', len(all_reviews_filtered))
print('Voti: ', len(all_ratings))
print('Mobile: ', len(all_mobile))
# Out:
# Nomi:  656
# Commenti:  656
# Voti:  656
# Mobile:  656

# %% [markdown]
# ### Eliminiamo le recensioni troppo lunghe e quelle di cui non sappiamo il genere del commentatore
# Creo una lista di liste [ ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ... ]

# %%
complete_list = []

i = len(all_names_filtered)

for indice in range(i):
  if all_genders[indice] != 'UNKNOWN' and all_reviews_filtered[indice] != 'RECENSIONE_TROPPO_LUNGA':
    temp = [all_names_filtered[indice], all_genders[indice], all_reviews_filtered[indice], all_ratings[indice], all_mobile[indice]]
    complete_list.append(temp)
    
print('DATI ANALIZZABILI: ', len(complete_list))
display(complete_list[:5])
# Out:
# DATI ANALIZZABILI:  40
# [['Giuliana',
#   'F',
#   'La location è splendida, quanto inaspettata.\ni prodotti freschi e di prima qualità.\nIl personale attento alle esigenze del cliente, sono sempre gentili e sorridenti\nlo consiglio vivamente!!!',
#   '4',
#   'PC'],
#  ['Martina',
#   'F',
#   'Sono stata due giorni fa a cena da Madre con il mio fidanzato e siamo rimasti davvero soddisfati. Location veramente bella, curata e accogliente. Personale preparatissimo e attento. Cibo particolare ma tutto buonissimo. Ci tornerò sicuramente !',
#   '5',
#   'Mobile'],
#  ['Aenne',
#   'F',
#   "Una vera boccata d'aria fresca per Roma.\nBella location, ottimi drink, buon cibo.\nPrezzi un tantino altini ma decisamente raccomandabile!",
#   '4',
#   'PC'],
#  ['Andrea',
#   'F',
#   'Consigliatissimo!!!\nSi mangia molto bene, si beve benissimo e se vi servirà Fabio sarete super coccolati! Bravo Fabio e bellissimo posto!!! Torneremo sicuramente!',
#   '5',
#   'Mobile'],
#  ['Barbara',
#   'F',
#   'Ottima location in pieno centro di Roma giardino fantastico, cibo ricercato . porzioni medie , ottima cantina personale veloce e attento - servizi igienici puliti - unica pecca tavoli troppo vicini',
#   '5',
#   'Mobile']]

# %% [markdown]
# ### Creiamo la tabella

# %%
# !pip install pandas
# !pip install xlsxwriter
import pandas as pd

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame({'Nomi': [elemento[0] for elemento in complete_list], 
                   'Genere': [elemento[1] for elemento in complete_list], 
                   'Recensioni': [elemento[2] for elemento in complete_list],
                   'Voti': [elemento[3] for elemento in complete_list],
                   'Scritta da': [elemento[4] for elemento in complete_list]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RISTORANTE_17.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
partial_dataframe = pd.read_excel("RISTORANTE_17.xlsx")

display(partial_dataframe)
# Out:
#    Genere        Nomi                                         Recensioni  \
# 0       F    Giuliana  La location è splendida, quanto inaspettata.\n...
# 1       F     Martina  Sono stata due giorni fa a cena da Madre con i...
# 2       F       Aenne  Una vera boccata d'aria fresca per Roma.\nBell...
# 3       F      Andrea  Consigliatissimo!!!\nSi mangia molto bene, si ...
# 4       F     Barbara  Ottima location in pieno centro di Roma giardi...
# 5       F       Lucia  Bellissimo giardino fresco,ordinato.Personale ...
# 6       M       Mauro  In uno dei quartieri più belli di Roma....ques...
# 7       M     Samuele  Ottimo posto personale bellissimo ed educato c...
# 8       F       Elena  Location splendida che riproduce una veranda f...
# 9       F   Valentina  Sempre impeccabili, la cucina è favolosa, i ma...
# 10      F   Francesca  Cibo buonissimo!!!! Tutti i tipi( carne,pesce,...
# 11      F       Piera  Moderno , location già vista , ambiente vario ...
# 12      M    Giovanni  Bella la location, gentile il personale niente...
# 13      M      Giulio  Scelto per la location, delusi per la cucina: ...
# 14      M      Donato  Almeno una volta bisogna venire da Madre per m...
# 15      F      Chiara  Posto fantastico, arredamento unico, curato ne...
# 16      F      Chiara  Locale veramente molto chic, personale moooolt...
# 17      F     Mirella  Ho festeggiato con alcune care amiche il mio c...
# 18      F     Mafalda  Pizza / pesce deliziosi ed ottimamente cucinat...
# 19      F     Barbara  location molto suggestiva e particolare person...
# 20      F   Valentina  Un posto incantevole cibo ottimo soprattutto l...
# 21      M         Rob  Cibo squisito presentato benissimo in porzioni...
# 22      F     Camilla  Ho cenato in questo ristorante qualche sera fa...
# 23      M         Ale  Location perfetta, seppur con difficoltà a par...
# 24      M  Sebastiano  Un luogo molto accogliente, personale gentile,...
# 25      F     Vinicia  Posto favoloso cibo ancora meglio\nSono stata ...
# 26      F    Carlotta  Atmosfera deliziosa, un ambiente sofisticato ,...
# 27      F     Elettra  Non conoscevo questo posto e sono andata solo ...
# 28      M    Ludovico  Location di eccezione, pranzo piacevolissimo. ...
# 29      M      Angelo  Location molto bella nel cuore del quartiere M...
# 30      F    Eleonora  Bel posto, buon servizio ..buoni i cocktail, s...
# 31      F   Gabriella  La qualità e l'accuratezza della preparazione ...
# 32      F    Eleonora  Locale di grande atmosfera, personale cordiale...
# 33      M     Antonio  Location veramente molto carina..\nIl cibo dir...
# 34      M        Pino  Si mangia molto bene. Molto accogliente. Il lo...
# 35      M      Davide  Il posto è molto bello. Il menu particolare. C...
# 36      F      Vanesa  Siamo stati con degli amici a prendere un drin...
# 37      F         Ana  La posizione è ottima, molto centrica, ma il m...
# 38      F      Angela  Questo ristorante è gestito da uno chef stella...
# 39      M       Marco  Madre è un concetto nuovo di zecca di ristoran...
#
#    Scritta da  Voti
# 0          PC     4
# 1      Mobile     5
# 2          PC     4
# 3      Mobile     5
# 4      Mobile     5
# 5      Mobile     5
# 6      Mobile     4
# 7      Mobile     5
# 8      Mobile     4
# 9          PC     5
# 10     Mobile     5
# 11     Mobile     1
# 12     Mobile     2
# 13     Mobile     2
# 14     Mobile     4
# 15     Mobile     3
# 16         PC     5
# 17         PC     5
# 18     Mobile     3
# 19         PC     4
# 20     Mobile     5
# 21     Mobile     5
# 22     Mobile     5
# 23     Mobile     2
# 24         PC     5
# 25     Mobile     5
# 26     Mobile     5
# 27         PC     4
# 28         PC     3
# 29         PC     2
# 30     Mobile     4
# 31         PC     5
# 32     Mobile     5
# 33     Mobile     3
# 34     Mobile     5
# 35     Mobile     4
# 36     Mobile     5
# 37     Mobile     3
# 38         PC     3
# 39         PC     4
