# %% [markdown]
# # Creo un nuovo dataset

# %% [markdown]
# ---
# ## Analisi dei commenti di un ristorante
#
# ### Luini Panzerotti - Milano
#
# URL di riferimento: https://www.tripadvisor.it/Restaurant_Review-g187849-d1097473-Reviews-Luini-Milan_Lombardy.html
# Home --> Ristoranti --> Milano

# %%
# IMPORT NECESSARI
import requests
from bs4 import BeautifulSoup

print("Imported")
# Out:
# Imported

# %%
page_URL = "https://www.tripadvisor.it/Restaurant_Review-g187849-d1097473-Reviews-Luini-Milan_Lombardy.html"

data = requests.get(page_URL)
clear_data = BeautifulSoup(data.content, "lxml")

print("Done")
# Out:
# Done

# %% [markdown]
# ---
# ### STRUTTURA HTML DEL SITO
#
# #### REVIEW
# `<p class="partial_entry"> qui c'è la review </p>`
#
# #### N° TOTALE DI REVIEWS
# `<a data-page-number="25" ...>
#     25
#  </a>`
#
# #### NAMES
# `<span class="expand_inline scrname" …>AlexandraCapeTown</span>`
#
# #### RATINGS
# `<span class="ui_bubble_rating bubble_30"></span>`

# %% [markdown]
# ---
# ### PRIMO SCRAPING (sulla prima pagina)
#
# Ottengo i nomi, i commenti, le review e da dove è stato scritto il commento per quanto rigurda la prima pagina. Ciò è necessario, in quanto, dalla seconda in poi l'URL cambia, permettendoci di iterare.

# %%
# OTTENGO UNA LISTA DI DIV CHE CONTENGONO NOME, RECENSIONE E VOTO

all_reviews = []
all_names = []
all_ratings = []
all_mobile = []

review_container = clear_data.findAll("div", attrs={"class":"review-container"})

for container in review_container:
  
    ### REVIEW ###
    review = container.find('p', attrs={'class': 'partial_entry'})
    if review:
        all_reviews.append(review.text)
        
    ### NAME ###
    name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
    if name:
      all_names.append(name.text)
    else:
      all_names.append('NO_NAME')
    
    ### RATING ###
    rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
    all_ratings.append(rating['class'][1][7:8])
    
    ### MOBILE ###
    mobile = container.find('span', attrs={'class': 'viaMobile'})
    if mobile:
      all_mobile.append('Mobile')
    else:
      all_mobile.append('PC')
    
    
################################################################################################################################
        
print("Executed")
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# Nomi:  10
# Commenti:  10
# Voti:  10
# Scritto da:  10

# %% [markdown]
# ### SECONDO SCRAPING (dalla seconda pagina in poi)
#
# Notiamo dall'URL che è possibile iterare sulle pagine, ottenendo i dati!

# %%
from tqdm import tqdm

URL_COMPLETO = 'https://www.tripadvisor.it/Restaurant_Review-g187849-d1097473-Reviews-or20-Luini-Milan_Lombardy.html'

URL_p1 = 'https://www.tripadvisor.it/Restaurant_Review-g187849-d1097473-Reviews-or'
URL_p2 = '0-Luini-Milan_Lombardy.html'
    
# OTTENGO I COMMENTI, NOMI E VOTI DALLA SECONDA PAGINA IN POI

total_pages = int(clear_data.select("a.pageNum.last.taLnk")[0].text) # 25 come intero

# per iterare dobbiamo partire dalla seconda pagina dei commenti, così nell'URL compaiono le cifre che ci servono
for r in tqdm(range(1,total_pages)):

    # OTTENGO L'URL DELLA PAGINA
    URL_temp = URL_p1 + str(r) + URL_p2

    # OTTENGO I DATI E CI APPLICO BEATIFULSOUP
    data = requests.get(URL_temp)
    clear_data = BeautifulSoup(data.content, "lxml")
    

    review_container = clear_data.findAll("div", attrs={"class":"review-container"})

    for container in review_container:
  
      ### REVIEW ###
      review = container.find('p', attrs={'class': 'partial_entry'})
      if review:
          all_reviews.append(review.text)

      ### NAME ###
      name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
      if name:
        all_names.append(name.text)
      else:
        all_names.append('NO_NAME')

      ### RATING ###
      rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
      all_ratings.append(rating['class'][1][7:8])

      ### MOBILE ###
      mobile = container.find('span', attrs={'class': 'viaMobile'})
      if mobile:
        all_mobile.append('Mobile')
      else:
        all_mobile.append('PC')
    
        
################################################################################################################################
        
print("Executed")
print('total_pages: ', total_pages)
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_mobile))
# Out:
# 100%|██████████| 1318/1318 [20:09<00:00,  1.24it/s]
# Executed
# total_pages:  1319
# Nomi:  13185
# Commenti:  13185
# Voti:  13185
# Scritto da:  13185

# %%
# display(all_reviews)

# %%
# print(all_names)

# %%
#print(all_ratings, '\n')
#print(len(all_ratings))

# %%
#display(all_mobile)

# %% [markdown]
# #### Problema recensioni troppo lunghe
# Alla fine di alcune recensioni troviamo un '...Più', che non possiamo espandere. Data la mole di dati, decidiamo dunque di non considerarle.

# %%
all_reviews_filtered = []
counter_reviews_scartate = 0;
counter_reviews_da_usare = 0;

for review in all_reviews:
    if '...Più' in review:
        all_reviews_filtered.append('RECENSIONE_TROPPO_LUNGA')
        counter_reviews_scartate+=1;
    else:
        all_reviews_filtered.append(review)
        counter_reviews_da_usare+=1;
        
        
print(
    'Totale recensioni:', counter_reviews_scartate + counter_reviews_da_usare, '\n',
    'Recensioni analizzabili:', counter_reviews_da_usare, '\n',
    'Recensioni scartate:', counter_reviews_scartate, '\n')

display(all_reviews_filtered[:10])
# Out:
# Totale recensioni: 13185
#  Recensioni analizzabili: 8583
#  Recensioni scartate: 4602
# ["Per chi va in centro a Milano non puo' non fermarsi ad assaggiare un panzerotto da Luini, a Milano diventato oramai un' Istituzione. I' ho preso con prosciutto e mozzarella. Davvero molto buono.",
#  "L'ho conosciuto solo pochi giorni fa... e ci tornerò sicuramente. Ci sono panzerotti per tutti i gusti, sia al forno che fritti, e il bello è mangiarli nel sacchettino di carta fra i vicoli circostanti, in mezzo a tutti gli altri clienti...",
#  'A parte la coda,Sempre lunghissima!Ma ne vale la pena!\nÈ sempre un piacere per le papille gustative!!\nOgni volta è tappa fissa!!!\nDa provare',
#  'RECENSIONE_TROPPO_LUNGA',
#  "Sempre il miglio panzerotto, ma non mi sembra più così buono. Forse perchè sono passati 40 anni da quando bigiavo al liceo, Difficile comunque trovare difetti. E' buonissimo, magari frli un pò più grandi...",
#  'Panzerotto molto buono con ingredienti di qualità nonostante la grande quantità di clienti.\nFila scorrevole e poca attesa in proporzione alla gente',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Ogni volta che passo dal centro..mangio sempre un paio di panzerotti....super buoni. Io prendo quasi sempre quelli mozzarella e pomodoro',
#  'I panzerotti ripieni più buoni di Milano e tra i migliori di Italia a mio parere.\nZona molto tranquilla ma un pochino nascosta',
#  "Panzerotti ovviamente buoni, di conseguenza tanti clienti e doppia fila ben fuori dal negozio. Però si fa abbastanza presto.\nSarà stato il periodo natalizio...ma abbiamo visto file un po' dappertutto..."]

# %% [markdown]
# ---
# ### Analisi dei nomi
# Cerchiamo di capire se chi ha commentato è un uomo (M) o una donna (F).

# %% [markdown]
# #### Elimino spazi e numeri
# Ho bisogno di tenere solo le informazioni riguardanti il nome, elimino il resto.

# %%
import re

all_names_filtered = []

regex = re.compile('[^a-zA-Z]')

for name in all_names:
    
    if ' ' in name:                           # se c'è uno spazio nel nome
        space = name.index(' ')               # ne trovo l'indice
        name = regex.sub('', name[:space])    # effettuo un controllo su tutto ciò che non è alfabeto fino a quell'indice
        all_names_filtered.append(name)       # e aggiungo la stringa
        
    else:
        name = regex.sub('', name)            # in caso contrario effettuo un controllo su tutto ciò che non è alfabeto
        all_names_filtered.append(name)       # e aggiungo la stringa
        
print(all_names, '\n')
print(all_names_filtered)
# Out:
# ['andrea g', 'AnnyS347', 'mgeg10', 'naturelle09', 'Davide F', '326danielee', 'joe_in_the_city', 'Stefania C', 'alessio a', 'ReviewsItaly', 'Eugenix2', 'allovertheworldd', 'Alberto A', 'feddy391', 'Silvana S', 'ArmandoAnna', 'Robi R', 'Tamara M', 'clou1104', '624mariapiaa', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'giorgio c', 'link7910', 'giuseppelorenzo', 'CateCate969', 'Emanuele_Q', '301DavidG', 'marinabb2016', 'Giorgio T', 'Cinzia P', 'lucalisci', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Y8518INangelop', 'Marghille', 'Diletta A', 'Checchina85', 'Thaumasios', 'Viatrix81', '583evitat', 'alessiabA9920MK', 'Francessscaa', 'spike70', 'nyoant', 'Elisa L', 'J6213VFelenas', 'Pietro B', 'Shade S', 'AntonioC1008', 'fr0ntinig', 'annapaola r', 'sweed11', 'ginogalasso', 'francescamenconi00', 'Antonio R', 'marcoMilanoCn69', 'CamillinaBianchii', 'giacomomartini', '887claudiax', 'Poolmart', 'Giancarlo M', 'W7919KPantoniob', 'laurenced233', 'antonio d', 'TheJurmans', 'Luciana P', 'Gallinicoletta65', 'Fra091276', 'mariamichitti', 'Charles-F-Muntz', '424silvial', '580massimilianog', 'chiara_baruffaldi', 'Roberto R', 'patrizia P', 'superkikka78', 'Andrea F', 'Fabrizio F', 'M389IMmariom', 'Pilottu', 'Kari A', 'caligola11', 'MancareMostri', 'paolaprincess83', 'camillax2018', 'Eleonora B', 'manuelab473', 'Valentina C', 'AndreaCV', 'X3580DMmarcop', 'Giuseppe E', 'IoViaggioLowCost365', 'marinamaino', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'withFrancescaR', 'Marcomega', 'ErMatador', 'paolol394', 'BrunoA82', 'Massimiliano L', 'roberto V', 'Flopla', 'Fabrizio F', 'paoloabbate23', 'chiarapicarelli', 'Giovanni M', 'P4601RFfedericom', 'marco_saff', 'Nido Famiglia T', 'jessicafJ7937DU', 'JohnDoeItalia', 'esterestaino92', 'stefanogourmet', 'c4rmen52', 'Roby4646', 'patstefano', 'lucetta_10', 'Sanbitter', 'Fili88M', 'NINASSA', 'enrica19752018', 'anna chiara z', '345paolop', 'Simona B', 'Luca M', 'Giordana G', '676graziad', 'davidemazzu', 'Artemisia G', 'claudio m', 'JulienRose', 'leon_kaiser46', 'anto624', 'mammamarty2', 'Floriana T', 'Erika N', '442piar', 'r0s372014', 'ALESSANDRO O', 'Arianna T', 'Monicayare', 'calendariog', 'margheritab901', 'giavili83', 'Z456ARdiegoc', '531paolas', 'FLB17082017', 'diankasm', 'chiablah', 'TRAVLSBIGH', 'Al1271', 'Paolo F', 'iena_21', 'verdino1943', 'CRISTIANO S', 'ndp24', 'Alek72', 'lucreziag95', '55cami', 'Mario C', 'giorgiofabris73', 'Ezio T', 'GUIDOLIK', 'artisart', 'agrippinot', 'Vivereilviaggio', 'francescosJ4648GF', '649paola', 'beatricel363', 'eiccia', 'Giadinchen', 'giovannilm', 'Flyer30806986383', 'Danya94', 'Federica D', '811irenek', 'Tony85italy', 'gloriacZ6095QV', 'AndreaD4914', 'Bea_259', 'trogloditas', 'Bubino_93', 'VenezianiAlida', 'FrenBZ', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'ChiccoZanna', 'gedeonerf', 'carlapau', 'Curiosity32452959043', 'Lallaben', 'simirma3', 'bbbbbbbb25', 'vincenzodb_97', 'stargazing29', 'Giulio C', 'Nemesi12', 'selu2016', 'Sergentegarcia', 'elena m', 'Ele V', '244indit', 'Domebomba', 'andreav233', 'LaDubyMilano', 'ElioLanz', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Soffilu', 'Foodpassion', 'sasaopici01', '836tinaa', 'ciccinchella', 'jennysluan', '442ClaudioC', 'Davide B', 'applefunny', 'Grazia R', 'LizzyDizz ...
#
# ['andrea', 'AnnyS', 'mgeg', 'naturelle', 'Davide', 'danielee', 'joeinthecity', 'Stefania', 'alessio', 'ReviewsItaly', 'Eugenix', 'allovertheworldd', 'Alberto', 'feddy', 'Silvana', 'ArmandoAnna', 'Robi', 'Tamara', 'clou', 'mariapiaa', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'giorgio', 'link', 'giuseppelorenzo', 'CateCate', 'EmanueleQ', 'DavidG', 'marinabb', 'Giorgio', 'Cinzia', 'lucalisci', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'YINangelop', 'Marghille', 'Diletta', 'Checchina', 'Thaumasios', 'Viatrix', 'evitat', 'alessiabAMK', 'Francessscaa', 'spike', 'nyoant', 'Elisa', 'JVFelenas', 'Pietro', 'Shade', 'AntonioC', 'frntinig', 'annapaola', 'sweed', 'ginogalasso', 'francescamenconi', 'Antonio', 'marcoMilanoCn', 'CamillinaBianchii', 'giacomomartini', 'claudiax', 'Poolmart', 'Giancarlo', 'WKPantoniob', 'laurenced', 'antonio', 'TheJurmans', 'Luciana', 'Gallinicoletta', 'Fra', 'mariamichitti', 'CharlesFMuntz', 'silvial', 'massimilianog', 'chiarabaruffaldi', 'Roberto', 'patrizia', 'superkikka', 'Andrea', 'Fabrizio', 'MIMmariom', 'Pilottu', 'Kari', 'caligola', 'MancareMostri', 'paolaprincess', 'camillax', 'Eleonora', 'manuelab', 'Valentina', 'AndreaCV', 'XDMmarcop', 'Giuseppe', 'IoViaggioLowCost', 'marinamaino', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'withFrancescaR', 'Marcomega', 'ErMatador', 'paolol', 'BrunoA', 'Massimiliano', 'roberto', 'Flopla', 'Fabrizio', 'paoloabbate', 'chiarapicarelli', 'Giovanni', 'PRFfedericom', 'marcosaff', 'Nido', 'jessicafJDU', 'JohnDoeItalia', 'esterestaino', 'stefanogourmet', 'crmen', 'Roby', 'patstefano', 'lucetta', 'Sanbitter', 'FiliM', 'NINASSA', 'enrica', 'anna', 'paolop', 'Simona', 'Luca', 'Giordana', 'graziad', 'davidemazzu', 'Artemisia', 'claudio', 'JulienRose', 'leonkaiser', 'anto', 'mammamarty', 'Floriana', 'Erika', 'piar', 'rs', 'ALESSANDRO', 'Arianna', 'Monicayare', 'calendariog', 'margheritab', 'giavili', 'ZARdiegoc', 'paolas', 'FLB', 'diankasm', 'chiablah', 'TRAVLSBIGH', 'Al', 'Paolo', 'iena', 'verdino', 'CRISTIANO', 'ndp', 'Alek', 'lucreziag', 'cami', 'Mario', 'giorgiofabris', 'Ezio', 'GUIDOLIK', 'artisart', 'agrippinot', 'Vivereilviaggio', 'francescosJGF', 'paola', 'beatricel', 'eiccia', 'Giadinchen', 'giovannilm', 'Flyer', 'Danya', 'Federica', 'irenek', 'Tonyitaly', 'gloriacZQV', 'AndreaD', 'Bea', 'trogloditas', 'Bubino', 'VenezianiAlida', 'FrenBZ', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'ChiccoZanna', 'gedeonerf', 'carlapau', 'Curiosity', 'Lallaben', 'simirma', 'bbbbbbbb', 'vincenzodb', 'stargazing', 'Giulio', 'Nemesi', 'selu', 'Sergentegarcia', 'elena', 'Ele', 'indit', 'Domebomba', 'andreav', 'LaDubyMilano', 'ElioLanz', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Soffilu', 'Foodpassion', 'sasaopici', 'tinaa', 'ciccinchella', 'jennysluan', 'ClaudioC', 'Davide', 'applefunny', 'Grazia', 'LizzyDizzy', 'niko', 'Germiniano', 'DZFantonioc', 'Sacchettina', 'Luigi', 'mirianab', 'Francesco', 'Elly', 'Martina', 'Dipe', 'ThomasValentino', 'BabsaColonia', 'debbyesem', 'SIMONE', 'Diane', 'FabioC', 'beaglutenfree', 'alexandrobonanno', 'cristiangt', 'Alessandro', 'anitafleps', 'bianchi', 'BBGandream', 'Daniela', 'Gigi', 'Silvia', 'Shadowria', 'pntsfn', 'walterl', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONA ...

# %% [markdown]
# #### Utilizzo gender_guesser
# Infine, posso utilizzare la libreria gender_guesser.
#
# NB: Genderize ti permette di analizzare 1000 nomi al giorno.

# %%
# !pip install gender_guesser
# Out:
# Collecting gender_guesser
#   Downloading https://files.pythonhosted.org/packages/13/fb/3f2aac40cd2421e164cab1668e0ca10685fcf896bd6b3671088f8aab356e/gender_guesser-0.4.0-py2.py3-none-any.whl (379kB)
#     100% |████████████████████████████████| 389kB 5.3MB/s
# Installing collected packages: gender-guesser
# Successfully installed gender-guesser-0.4.0

# %%
import gender_guesser.detector as gender
d = gender.Detector()

names_with_gender = []

for name in all_names_filtered:
    temp_gender = d.get_gender(name)
    names_with_gender.append(temp_gender)
  
print(names_with_gender)
# Out:
# ['unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'female', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'female ...

# %%
all_genders = []
i = 0

for guess in names_with_gender:
    if guess == 'male' or guess == 'mostly_male':
        all_genders.append('M')
    elif guess == 'female' or guess == 'mostly_female':
        all_genders.append('F')
    else:
        all_genders.append('UNKNOWN')

    
print(all_genders)
# Out:
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN' ...

# %% [markdown]
# ---
# ## Salviamo ora i dati ottenuti in una tabella Excel
# Così non dovremo ogni volta rieseguire tutto il codice

# %% [markdown]
# ### Controlliamo che ci siano lo stesso numero di dati
# Potremo così creare una tabella sfruttando Pandas

# %%
print('Nomi: ', len(all_names_filtered))
print('Commenti: ', len(all_reviews_filtered))
print('Voti: ', len(all_ratings))
print('Mobile: ', len(all_mobile))
# Out:
# Nomi:  13185
# Commenti:  13185
# Voti:  13185
# Mobile:  13185

# %% [markdown]
# ### Eliminiamo le recensioni troppo lunghe e quelle di cui non sappiamo il genere del commentatore
# Creo una lista di liste [ ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ... ]

# %%
complete_list = []

i = len(all_names_filtered)

for indice in range(i):
  if all_genders[indice] != 'UNKNOWN' and all_reviews_filtered[indice] != 'RECENSIONE_TROPPO_LUNGA':
    temp = [all_names_filtered[indice], all_genders[indice], all_reviews_filtered[indice], all_ratings[indice], all_mobile[indice]]
    complete_list.append(temp)
    
print('DATI ANALIZZABILI: ', len(complete_list))
display(complete_list[:5])
# Out:
# DATI ANALIZZABILI:  1781
# [['Davide',
#   'M',
#   "Sempre il miglio panzerotto, ma non mi sembra più così buono. Forse perchè sono passati 40 anni da quando bigiavo al liceo, Difficile comunque trovare difetti. E' buonissimo, magari frli un pò più grandi...",
#   '3',
#   'PC'],
#  ['Stefania',
#   'F',
#   'Ogni volta che passo dal centro..mangio sempre un paio di panzerotti....super buoni. Io prendo quasi sempre quelli mozzarella e pomodoro',
#   '4',
#   'Mobile'],
#  ['Alberto',
#   'M',
#   'Fila chilometrica ma ne è valsa la pena Come sempre una tradizione da non dimenticare ottimo il prodotto',
#   '5',
#   'Mobile'],
#  ['Giorgio',
#   'M',
#   'Sempre un piacere gustare un paio di buoni panzerotti ( mozzarella/ pomodoro e mozzarella cipolle olive ) da Luini. Coda veloce, personale gentile, purtroppo bisogna mangiare in piedi...',
#   '4',
#   'PC'],
#  ['Cinzia',
#   'F',
#   'Per chi si trova a dover pranzare e vuole gustarsi un ottimo panzerotto, non deve dimenticarsi di fare tappa da Luini.\nUn pò di coda... ma ne vale la pena.',
#   '4',
#   'PC']]

# %% [markdown]
# ### Creiamo la tabella

# %%
 # !pip install pandas
 # !pip install xlsxwriter
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.22.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.14.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas) (1.11.0)
# Collecting xlsxwriter
#   Downloading https://files.pythonhosted.org/packages/3d/1b/4caecd4efde1d41ba3bef1a81027032a7a6dff7d5112e1731f232c0addb9/XlsxWriter-1.1.2-py2.py3-none-any.whl (142kB)
#     100% |████████████████████████████████| 143kB 4.3MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-1.1.2

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame({'Nomi': [elemento[0] for elemento in complete_list], 
                   'Genere': [elemento[1] for elemento in complete_list], 
                   'Recensioni': [elemento[2] for elemento in complete_list],
                   'Voti': [elemento[3] for elemento in complete_list],
                   'Scritta da': [elemento[4] for elemento in complete_list]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RISTORANTE_21.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
partial_dataframe = pd.read_excel("RISTORANTE_21.xlsx")

display(partial_dataframe)
# Out:
#      Genere          Nomi                                         Recensioni  \
# 0         M        Davide  Sempre il miglio panzerotto, ma non mi sembra ...
# 1         F      Stefania  Ogni volta che passo dal centro..mangio sempre...
# 2         M       Alberto  Fila chilometrica ma ne è valsa la pena Come s...
# 3         M       Giorgio  Sempre un piacere gustare un paio di buoni pan...
# 4         F        Cinzia  Per chi si trova a dover pranzare e vuole gust...
# 5         F       Diletta  Mangerete i migliori panzerotti in assoluto. I...
# 6         F         Elisa  Non ci sono parole per descrivere la bontà dei...
# 7         M       Antonio  Ci siamo stati il 7/12 di passaggio dopo una s...
# 8         M     Giancarlo  qualità ottima, un pò di fila, ma ne vale la p...
# 9         M       Roberto  che dire di luini.....\nsono più di 30 anni ch...
# 10        M      Fabrizio  Da non perdere il panzer otto di Luini è un co...
# 11        F          Kari  L’attesa vale la pena. Posto sempre pieno, il ...
# 12        F      Eleonora  Sicuramente da provare per un panzerotto veloc...
# 13        F     Valentina  I panzerotti Luini sono ormai un prodotto tipi...
# 14        M  Massimiliano  Locale storico ed affollato, servizio veloce o...
# 15        M      Giovanni  In gita a Milano con amici, ci prendiamo dei p...
# 16        M          Roby  Non capisco perché da anni la gente si affolla...
# 17        F        Simona  Panzerotti divini ad un ottimo prezzo...nn ci ...
# 18        M          Luca  I panzerotti luini sono un'istituzione a Milan...
# 19        F      Giordana  A Milano è un'istituzione, infatti c è sempre ...
# 20        F      Floriana  Panzerotto al prosciutto e mozzarella buonissi...
# 21        F         Erika  È uno dei pochi panzerotti che mi piacciono, è...
# 22        F       Arianna  Se vai in Duomo non puoi non entrare da Luini....
# 23        M         Mario  Sono stato con amici, la coda era la premessa ...
# 24        M          Ezio  Presi diversi tipi di panzerotti, tutti buoni....
# 25        F      Federica  Conosciuto da poco, tramite un'amica!!!\nDavve...
# 26        F           Bea  Chi viene a Milano, non può non provare i panz...
# 27        M        Giulio  Era un po’ che non tornavo da Luini,sono ritor...
# 28        M        Davide  Buonissimi i panzerotti, ma non giustificano l...
# 29        F        Grazia  Purtroppo non è piu il luini di una volta, mi ...
# ...     ...           ...                                                ...
# 1751      F      Georgina  Valeva la pena aspettare. Il Panzerotti di zuc...
# 1752      M     Ferruccio  Provare quelli fritti, solo pomodoro e mozzare...
# 1753      F        Silvia  Ogni volta che torno a Milano "transporters Lu...
# 1754      F         Catia  E' solo per mangiare la famosa Panzerotti di z...
# 1755      F        Isabel  Personalmente, non godono le panzerottis da Lu...
# 1756      F         Maria  Abbiamo vistited questa plice due volte al gio...
# 1757      M       Roberto  Ottimo per uno spuntino eccellente nell'area d...
# 1758      M       Stefano  Essere proprio nel centro di Milano è una "pan...
# 1759      M          Jack  E' molto ben posizionato, vicino al Duomo, cos...
# 1760      M       Agustin  Situato in una strada laterale dal Duomo, Luin...
# 1761      M          Igor  Durante la nostra visita nel centro di Milano,...
# 1762      M        Wilton  In una stradina tra uno dei grandi negozi e ga...
# 1763      M       Stephan  Sono andato a Milano durante il fine settimana...
# 1764      M          Gary  Abbiamo letto di questo posto in italiano guid...
# 1765      M     Sebastien  Da provare se andate a Milano ho m un simpatic...
# 1766      M        Adrian  Siete a Milano e vicino al Duomo e vuole prova...
# 1767      M          Thor  Alcuni amici mi ha parlato di questo posto, mi...
# 1768      M         Scott  Se volete un veloce pranzo vicino il Duomo, go...
# 1769      F         Carla  Luini Panzerotti di zucca in è incredibile! Se...
# 1770      M          Jean  Siamo andati a piedi da questa piccola strada ...
# 1771      M         Diogo  Luini Panzerotti di zucca in è stata un succes...
# 1772      F       Tiffany  Questo negozio è così famosa e popolare. Quand...
# 1773      M          Eray  Era tutto squisito. Purtroppo era chiuso quand...
# 1774      F        Giulia  Il posto è molto facile da trovare, dal Duomo,...
# 1775      M         Mario  Toccare forzato di tutti i giovani passying da...
# 1776      M      Federico  Situato a pochi passi dal Duomo, Luini è un po...
# 1777      M         Yaron  Un fast food snack-bar, senza un'area salotto....
# 1778      F       Aurelie  Panzerotti di zucca in da Luini sono incantevo...
# 1779      M       Giacomo  Se si ri vicino al Duomo, non sprecate i vostr...
# 1780      M           Ron  Migliore e più famosa Panzerotti di zucca in M...
#
#      Scritta da  Voti
# 0            PC     3
# 1        Mobile     4
# 2        Mobile     5
# 3            PC     4
# 4            PC     4
# 5        Mobile     4
# 6        Mobile     5
# 7        Mobile     5
# 8            PC     5
# 9            PC     5
# 10       Mobile     5
# 11       Mobile     5
# 12       Mobile     5
# 13       Mobile     5
# 14           PC     3
# 15           PC     3
# 16       Mobile     3
# 17       Mobile     5
# 18       Mobile     4
# 19       Mobile     1
# 20           PC     5
# 21       Mobile     4
# 22       Mobile     5
# 23           PC     5
# 24       Mobile     4
# 25           PC     5
# 26       Mobile     5
# 27       Mobile     4
# 28       Mobile     4
# 29       Mobile     1
# ...         ...   ...
# 1751     Mobile     5
# 1752         PC     5
# 1753         PC     5
# 1754         PC     3
# 1755         PC     3
# 1756         PC     5
# 1757         PC     5
# 1758         PC     4
# 1759         PC     5
# 1760         PC     5
# 1761         PC     5
# 1762         PC     5
# 1763         PC     5
# 1764         PC     4
# 1765     Mobile     5
# 1766         PC     5
# 1767         PC     5
# 1768         PC     4
# 1769         PC     5
# 1770         PC     4
# 1771         PC     5
# 1772         PC     4
# 1773         PC     5
# 1774         PC     5
# 1775         PC     4
# 1776         PC     5
# 1777         PC     4
# 1778         PC     4
# 1779         PC     5
# 1780         PC     5
#
# [1781 rows x 5 columns]
