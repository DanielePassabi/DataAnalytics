# %% [markdown]
# # Creo un nuovo dataset

# %% [markdown]
# ---
# ## Analisi dei commenti di un ristorante
#
# ### Mimi e Coco - Lazio
#
# URL di riferimento: https://www.tripadvisor.it/Restaurant_Review-g187791-d1210614-Reviews-Mimi_e_Coco-Rome_Lazio.html
#
# Home --> Ristoranti --> Firenze --> Best_ranking--> SENZ_ALTRO_Bistrot

# %%
# IMPORT NECESSARI
import requests
from bs4 import BeautifulSoup

print("Imported")
# Out:
# Imported

# %%
page_URL = "https://www.tripadvisor.it/Restaurant_Review-g187791-d1210614-Reviews-Mimi_e_Coco-Rome_Lazio.html"

data = requests.get(page_URL)
clear_data = BeautifulSoup(data.content, "lxml")

print("Done")
# Out:
# Done

# %% [markdown]
# ---
# ### STRUTTURA HTML DEL SITO
#
# #### REVIEW
# `<p class="partial_entry"> qui c'è la review </p>`
#
# #### N° TOTALE DI REVIEWS
# `<a data-page-number="25" ...>
#     25
#  </a>`
#
# #### NAMES
# `<span class="expand_inline scrname" …>AlexandraCapeTown</span>`
#
# #### RATINGS
# `<span class="ui_bubble_rating bubble_30"></span>`

# %% [markdown]
# ---
# ### PRIMO SCRAPING (sulla prima pagina)
#
# Ottengo i nomi, i commenti, le review e da dove è stato scritto il commento per quanto rigurda la prima pagina. Ciò è necessario, in quanto, dalla seconda in poi l'URL cambia, permettendoci di iterare.

# %%
# OTTENGO UNA LISTA DI DIV CHE CONTENGONO NOME, RECENSIONE E VOTO

all_reviews = []
all_names = []
all_ratings = []
all_mobile = []

review_container = clear_data.findAll("div", attrs={"class":"review-container"})

for container in review_container:
  
    ### REVIEW ###
    review = container.find('p', attrs={'class': 'partial_entry'})
    if review:
        all_reviews.append(review.text)
        
    ### NAME ###
    name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
    if name:
      all_names.append(name.text)
    else:
      all_names.append('NO_NAME')
    
    ### RATING ###
    rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
    all_ratings.append(rating['class'][1][7:8])
    
    ### MOBILE ###
    mobile = container.find('span', attrs={'class': 'viaMobile'})
    if mobile:
      all_mobile.append('Mobile')
    else:
      all_mobile.append('PC')
    
    
################################################################################################################################
        
print("Executed")
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# Nomi:  10
# Commenti:  10
# Voti:  10
# Scritto da:  10

# %% [markdown]
# ### SECONDO SCRAPING (dalla seconda pagina in poi)
#
# Notiamo dall'URL che è possibile iterare sulle pagine, ottenendo i dati!

# %%
URL_COMPLETO = 'https://www.tripadvisor.it/Restaurant_Review-g187791-d1210614-Reviews-or10-Mimi_e_Coco-Rome_Lazio.html'

URL_p1 = 'https://www.tripadvisor.it/Restaurant_Review-g187791-d1210614-Reviews-or'
URL_p2 = '0-Mimi_e_Coco-Rome_Lazio.html'
    
# OTTENGO I COMMENTI, NOMI E VOTI DALLA SECONDA PAGINA IN POI

total_pages = int(clear_data.select("a.pageNum.last.taLnk")[0].text) # 25 come intero

# per iterare dobbiamo partire dalla seconda pagina dei commenti, così nell'URL compaiono le cifre che ci servono
for r in range(1,total_pages):

    # OTTENGO L'URL DELLA PAGINA
    URL_temp = URL_p1 + str(r) + URL_p2

    # OTTENGO I DATI E CI APPLICO BEATIFULSOUP
    data = requests.get(URL_temp)
    clear_data = BeautifulSoup(data.content, "lxml")
    

    review_container = clear_data.findAll("div", attrs={"class":"review-container"})

    for container in review_container:
  
      ### REVIEW ###
      review = container.find('p', attrs={'class': 'partial_entry'})
      if review:
          all_reviews.append(review.text)

      ### NAME ###
      name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
      if name:
        all_names.append(name.text)
      else:
        all_names.append('NO_NAME')

      ### RATING ###
      rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
      all_ratings.append(rating['class'][1][7:8])

      ### MOBILE ###
      mobile = container.find('span', attrs={'class': 'viaMobile'})
      if mobile:
        all_mobile.append('Mobile')
      else:
        all_mobile.append('PC')
    
        
################################################################################################################################
        
print("Executed")
print('total_pages: ', total_pages)
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Page 1 of 233
# Page 2 of 233
# Page 3 of 233
# Page 4 of 233
# Page 5 of 233
# Page 6 of 233
# Page 7 of 233
# Page 8 of 233
# Page 9 of 233
# Page 10 of 233
# Page 11 of 233
# Page 12 of 233
# Page 13 of 233
# Page 14 of 233
# Page 15 of 233
# Page 16 of 233
# Page 17 of 233
# Page 18 of 233
# Page 19 of 233
# Page 20 of 233
# Page 21 of 233
# Page 22 of 233
# Page 23 of 233
# Page 24 of 233
# Page 25 of 233
# Page 26 of 233
# Page 27 of 233
# Page 28 of 233
# Page 29 of 233
# Page 30 of 233
# Page 31 of 233
# Page 32 of 233
# Page 33 of 233
# Page 34 of 233
# Page 35 of 233
# Page 36 of 233
# Page 37 of 233
# Page 38 of 233
# Page 39 of 233
# Page 40 of 233
# Page 41 of 233
# Page 42 of 233
# Page 43 of 233
# Page 44 of 233
# Page 45 of 233
# Page 46 of 233
# Page 47 of 233
# Page 48 of 233
# Page 49 of 233
# Page 50 of 233
# Page 51 of 233
# Page 52 of 233
# Page 53 of 233
# Page 54 of 233
# Page 55 of 233
# Page 56 of 233
# Page 57 of 233
# Page 58 of 233
# Page 59 of 233
# Page 60 of 233
# Page 61 of 233
# Page 62 of 233
# Page 63 of 233
# Page 64 of 233
# Page 65 of 233
# Page 66 of 233
# Page 67 of 233
# Page 68 of 233
# Page 69 of 233
# Page 70 of 233
# Page 71 of 233
# Page 72 of 233
# Page 73 of 233
# Page 74 of 233
# Page 75 of 233
# Page 76 of 233
# Page 77 of 233
# Page 78 of 233
# Page 79 of 233
# Page 80 of 233
# Page 81 of 233
# Page 82 of 233
# Page 83 of 233
# Page 84 of 233
# Page 85 of 233
# Page 86 of 233
# Page 87 of 233
# Page 88 of 233
# Page 89 of 233
#print(len(all_ratings))

# %%
#display(all_mobile)

# %% [markdown]
# #### Problema recensioni troppo lunghe
# Alla fine di alcune recensioni troviamo un '...Più', che non possiamo espandere. Data la mole di dati, decidiamo dunque di non considerarle.

# %%
all_reviews_filtered = []
counter_reviews_scartate = 0;
counter_reviews_da_usare = 0;

for review in all_reviews:
    if '...Più' in review:
        all_reviews_filtered.append('RECENSIONE_TROPPO_LUNGA')
        counter_reviews_scartate+=1;
    else:
        all_reviews_filtered.append(review)
        counter_reviews_da_usare+=1;
        
        
print(
    'Totale recensioni:', counter_reviews_scartate + counter_reviews_da_usare, '\n',
    'Recensioni analizzabili:', counter_reviews_da_usare, '\n',
    'Recensioni scartate:', counter_reviews_scartate, '\n')

display(all_reviews_filtered[:10])
# Out:
# Totale recensioni: 2321
#  Recensioni analizzabili: 1702
#  Recensioni scartate: 619
# ['RECENSIONE_TROPPO_LUNGA',
#  "Siamo stati a cena la sera dell'epifania; fortunatamente abbiamo atteso soltanto circa 10' per sederci; ordinato n.2 pinse, n.2 birre medie alla spina e n.1 bottiglia di acqua; tutto molto buono; il personale e' stato molto gentile; il conto è stato 33€.",
#  'il posto è piccolo ma accogliente - attenzione a nn sedersi d‘inverno vicino alla porta che è sempre (comprensibilmente) aperta. Nn si può prenotare e quindi andare „presto“ se si vuole evitare file.\nIl cibo buono ed abbondante. Servizio molto veloce e gentile. Ci torneremo!',
#  'Ho passato una serata magnifica mi hanno accolto come se fossi la figlia del proprietario.Devo fare i miei più sentiti complimenti al responsabile Lorenzo veramente simpaticissimo ! E niente vi saluto,un caro abbraccio! VE LO CONSIGLIO !!!',
#  'Quasi impossibile trovare posto in questo localino piccolissimo e sempre pieno, noi siamo stati fortunati! ! Da provare la pasta alla grigia assolutamente',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Una bella scoperta!!! Una carbonara da favola! Ottima qualità e personale super simpatico. Da ritornarci sicuramente',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA']

# %% [markdown]
# ---
# ### Analisi dei nomi
# Cerchiamo di capire se chi ha commentato è un uomo (M) o una donna (F).

# %% [markdown]
# #### Elimino spazi e numeri
# Ho bisogno di tenere solo le informazioni riguardanti il nome, elimino il resto.

# %%
import re

all_names_filtered = []

regex = re.compile('[^a-zA-Z]')

for name in all_names:
    
    if ' ' in name:                           # se c'è uno spazio nel nome
        space = name.index(' ')               # ne trovo l'indice
        name = regex.sub('', name[:space])    # effettuo un controllo su tutto ciò che non è alfabeto fino a quell'indice
        all_names_filtered.append(name)       # e aggiungo la stringa
        
    else:
        name = regex.sub('', name)            # in caso contrario effettuo un controllo su tutto ciò che non è alfabeto
        all_names_filtered.append(name)       # e aggiungo la stringa
        
print(all_names, '\n')
print(all_names_filtered)
# Out:
 'Escape', 'cisalpino', 'dario', 'camillaprince', 'francescacrm', 'Elena', 'Michele', 'EmiM', 'Massiv', 'elenadam', 'agata', 'robertthorn', 'AlessandroDelBrocco', 'QQKvincenzoa', 'Lolosuper', 'Luciano', 'cristinadessole', 'Francesco', 'nicolac', 'Gloria', 'federicasilvanap', 'Kendra', 'Mariiiiii', 'Martina', 'Gioiarada', 'carlogambi', 'marilenag', 'Frankie', 'Fantawarrior', 'QAPlucac', 'SALENTOTIUM', 'marcomEZZ', 'Diego', 'TravelersMice', 'francescosich', 'NicolaFlash', 'Camilla', 'saramQEZ', 'Ale', 'Elena', 'Elena', 'alessandraf', 'Valentinapick', 'Augusto', 'PeoVince', 'guardiaprimula', 'EnricaE', 'Emimek', 'nicolap', 'sanchioni', 'mdigregorio', 'LuciaBaddo', 'Silvia', 'melixcau', 'ANEP', 'Giovanni', 'gretagiampietro', 'crazy', 'EmiM', 'simonamLUB', 'Marta', 'Gemma', 'Laura', 'Luca', 'Emiliano', 'salvatorepetaloso', 'Donata', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Antonio', 'Deus', 'Luca', 'lvizintin', 'mazzarino', 'JujaGrande', 'olastododeka', 'Claudia', 'EdoBologna', 'virginiaamadori', 'matteolFSP', 'alexiamaestrati', 'camil', 'quasarx', 'michimichi', 'andreat', 'Simonpee', 'mikelasando', 'vikyh', 'ju', 'contefava', 'TaniaL', 'aledalca', 'simoncoste', 'antosciulloio', 'francescaa', 'lg', 'matteofantin', 'VEPsaram', 'parquattro', 'Daniela', 'Giorgio', 'simogi', 'Andrea', 'Michele', 'Ale', 'fianny', 'gaetanoc', 'chiaralazzari', 'sonya', 'Elena', 'Andrea', 'celestepanzeri', 'alessandrosTRT', 'valeriab', 'marialuisam', 'alessandro', 'Ciccioerpiccoletto', 'camilla', 'cavallosardo', 'Paul', 'madkorry', 'chiara', 'Martina', 'Marianna', 'giacomog', 'valeriov', 'virginiadvisor', 'nicolap', 'telettico', 'Deborah', 'MaraAnto', 'adreamer', 'AlessiaD', 'robertodSKP', 'central', 'Ale', 'francov', 'Camilla', 'Elena', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'anglomurru', 'carlo', 'Valentina', 'Michela', 'Saverio', 'marianoto', 'chiarac', 'Kuruzzu', 'Elena', 'VossAlex', 'francesca', 'croods', 'Sallyebasta', 'Stefandra', 'Paola', 'aleroma', 'Elena', 'luksteyn', 'fabristuta', 'Rubschtin', 'violetta', 'chiarafab', 'Marina', 'iofaraone', 'Martina', 'fortitudof', 'michele', 'Itazone', 'viaggiogourmet', 'Alessandra', 'claurubi', 'francy', 'eliadami',  ...

# %% [markdown]
# #### Utilizzo gender_guesser
# Infine, posso utilizzare la libreria gender_guesser.
#
# NB: Genderize ti permette di analizzare 1000 nomi al giorno.

# %%
# !pip install gender_guesser
# Out:
# Requirement already satisfied: gender_guesser in /usr/local/lib/python3.6/dist-packages (0.4.0)

# %%
import gender_guesser.detector as gender
d = gender.Detector()

names_with_gender = []

for name in all_names_filtered:
    temp_gender = d.get_gender(name)
    names_with_gender.append(temp_gender)
  
print(names_with_gender)
# Out:
# ['unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'female', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'andy', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'female', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'female', 'male', 'male', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'female', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'female', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'andy', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unk ...

# %%
all_genders = []
i = 0

for guess in names_with_gender:
    if guess == 'male' or guess == 'mostly_male':
        all_genders.append('M')
    elif guess == 'female' or guess == 'mostly_female':
        all_genders.append('F')
    else:
        all_genders.append('UNKNOWN')

    
print(all_genders)
# Out:
# ['UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'F', 'M', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'F', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', ...

# %% [markdown]
# ---
# ## Salviamo ora i dati ottenuti in una tabella Excel
# Così non dovremo ogni volta rieseguire tutto il codice

# %% [markdown]
# ### Controlliamo che ci siano lo stesso numero di dati
# Potremo così creare una tabella sfruttando Pandas

# %%
print('Nomi: ', len(all_names_filtered))
print('Commenti: ', len(all_reviews_filtered))
print('Voti: ', len(all_ratings))
print('Mobile: ', len(all_mobile))
# Out:
# Nomi:  2321
# Commenti:  2321
# Voti:  2321
# Mobile:  2321

# %% [markdown]
# ### Eliminiamo le recensioni troppo lunghe e quelle di cui non sappiamo il genere del commentatore
# Creo una lista di liste [ ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ... ]

# %%
complete_list = []

i = len(all_names_filtered)

for indice in range(i):
  if all_genders[indice] != 'UNKNOWN' and all_reviews_filtered[indice] != 'RECENSIONE_TROPPO_LUNGA':
    temp = [all_names_filtered[indice], all_genders[indice], all_reviews_filtered[indice], all_ratings[indice], all_mobile[indice]]
    complete_list.append(temp)
    
print('DATI ANALIZZABILI: ', len(complete_list))
display(complete_list[:5])
# Out:
# DATI ANALIZZABILI:  455
# [['Gaetano',
#   'M',
#   "Siamo stati a cena la sera dell'epifania; fortunatamente abbiamo atteso soltanto circa 10' per sederci; ordinato n.2 pinse, n.2 birre medie alla spina e n.1 bottiglia di acqua; tutto molto buono; il personale e' stato molto gentile; il conto è stato 33€.",
#   '4',
#   'Mobile'],
#  ['Roberto',
#   'M',
#   'Trovato in base alle recensioni degli altri clienti e direi tt esatte. Personale professionale e simpatico il cibo ottimo e i prezzi nella norma se uno passa di li da provare di sicuro .',
#   '5',
#   'Mobile'],
#  ['Paola',
#   'F',
#   'Ambiente accogliente nei piccoli spazi a disposizione...e buoni piatti! Nuovi gestori giovani e ospitali!',
#   '4',
#   'Mobile'],
#  ['Belinda',
#   'F',
#   'Per chi vuole assaporare la vera pasta tipica romana è perfetto. Piccolo ma accogliente. Servizio molto cordiale. Ci hanno accolti Andreea e Federico. Siamo rimasti molto soddisfatti di tutto. Consigliatissimo',
#   '5',
#   'Mobile'],
#  ['Cinzia',
#   'F',
#   'Arrivati verso le 12.30 per un aperitivo...il locale era ancora tutto per noi .. ci siamo venuti altre volte e ci siamo sempre trovati benissimo!! Tutti gentilissimi e taglieri buonissimi!!!',
#   '5',
#   'Mobile']]

# %% [markdown]
# ### Creiamo la tabella

# %%
# !pip install xlsxwriter
import pandas as pd
# Out:
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.6/dist-packages (1.1.2)

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame({'Nomi': [elemento[0] for elemento in complete_list], 
                   'Genere': [elemento[1] for elemento in complete_list], 
                   'Recensioni': [elemento[2] for elemento in complete_list],
                   'Voti': [elemento[3] for elemento in complete_list],
                   'Scritta da': [elemento[4] for elemento in complete_list]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RISTORANTE_14.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
partial_dataframe = pd.read_excel("RISTORANTE_14.xlsx")

display(partial_dataframe)
# Out:
#     Genere          Nomi                                         Recensioni  \
# 0        M       Gaetano  Siamo stati a cena la sera dell'epifania; fort...
# 1        M       Roberto  Trovato in base alle recensioni degli altri cl...
# 2        F         Paola  Ambiente accogliente nei piccoli spazi a dispo...
# 3        F       Belinda  Per chi vuole assaporare la vera pasta tipica ...
# 4        F        Cinzia  Arrivati verso le 12.30 per un aperitivo...il ...
# 5        F         Katia  Buono, bravi e simpatici. È già la seconda vol...
# 6        F           Sue  Il locale è abbastanza piccolo però si è mangi...
# 7        F         Giusy  Il ristorante è veramente piccolo ma è molto c...
# 8        M  Massimiliano  Ci siamo passati grazie alle.altre recensioni....
# 9        F          Sara  Locale intimo e rustico.\nNel centro di Roma, ...
# 10       M          Alby  Sempre bello ritornare in questo locale. Un ri...
# 11       F         Giota  Difficile da trovare posto per due motivi; vi ...
# 12       F        Silvia  Ho cenato da sola in questo piccolo ristorante...
# 13       M     Francesco  Abbiamo cenato qui la prima sera passata a Rom...
# 14       M      Kristian  Ho trovato lo staff gentilissimo ed accoglient...
# 15       F       Daniela  Ottima scelta per assaporare i piatti autentic...
# 16       M  Massimiliano  Qualità davvero notevole in un contesto inform...
# 17       M      Gianluca  Ottima pizza locale accogliente pulito e perso...
# 18       M       Luciano  Un bel posto, nonostante il piccolo spazio, ma...
# 19       M     Francesco  Ottimo,prezzi competitivi e qualità medio-alta...
# 20       F        Gloria  Abbiamo pranzato lì già abbastanza convinti pe...
# 21       F       Martina  Ristorante carino e piacevole al centro di rom...
# 22       M         Diego  È stata la mia prima volta a Roma e anche la p...
# 23       F       Camilla  Servizio eccellente, cibo delizioso e location...
# 24       M           Ale  musica eccezionale, jazz swing e tutti le hit ...
# 25       F         Elena  Abbiamo passato una piacevole serata.locale mo...
# 26       M       Augusto  La location li per li non ispira molta fiducia...
# 27       F        Silvia  Trattoria piccola situata ad un passo da Piazz...
# 28       M      Giovanni  Spettacolare. Caratteristico locale che non sa...
# 29       F        Donata  Cibo ottimo, personale molto simpatico e corte...
# ..     ...           ...                                                ...
# 425      M         Scott  Avevamo visto e di Mimi's Coco in una passeggi...
# 426      M           Dan  Il personale era gentile, il cibo era eccellen...
# 427      M         Larry  Ci siamo fermati per il vino e uno spuntino me...
# 428      F        Andrea  Dopo aver letto molti blog relativa opzione gr...
# 429      M        Steven  Si tratta di un cafè/bar meraviglioso in una s...
# 430      F         Kelly  Dopo aver camminato per miglia e affrontando l...
# 431      F          Mary  Ci siamo imbattuti casualmente in questo posto...
# 432      F          Gina  Il ristorante è molto bello e si trova tra il ...
# 433      F        Marion  Consiglio vivamente questo posto... siamo anda...
# 434      M       Richard  Ci siamo imbattuti in questo vino resstuarant ...
# 435      M          Andy  Il miglior ristorante siamo andati a durante 4...
# 436      F          Tine  Veramente meraviglioso piccolo posto, con past...
# 437      M     Giampiero  Siamo rimasti a piedi vicino a Piazza Navona e...
# 438      M        Justin  Non ho spesso scrivere recensioni negative, ma...
# 439      F         Cathy  Ho mangiato qui durante un viaggio a Roma con ...
# 440      M           Nic  Abbiamo trovato questo posto saggi che cercano...
# 441      M          Matt  Abbiamo trovato e Mimi's Coco mentre stai cerc...
# 442      F          Lucy  Accogliente e bizzarro bistro su una strada gr...
# 443      M         Peter  Questo caffè/bar poco alla moda sembra essere ...
# 444      M         Nikos  4 Anni fa e ancora non posso dimenticare la ca...
# 445      F         Jenny  Il cibo, il personale e atmosfera eccellente -...
# 446      M        Edgars  Questo posto ci è davvero piaciuto. il cibo er...
# 447      F          Lisa  Il cibo e i Mimi's Coco è fantastico, e con cr...
# 448      F          Jane  Eravamo diretti a Piazza Navona dal Vaticano q...
# 449      F        Eileen  POSTO FANTASTICO, PIENO DI ATMOSFERA" avevamo ...
# 450      M          Phil  Posizione fantastica\nOttima pizza e insalate ...
# 451      F         Anika  Questo è un vero gioiello trovare dietro Piazz...
# 452      M         Chino  Abbiamo deciso di mangiare qui dopo essere sta...
# 453      M          Owen  Posizione fantastica solo per sedersi e guarda...
# 454      M        Kostas  Il cibo era ottima, così come l'atmosfera. Ino...
#
#     Scritta da  Voti
# 0       Mobile     4
# 1       Mobile     5
# 2       Mobile     4
# 3       Mobile     5
# 4       Mobile     5
# 5       Mobile     5
# 6       Mobile     5
# 7       Mobile     5
# 8       Mobile     5
# 9           PC     5
# 10      Mobile     5
# 11      Mobile     4
# 12          PC     4
# 13      Mobile     5
# 14      Mobile     5
# 15      Mobile     5
# 16      Mobile     5
# 17      Mobile     5
# 18      Mobile     5
# 19      Mobile     5
# 20      Mobile     5
# 21      Mobile     5
# 22      Mobile     5
# 23          PC     5
# 24          PC     5
# 25      Mobile     5
# 26      Mobile     4
# 27      Mobile     5
# 28          PC     4
# 29          PC     5
# ..         ...   ...
# 425         PC     2
# 426         PC     5
# 427         PC     4
# 428         PC     2
# 429         PC     5
# 430         PC     5
# 431         PC     5
# 432         PC     5
# 433         PC     5
# 434         PC     5
# 435         PC     4
# 436         PC     5
# 437         PC     4
# 438         PC     1
# 439         PC     3
# 440         PC     4
# 441         PC     5
# 442         PC     5
# 443         PC     4
# 444         PC     5
# 445         PC     5
# 446         PC     5
# 447         PC     4
# 448         PC     5
# 449         PC     5
# 450         PC     4
# 451         PC     5
# 452         PC     4
# 453         PC     5
# 454         PC     4
#
# [455 rows x 5 columns]
