# %% [markdown]
# # Creo un nuovo dataset

# %% [markdown]
# ---
# ## Analisi dei commenti di un ristorante
#
# ### Nerino Dieci Trattoria - Lombardia
#
# URL di riferimento: https://www.tripadvisor.it/Restaurant_Review-g187849-d2048527-Reviews-Nerino_Dieci_Trattoria-Milan_Lombardy.html
#
# Home --> Ristoranti --> Firenze --> Best_ranking--> SENZ_ALTRO_Bistrot

# %%
# IMPORT NECESSARI
import requests
from bs4 import BeautifulSoup

print("Imported")
# Out:
# Imported

# %%
page_URL = "https://www.tripadvisor.it/Restaurant_Review-g187849-d2048527-Reviews-Nerino_Dieci_Trattoria-Milan_Lombardy.html"

data = requests.get(page_URL)
clear_data = BeautifulSoup(data.content, "lxml")

print("Done")
# Out:
# Done

# %% [markdown]
# ---
# ### STRUTTURA HTML DEL SITO
#
# #### REVIEW
# `<p class="partial_entry"> qui c'è la review </p>`
#
# #### N° TOTALE DI REVIEWS
# `<a data-page-number="25" ...>
#     25
#  </a>`
#
# #### NAMES
# `<span class="expand_inline scrname" …>AlexandraCapeTown</span>`
#
# #### RATINGS
# `<span class="ui_bubble_rating bubble_30"></span>`

# %% [markdown]
# ---
# ### PRIMO SCRAPING (sulla prima pagina)
#
# Ottengo i nomi, i commenti, le review e da dove è stato scritto il commento per quanto rigurda la prima pagina. Ciò è necessario, in quanto, dalla seconda in poi l'URL cambia, permettendoci di iterare.

# %%
# OTTENGO UNA LISTA DI DIV CHE CONTENGONO NOME, RECENSIONE E VOTO

all_reviews = []
all_names = []
all_ratings = []
all_mobile = []

review_container = clear_data.findAll("div", attrs={"class":"review-container"})

for container in review_container:
  
    ### REVIEW ###
    review = container.find('p', attrs={'class': 'partial_entry'})
    if review:
        all_reviews.append(review.text)
        
    ### NAME ###
    name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
    if name:
      all_names.append(name.text)
    else:
      all_names.append('NO_NAME')
    
    ### RATING ###
    rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
    all_ratings.append(rating['class'][1][7:8])
    
    ### MOBILE ###
    mobile = container.find('span', attrs={'class': 'viaMobile'})
    if mobile:
      all_mobile.append('Mobile')
    else:
      all_mobile.append('PC')
    
    
################################################################################################################################
        
print("Executed")
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# Nomi:  10
# Commenti:  10
# Voti:  10
# Scritto da:  10

# %% [markdown]
# ### SECONDO SCRAPING (dalla seconda pagina in poi)
#
# Notiamo dall'URL che è possibile iterare sulle pagine, ottenendo i dati!

# %%
URL_COMPLETO = 'https://www.tripadvisor.it/Restaurant_Review-g187849-d2048527-Reviews-or10-Nerino_Dieci_Trattoria-Milan_Lombardy.html'

URL_p1 = 'https://www.tripadvisor.it/Restaurant_Review-g187849-d2048527-Reviews-or'
URL_p2 = '0-Nerino_Dieci_Trattoria-Milan_Lombardy.html'
    
# OTTENGO I COMMENTI, NOMI E VOTI DALLA SECONDA PAGINA IN POI

total_pages = int(clear_data.select("a.pageNum.last.taLnk")[0].text) # 25 come intero

# per iterare dobbiamo partire dalla seconda pagina dei commenti, così nell'URL compaiono le cifre che ci servono
for r in range(1,total_pages):

    # OTTENGO L'URL DELLA PAGINA
    URL_temp = URL_p1 + str(r) + URL_p2

    # OTTENGO I DATI E CI APPLICO BEATIFULSOUP
    data = requests.get(URL_temp)
    clear_data = BeautifulSoup(data.content, "lxml")
    

    review_container = clear_data.findAll("div", attrs={"class":"review-container"})

    for container in review_container:
  
      ### REVIEW ###
      review = container.find('p', attrs={'class': 'partial_entry'})
      if review:
          all_reviews.append(review.text)

      ### NAME ###
      name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
      if name:
        all_names.append(name.text)
      else:
        all_names.append('NO_NAME')

      ### RATING ###
      rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
      all_ratings.append(rating['class'][1][7:8])

      ### MOBILE ###
      mobile = container.find('span', attrs={'class': 'viaMobile'})
      if mobile:
        all_mobile.append('Mobile')
      else:
        all_mobile.append('PC')
    
        
################################################################################################################################
        
print("Executed")
print('total_pages: ', total_pages)
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# total_pages:  366
# Nomi:  3656
# Commenti:  3656
# Voti:  3656
# Scritto da:  3656

# %%
# display(all_reviews)

# %%
# print(all_names)

# %%
#print(all_ratings, '\n')
#print(len(all_ratings))

# %%
#display(all_mobile)

# %% [markdown]
# #### Problema recensioni troppo lunghe
# Alla fine di alcune recensioni troviamo un '...Più', che non possiamo espandere. Data la mole di dati, decidiamo dunque di non considerarle.

# %%
all_reviews_filtered = []
counter_reviews_scartate = 0;
counter_reviews_da_usare = 0;

for review in all_reviews:
    if '...Più' in review:
        all_reviews_filtered.append('RECENSIONE_TROPPO_LUNGA')
        counter_reviews_scartate+=1;
    else:
        all_reviews_filtered.append(review)
        counter_reviews_da_usare+=1;
        
        
print(
    'Totale recensioni:', counter_reviews_scartate + counter_reviews_da_usare, '\n',
    'Recensioni analizzabili:', counter_reviews_da_usare, '\n',
    'Recensioni scartate:', counter_reviews_scartate, '\n')

display(all_reviews_filtered[:10])
# Out:
# Totale recensioni: 3656
#  Recensioni analizzabili: 1795
#  Recensioni scartate: 1861
# ['Un buonissimo ristorante molto vicino al Duomo. Bel posto all’interno con un servizio professionale. Da andare con prenotazione perché c’è quasi sempre tutto occupato.',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Ottima Trattoria a pochi passi da Piazza Duomo. Locale affollato, servizio veloce , attento e professionale. Cucina a vista, piatti preparati con cura e con eccellenti materie prime utilizzate . Buon rapporto qualità prezzo',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Ho apprezzato molto servizio, location e cibo.\nSimpatia, educazione, trattoria con eleganza e carne ottima.',
#  'RECENSIONE_TROPPO_LUNGA',
#  'RECENSIONE_TROPPO_LUNGA',
#  "Fino a ieri sera, quando sono stato con un amico carissimo, ne ignoravo l'esistenza.\nUn po' nascosto, in una traversa di via Torino, è stata una piacevole scoperta.\nOttima qualità del cibo.",
#  'Un ristorante accogliente, servizio attento, cordialità, buon cibo. A pranzo è molto frequentato la sera è più tranquillo. Consigliato']

# %% [markdown]
# ---
# ### Analisi dei nomi
# Cerchiamo di capire se chi ha commentato è un uomo (M) o una donna (F).

# %% [markdown]
# #### Elimino spazi e numeri
# Ho bisogno di tenere solo le informazioni riguardanti il nome, elimino il resto.

# %%
import re

all_names_filtered = []

regex = re.compile('[^a-zA-Z]')

for name in all_names:
    
    if ' ' in name:                           # se c'è uno spazio nel nome
        space = name.index(' ')               # ne trovo l'indice
        name = regex.sub('', name[:space])    # effettuo un controllo su tutto ciò che non è alfabeto fino a quell'indice
        all_names_filtered.append(name)       # e aggiungo la stringa
        
    else:
        name = regex.sub('', name)            # in caso contrario effettuo un controllo su tutto ciò che non è alfabeto
        all_names_filtered.append(name)       # e aggiungo la stringa
        
print(all_names, '\n')
print(all_names_filtered)
# Out:
# ['Pellarob', 'Francesco P', 'maram926', 'giorgio2195', 'Elia T', 'xlaf', 'B5292CRfedericap', 'ISABELLA R', 'Lorenzo V', 'rolling69', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'giampaolol120', 'alessandral527', 'pataepisi', 'patriziaelli', 'tommasot269', 'cesare m', '50sfumaturedimamma', 'Elele1983', '886las', 'Natalia D', 'npettinato', 'robertoegraziab', 'feuse', 'patrizia P', 'amagnama', 'bubitimeflies', 'claudio m', 'lauratW4868QN', 'MattiaValsecchi', 'fgblue', 'Parando', 'mariog_1989', 'H7283QQluigic', 'Jessica R', 'iamsimo_k', 'Maria Chiara M', 'Rum_55', 'FilippoL451', 'Gin70ros', 'Luigi G', 'djmarkino94', 'Ev_vu3', 'IlRecensoreditalia', 'Marconeri92', 'Elepe', 'carlapau', 'Paolettasciacca', 'marcomU6482OW', 'sonounmeli', 'flycosimo', '501giorgiom', 'ciuffex', 'clopols', 'MarcoWolf', 'Alberto T', '262luciag', 'Olindione', 'chiara_assi', 'S3702EPdenisem', 'siccio', 'Davide Omar B', 'Alkazam', '826Piero59', 'aiscakepassion', 'teresaa604', 'raninviaggio', '987martav', 'fralazza', 'fabiorestelli90', 'martisorce', 'Mirtilla M', 'Gio5507', 'Ettore63Napoli', 'donatellifaio', 'Fili1703', 'R4525DMantonioc', 'trapdem', 'bansheewicked', 'Kalos1', 'elmagicokgb', 'donatelladigregorio', 'IlDirittoalBello', 'Giorgia A', 'valeriad427', 'X256PVmarcof', 'Jupiter1980', 'marcomU6482OW', 'MonicaC_MB', 'nunzioc910', 'claudiop223', 'Veronica L', 'Francesca B', 'N6718RNgabrielec', '449benedettap', '977vincenzol', 'Kabbo84', 'GaboTata', 'Matilde C', 'Trioev', 'rapanellocondito', 'Paolo P', 'A951SBandreat', 'ivanmA9392EB', 'Carmelo S', 'SottoMettimi', 'Z6090PEmarcom', 'Fablunder', 'Thaumasios', 'DaniloM2824', 'Armando2959', 'Zuleika M', 'noecld', 'Tonymarchino', 'deca32', 'smenny87', 'Ilariaanna', 'roberto b', 'H3445RWpaolod', 'francescom677', 'mirkov247', 'vincenzog133', 'criscanf', 'grezaccari', 'Tecla M', 'marcomU6482OW', '5carlom', 'C5192YJalessiab', 'ludelica', 'Francesco966', 'Gennaro D', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Umberto A', 'agilulf0', 'Pasquale N', 'liab82', 'R6060MRriccardop', 'Silvia Maria T', 'PetraN70', 'Massi104', 'mary670658', 'Sara R', 'alessandrorB5065LE', 'fratecarlo', 'Gianlucap242', 'Tobia06', 'Graziella L', 'Eduardo Z', 'tartarugagenio', 'Alberto T', 'GIURO81', 'Professorepercaso', 'vin-bar2000', 'guidos591', 'F16_onair', 'Filippo L', 'CCodecasa', 'GuBi-1', 'chiaralazzari91', 'AleNardi1994', 'Ciu65', 'paOlettat986', 'micbO6684ZH', 'Roberta V', 'Barros9', 'Arcapazzi', 'saverioa639', 'Eus82', 'lorisca1950', 'consigli s', 'DanyFurby', 'YuriDeMichelis', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Fabi0Al', 'rachelegori', 'andreabigi', 'Massimo V', 'Giovanni N', 'Vitty-Salvo', 'Alice M', 'Buiaa84', 'Carlosimoncini2017', 'BARBARA_MN73', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Michelavigani78', 'Orazio65rossonero', 'Alfonso S', '493gianmarcos', 'Borish', 'Elia R', 'lucaibram', 'ramelow', 'Vanessa E', 'saraz1993', 'stebalzi', 'G711_12', 'TuristaPerSempre81', '150mirellam', 'angel0nec', 'Giorgio M', 'armata89', 'secchiamantovana', 'anto_giordy', 'nicoespo73', 'Federico D', 'Stirandstrain7', 'Vittorio_Beretta', 'FeX91', 'G7206WOrobertof', 'francord80', 'davidelU9904DJ', 'Mizio I', 'Adriana M', 'vicsoft1', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Saberio70', 'danielsav', 'Michele V', 'ninom943', 'giuliafE5470UT', 'ggg303', 'micetta182', 'Francesco B', '400giuseppec', 'Martino_Dalmasso54', 'Fabio C', 'pepinedda23', 'OlivieroNessi', 'Rosary68', 'Mariozo1954', 'Lulus505', 'VDC2960', 'Federica S', 'James196682', 'Hirundo71', 'matteos116', '445lauraz', 'contegiacomo', 'Papillegustative1966', 'lippi87', 'Vincenzo M', 'francescamarra10', 'Perseo74', 'PieroC1231', 'Freedom148747', 'marudino', ...
#
# ['Pellarob', 'Francesco', 'maram', 'giorgio', 'Elia', 'xlaf', 'BCRfedericap', 'ISABELLA', 'Lorenzo', 'rolling', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'giampaolol', 'alessandral', 'pataepisi', 'patriziaelli', 'tommasot', 'cesare', 'sfumaturedimamma', 'Elele', 'las', 'Natalia', 'npettinato', 'robertoegraziab', 'feuse', 'patrizia', 'amagnama', 'bubitimeflies', 'claudio', 'lauratWQN', 'MattiaValsecchi', 'fgblue', 'Parando', 'mariog', 'HQQluigic', 'Jessica', 'iamsimok', 'Maria', 'Rum', 'FilippoL', 'Ginros', 'Luigi', 'djmarkino', 'Evvu', 'IlRecensoreditalia', 'Marconeri', 'Elepe', 'carlapau', 'Paolettasciacca', 'marcomUOW', 'sonounmeli', 'flycosimo', 'giorgiom', 'ciuffex', 'clopols', 'MarcoWolf', 'Alberto', 'luciag', 'Olindione', 'chiaraassi', 'SEPdenisem', 'siccio', 'Davide', 'Alkazam', 'Piero', 'aiscakepassion', 'teresaa', 'raninviaggio', 'martav', 'fralazza', 'fabiorestelli', 'martisorce', 'Mirtilla', 'Gio', 'EttoreNapoli', 'donatellifaio', 'Fili', 'RDMantonioc', 'trapdem', 'bansheewicked', 'Kalos', 'elmagicokgb', 'donatelladigregorio', 'IlDirittoalBello', 'Giorgia', 'valeriad', 'XPVmarcof', 'Jupiter', 'marcomUOW', 'MonicaCMB', 'nunzioc', 'claudiop', 'Veronica', 'Francesca', 'NRNgabrielec', 'benedettap', 'vincenzol', 'Kabbo', 'GaboTata', 'Matilde', 'Trioev', 'rapanellocondito', 'Paolo', 'ASBandreat', 'ivanmAEB', 'Carmelo', 'SottoMettimi', 'ZPEmarcom', 'Fablunder', 'Thaumasios', 'DaniloM', 'Armando', 'Zuleika', 'noecld', 'Tonymarchino', 'deca', 'smenny', 'Ilariaanna', 'roberto', 'HRWpaolod', 'francescom', 'mirkov', 'vincenzog', 'criscanf', 'grezaccari', 'Tecla', 'marcomUOW', 'carlom', 'CYJalessiab', 'ludelica', 'Francesco', 'Gennaro', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Umberto', 'agilulf', 'Pasquale', 'liab', 'RMRriccardop', 'Silvia', 'PetraN', 'Massi', 'mary', 'Sara', 'alessandrorBLE', 'fratecarlo', 'Gianlucap', 'Tobia', 'Graziella', 'Eduardo', 'tartarugagenio', 'Alberto', 'GIURO', 'Professorepercaso', 'vinbar', 'guidos', 'Fonair', 'Filippo', 'CCodecasa', 'GuBi', 'chiaralazzari', 'AleNardi', 'Ciu', 'paOlettat', 'micbOZH', 'Roberta', 'Barros', 'Arcapazzi', 'saverioa', 'Eus', 'lorisca', 'consigli', 'DanyFurby', 'YuriDeMichelis', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'FabiAl', 'rachelegori', 'andreabigi', 'Massimo', 'Giovanni', 'VittySalvo', 'Alice', 'Buiaa', 'Carlosimoncini', 'BARBARAMN', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Michelavigani', 'Oraziorossonero', 'Alfonso', 'gianmarcos', 'Borish', 'Elia', 'lucaibram', 'ramelow', 'Vanessa', 'saraz', 'stebalzi', 'G', 'TuristaPerSempre', 'mirellam', 'angelnec', 'Giorgio', 'armata', 'secchiamantovana', 'antogiordy', 'nicoespo', 'Federico', 'Stirandstrain', 'VittorioBeretta', 'FeX', 'GWOrobertof', 'francord', 'davidelUDJ', 'Mizio', 'Adriana', 'vicsoft', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Saberio', 'danielsav', 'Michele', 'ninom', 'giuliafEUT', 'ggg', 'micetta', 'Francesco', 'giuseppec', 'MartinoDalmasso', 'Fabio', 'pepinedda', 'OlivieroNessi', 'Rosary', 'Mariozo', 'Lulus', 'VDC', 'Federica', 'James', 'Hirundo', 'matteos', 'lauraz', 'contegiacomo', 'Papillegustative', 'lippi', 'Vincenzo', 'francescamarra', 'Perseo', 'PieroC', 'Freedom', 'marudino', 'Elio', 'sange', 'LauraM', 'silviagQCR', 'Eugenio', 'Alberto', 'PesceTropicale', 'fabri', 'tommaso', 'MARTA', 'Francesca', 'Vladimirto', 'KNMmariag', 'bagnino', 'Michele', 'irenel', 'Debcla', 'enzob', 'danilomistralquase', 'eleonoriana', 'gaetanof', 'alessiatrips', 'andrea', 'Marco', 'Gio', 'gipsyontheroad', 'enricoq', 'forchettallamano', 'FraKikka', 'cesarem', 'stefanoa', 'Tonino', 'bagoden', 'g', 'sara', 'Marco', 'intrepido', 'marco', 'Albymi', 'Massimo', 'NalinaMatiBiba', 'thegini', 'Alessandro', 'Luca', 'Federica', 'candalabissa' ...

# %% [markdown]
# #### Utilizzo gender_guesser
# Infine, posso utilizzare la libreria gender_guesser.
#
# NB: Genderize ti permette di analizzare 1000 nomi al giorno.

# %%
# !pip install gender_guesser
# Out:
# Requirement already satisfied: gender_guesser in /usr/local/lib/python3.6/dist-packages (0.4.0)

# %%
import gender_guesser.detector as gender
d = gender.Detector()

names_with_gender = []

for name in all_names_filtered:
    temp_gender = d.get_gender(name)
    names_with_gender.append(temp_gender)
  
print(names_with_gender)
# Out:
# ['unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'female', 'female', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unkn ...

# %%
all_genders = []
i = 0

for guess in names_with_gender:
    if guess == 'male' or guess == 'mostly_male':
        all_genders.append('M')
    elif guess == 'female' or guess == 'mostly_female':
        all_genders.append('F')
    else:
        all_genders.append('UNKNOWN')

    
print(all_genders)
# Out:
# ['UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UN ...

# %% [markdown]
# ---
# ## Salviamo ora i dati ottenuti in una tabella Excel
# Così non dovremo ogni volta rieseguire tutto il codice

# %% [markdown]
# ### Controlliamo che ci siano lo stesso numero di dati
# Potremo così creare una tabella sfruttando Pandas

# %%
print('Nomi: ', len(all_names_filtered))
print('Commenti: ', len(all_reviews_filtered))
print('Voti: ', len(all_ratings))
print('Mobile: ', len(all_mobile))
# Out:
# Nomi:  3656
# Commenti:  3656
# Voti:  3656
# Mobile:  3656

# %% [markdown]
# ### Eliminiamo le recensioni troppo lunghe e quelle di cui non sappiamo il genere del commentatore
# Creo una lista di liste [ ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ... ]

# %%
complete_list = []

i = len(all_names_filtered)

for indice in range(i):
  if all_genders[indice] != 'UNKNOWN' and all_reviews_filtered[indice] != 'RECENSIONE_TROPPO_LUNGA':
    temp = [all_names_filtered[indice], all_genders[indice], all_reviews_filtered[indice], all_ratings[indice], all_mobile[indice]]
    complete_list.append(temp)
    
print('DATI ANALIZZABILI: ', len(complete_list))
display(complete_list[:5])
# Out:
# DATI ANALIZZABILI:  350
# [['Lorenzo',
#   'M',
#   "Fino a ieri sera, quando sono stato con un amico carissimo, ne ignoravo l'esistenza.\nUn po' nascosto, in una traversa di via Torino, è stata una piacevole scoperta.\nOttima qualità del cibo.",
#   '5',
#   'PC'],
#  ['Natalia',
#   'F',
#   'Sono andata con i miei genitori in occasione del mio compleanno, è sempre una garanzia, piatti eccezionali, servizio impeccabile, accostamenti top, dolci supremi, il meglio direi.',
#   '5',
#   'PC'],
#  ['Maria',
#   'F',
#   'Ho pranzato in questo ristorante dalla location elegante. Tutti i piatti serviti sono stati ottimi e anche il servizio molto soddisfacente e gentile.',
#   '4',
#   'Mobile'],
#  ['Fili',
#   'F',
#   '...ci ritorno sempre volentieri in questo locale, cibo di qualità, personale cortese e disponibile, locale raffinato ed accogliente che ti avvolge col suo calore... sentirsi a casa anche quando sei lontano...',
#   '5',
#   'PC'],
#  ['Giorgia',
#   'F',
#   'Consiglio questo ristorante per un pranzo fra colleghi.\nServizio veloce e piatti invidiabili.\nÈ consigliabile prenotare.',
#   '3',
#   'Mobile']]

# %% [markdown]
# ### Creiamo la tabella

# %%
# !pip install pandas
# !pip install xlsxwriter
import pandas as pd

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame({'Nomi': [elemento[0] for elemento in complete_list], 
                   'Genere': [elemento[1] for elemento in complete_list], 
                   'Recensioni': [elemento[2] for elemento in complete_list],
                   'Voti': [elemento[3] for elemento in complete_list],
                   'Scritta da': [elemento[4] for elemento in complete_list]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RISTORANTE_5.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
partial_dataframe = pd.read_excel("RISTORANTE_5.xlsx")

display(partial_dataframe)
# Out:
#     Genere         Nomi                                         Recensioni  \
# 0        M      Lorenzo  Fino a ieri sera, quando sono stato con un ami...
# 1        F      Natalia  Sono andata con i miei genitori in occasione d...
# 2        F        Maria  Ho pranzato in questo ristorante dalla locatio...
# 3        F         Fili  ...ci ritorno sempre volentieri in questo loca...
# 4        F      Giorgia  Consiglio questo ristorante per un pranzo fra ...
# 5        F     Veronica  Il ristorante si trova in centro a Milano, vic...
# 6        F      Matilde  Mi sono recata in questo locale a pranzo. Pres...
# 7        M        Paolo  Piatti curati e ben preparati in un ristorante...
# 8        M      Gennaro  Personalmente il locale mi piace molto e devo ...
# 9        F         Sara  Ottimo cena di pesce in un ristorante con “car...
# 10       F    Graziella  Non capisco le recensioni non positive ... io ...
# 11       M      Filippo  Sono stato qui con mio fratello durante la pau...
# 12       M     Giovanni  Siamo stati da Nerino 10 a pranzo, 4 adulti e ...
# 13       M      Alfonso  Non si può chiedere di più a questo ristorante...
# 14       F         Elia  Tutto eccezionale e personale molto disponibil...
# 15       F      Michele  Ottimo ristorante, di quelli turistici, situat...
# 16       M        Fabio  Luogo caratteristico milanese apprezzato dai m...
# 17       F     Federica  Qualità, convivialità e servizio veloce sono l...
# 18       M        James  Ogni volta che mi capita di tornar a Milano pr...
# 19       M     Vincenzo  Qualità, competenza e cortesia. Prezzo coerent...
# 20       M         Elio  Io e mia figlia abbiamo trovato questa trattor...
# 21       M      Eugenio  Ristorante stupefacente. Alterna l'eleganza de...
# 22       F    Francesca  Cena con un amico, ci hanno fatto accomodare s...
# 23       M       Tonino  Che dire...\nVado spesso è uno dei migliori ri...
# 24       M      Massimo  Sicuramente uno dei ristoranti più famosi di M...
# 25       M         Luca  Senza parole\n10 e LODE\nÈ la terza volta che ...
# 26       F     Federica  Locale molto carino, prezzo giusto e in linea ...
# 27       M   Alessandro  Ottimo ristorante situato in una bellissima zo...
# 28       M     Antonino  Siamo stati recentemente in questo bel ristora...
# 29       M    Francesco  Il migliore in assoluto a Milano capisco bene ...
# ..     ...          ...                                                ...
# 320      F         Ruth  Avevamo bisogno di un posto per la cena e non ...
# 321      F     Marijana  Questo posto mi ha stupito! Ottimo personale d...
# 322      F       Denise  Amici altamente consigliato Nerino Diece (10) ...
# 323      M  Christopher  Ho avuto la spinaci saltati con aglio e burro,...
# 324      F      Arielle  Abbiamo trovato questo ristorante su Trip Advi...
# 325      M         John  Questo ristorante si trova su una strada later...
# 326      M       Sandro  Abbiamo trovato questo ristorante con un consu...
# 327      M    Sebastien  Si tratta di un buon ristorante italiano con i...
# 328      F     Adrianna  Personale molto gentile e un'atmosfera molto p...
# 329      M         Hank  Abbiamo avuto un buon esempio del cibo offrono...
# 330      F       Ramona  È un posto molto trafficata, quindi si ha vera...
# 331      M         John  Eravamo 4 adulti a Milano per un lungo weekend...
# 332      M         Tony  Siamo stati in Italia per una settimana e ques...
# 333      M       Norman  Questo posto era quello che mi piace: ingredie...
# 334      F      Nicolle  Abbiamo visitato Milano per il 60° compleanno ...
# 335      M     Heinrich  È stato un viaggio di un weekend a Milano e ho...
# 336      F         Rani  Io e mia madre abbiamo visitato questo posto p...
# 337      M    Jefferson  Ho usato TripAdvisor per scegliere questo rist...
# 338      M         Mark  Mia moglie e ho visitato questo ristorante sul...
# 339      M        Danny  Mi sono imbattuto in questo ristorante il gior...
# 340      M       Andrew  Abbiamo deciso sullo sperone del momento di an...
# 341      M          Bob  Assolutamente perfetto, tutto. Ho mangiato fuo...
# 342      F         Sara  Questo è stato il primo ristorante che abbiamo...
# 343      M         Luke  Molti ristoranti nella Cupola sono sopravviver...
# 344      M          Leo  Abbiamo trovato questo ristorante attraverso T...
# 345      F         Tina  Il cibo è ottimo con un menù vario e ottimo ra...
# 346      M          Sam  Questo è stato il miglior pasto che abbiamo fa...
# 347      M         John  Quando siete a Milano, questo posto è un must....
# 348      M         Joey  Nascosto in una stradina senza pretese di Mila...
# 349      F        Irene  Io e i miei amici siamo stati benissimo in que...
#
#     Scritta da  Voti
# 0           PC     5
# 1           PC     5
# 2       Mobile     4
# 3           PC     5
# 4       Mobile     3
# 5           PC     5
# 6           PC     4
# 7           PC     5
# 8       Mobile     4
# 9       Mobile     5
# 10      Mobile     5
# 11      Mobile     5
# 12      Mobile     4
# 13      Mobile     5
# 14      Mobile     5
# 15      Mobile     4
# 16      Mobile     4
# 17          PC     5
# 18      Mobile     5
# 19      Mobile     5
# 20          PC     4
# 21          PC     5
# 22      Mobile     4
# 23      Mobile     5
# 24      Mobile     5
# 25      Mobile     5
# 26      Mobile     5
# 27      Mobile     5
# 28      Mobile     4
# 29      Mobile     5
# ..         ...   ...
# 320     Mobile     5
# 321         PC     5
# 322         PC     5
# 323         PC     5
# 324         PC     5
# 325         PC     5
# 326     Mobile     5
# 327         PC     5
# 328         PC     5
# 329         PC     4
# 330         PC     5
# 331         PC     5
# 332         PC     5
# 333         PC     5
# 334         PC     5
# 335         PC     4
# 336         PC     4
# 337         PC     5
# 338         PC     5
# 339         PC     5
# 340         PC     5
# 341         PC     5
# 342         PC     5
# 343         PC     5
# 344         PC     5
# 345         PC     5
# 346         PC     5
# 347         PC     5
# 348         PC     5
# 349         PC     5
#
# [350 rows x 5 columns]
