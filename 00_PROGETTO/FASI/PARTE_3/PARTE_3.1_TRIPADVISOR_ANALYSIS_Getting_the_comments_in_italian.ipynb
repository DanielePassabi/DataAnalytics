# %% [markdown]
# # Creo un nuovo dataset

# %% [markdown]
# ---
# ## Analisi dei commenti di un ristorante
#
# ### Pucceria Quattroquarti - Basilicata
#
# URL di riferimento: https://www.tripadvisor.it/Restaurant_Review-g187772-d8473707-Reviews-Quattroquarti_Crostaemollica-Matera_Province_of_Matera_Basilicata.html
#
# Home --> Ristoranti --> Firenze --> Best_ranking--> SENZ_ALTRO_Bistrot

# %%
# IMPORT NECESSARI
import requests
from bs4 import BeautifulSoup

print("Imported")
# Out:
# Imported

# %%
page_URL = "https://www.tripadvisor.it/Restaurant_Review-g187772-d8473707-Reviews-Quattroquarti_Crostaemollica-Matera_Province_of_Matera_Basilicata.html"

data = requests.get(page_URL)
clear_data = BeautifulSoup(data.content, "lxml")

print("Done")
# Out:
# Done

# %% [markdown]
# ---
# ### STRUTTURA HTML DEL SITO
#
# #### REVIEW
# `<p class="partial_entry"> qui c'è la review </p>`
#
# #### N° TOTALE DI REVIEWS
# `<a data-page-number="25" ...>
#     25
#  </a>`
#
# #### NAMES
# `<span class="expand_inline scrname" …>AlexandraCapeTown</span>`
#
# #### RATINGS
# `<span class="ui_bubble_rating bubble_30"></span>`

# %% [markdown]
# ---
# ### PRIMO SCRAPING (sulla prima pagina)
#
# Ottengo i nomi, i commenti, le review e da dove è stato scritto il commento per quanto rigurda la prima pagina. Ciò è necessario, in quanto, dalla seconda in poi l'URL cambia, permettendoci di iterare.

# %%
# OTTENGO UNA LISTA DI DIV CHE CONTENGONO NOME, RECENSIONE E VOTO

all_reviews = []
all_names = []
all_ratings = []
all_mobile = []

review_container = clear_data.findAll("div", attrs={"class":"review-container"})

for container in review_container:
  
    ### REVIEW ###
    review = container.find('p', attrs={'class': 'partial_entry'})
    if review:
        all_reviews.append(review.text)
        
    ### NAME ###
    name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
    if name:
      all_names.append(name.text)
    else:
      all_names.append('NO_NAME')
    
    ### RATING ###
    rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
    all_ratings.append(rating['class'][1][7:8])
    
    ### MOBILE ###
    mobile = container.find('span', attrs={'class': 'viaMobile'})
    if mobile:
      all_mobile.append('Mobile')
    else:
      all_mobile.append('PC')
    
    
################################################################################################################################
        
print("Executed")
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# Nomi:  10
# Commenti:  10
# Voti:  10
# Scritto da:  10

# %% [markdown]
# ### SECONDO SCRAPING (dalla seconda pagina in poi)
#
# Notiamo dall'URL che è possibile iterare sulle pagine, ottenendo i dati!

# %%
URL_COMPLETO = 'https://www.tripadvisor.it/Restaurant_Review-g187772-d8473707-Reviews-or10-Quattroquarti_Crostaemollica-Matera_Province_of_Matera_Basilicata.html'

URL_p1 = 'https://www.tripadvisor.it/Restaurant_Review-g187772-d8473707-Reviews-or'
URL_p2 = '0-Quattroquarti_Crostaemollica-Matera_Province_of_Matera_Basilicata.html'
    
# OTTENGO I COMMENTI, NOMI E VOTI DALLA SECONDA PAGINA IN POI

total_pages = int(clear_data.select("a.pageNum.last.taLnk")[0].text) # 25 come intero

# per iterare dobbiamo partire dalla seconda pagina dei commenti, così nell'URL compaiono le cifre che ci servono
for r in range(1,total_pages):

    # OTTENGO L'URL DELLA PAGINA
    URL_temp = URL_p1 + str(r) + URL_p2

    # OTTENGO I DATI E CI APPLICO BEATIFULSOUP
    data = requests.get(URL_temp)
    clear_data = BeautifulSoup(data.content, "lxml")
    

    review_container = clear_data.findAll("div", attrs={"class":"review-container"})

    for container in review_container:
  
      ### REVIEW ###
      review = container.find('p', attrs={'class': 'partial_entry'})
      if review:
          all_reviews.append(review.text)

      ### NAME ###
      name = container.find('span', attrs={'class': ('expand_inline', 'scrname')})
      if name:
        all_names.append(name.text)
      else:
        all_names.append('NO_NAME')

      ### RATING ###
      rating = container.find('span', attrs={'class': 'ui_bubble_rating'})
      all_ratings.append(rating['class'][1][7:8])

      ### MOBILE ###
      mobile = container.find('span', attrs={'class': 'viaMobile'})
      if mobile:
        all_mobile.append('Mobile')
      else:
        all_mobile.append('PC')
    
        
################################################################################################################################
        
print("Executed")
print('total_pages: ', total_pages)
print('Nomi: ', len(all_names))
print('Commenti: ', len(all_reviews))
print('Voti: ', len(all_ratings))
print('Scritto da: ', len(all_ratings))
# Out:
# Executed
# total_pages:  113
# Nomi:  1128
# Commenti:  1128
# Voti:  1128
# Scritto da:  1128

# %%
# display(all_reviews)

# %%
# print(all_names)

# %%
#print(all_ratings, '\n')
#print(len(all_ratings))

# %%
#display(all_mobile)

# %% [markdown]
# #### Problema recensioni troppo lunghe
# Alla fine di alcune recensioni troviamo un '...Più', che non possiamo espandere. Data la mole di dati, decidiamo dunque di non considerarle.

# %%
all_reviews_filtered = []
counter_reviews_scartate = 0;
counter_reviews_da_usare = 0;

for review in all_reviews:
    if '...Più' in review:
        all_reviews_filtered.append('RECENSIONE_TROPPO_LUNGA')
        counter_reviews_scartate+=1;
    else:
        all_reviews_filtered.append(review)
        counter_reviews_da_usare+=1;
        
        
print(
    'Totale recensioni:', counter_reviews_scartate + counter_reviews_da_usare, '\n',
    'Recensioni analizzabili:', counter_reviews_da_usare, '\n',
    'Recensioni scartate:', counter_reviews_scartate, '\n')

display(all_reviews_filtered[:10])
# Out:
# Totale recensioni: 1128
#  Recensioni analizzabili: 733
#  Recensioni scartate: 395
# ['Infinita la scelta degli ingredienti da combinare nelle pucce. Purtroppo ne abbiamo assaggiate solo tre ed erano ottime, ottimo anche il rapporto qualità prezzo; molto simpatico il proprietario.',
#  "Entriamo a fatica in un locale con superficie disponibile minima, ma l'attesa e la difficoltà di trovare posto vengono ripagate da pucce buonissime, fatte con cura davanti a noi, con ingredienti di ottimo livello. Cordiale e infaticabile il proprietario. Gradevole pausa veloce per il pranzo.",
#  'Locale piccolo, la puccia però è uno spettacolo per il palato e la birra artigianale di Matera buonissima😍',
#  'Una certezza a Matera. Locale piccolo, ma accogliente, personale caloroso. I prodotti sono locali e freschi, è possibile sostituire gli ingredienti delle pucce presenti nel menù.',
#  'Locale piccolo ma molto accogliente prodotti freschi e buoni il proprietario gran bella persona consigliatissimo',
#  'Quasi per caso mi sono ritrovata a mangiare in questa pucceria, e che puccia! C’è una infinita scelta di pucce per tutti i gusti e il proprietario è adorabile!\nLa consiglio assolutamente.',
#  'RECENSIONE_TROPPO_LUNGA',
#  'Ho provato 2/4 della puccia "Cavaliere" e 2/4 di quella "Cattedrale". Tutto molto buono: prodotti di qualità, saporiti ed abbinati con fantasia ed originalità. Prezzi modici e personale cortese.',
#  'Ottima Pucceria con tantissimi gusti, ingredienti di qualità che risaltano i sapori lucani. Locale piccolo ma per un pranzo o cena veloci vale veramente la pena. Proprietario gentile e simpatico.  Complimenti davvero di cuore!',
#  'Abbiamo cenato in questa pucceria....c’è davvero l’imbarazzo della scelta, le pucce  che abbiamo assaggiato erano davvero buone e il proprietario è molto cordiale e simpatico. Da provare sicuramente se si viene a Matera!']

# %% [markdown]
# ---
# ### Analisi dei nomi
# Cerchiamo di capire se chi ha commentato è un uomo (M) o una donna (F).

# %% [markdown]
# #### Elimino spazi e numeri
# Ho bisogno di tenere solo le informazioni riguardanti il nome, elimino il resto.

# %%
import re

all_names_filtered = []

regex = re.compile('[^a-zA-Z]')

for name in all_names:
    
    if ' ' in name:                           # se c'è uno spazio nel nome
        space = name.index(' ')               # ne trovo l'indice
        name = regex.sub('', name[:space])    # effettuo un controllo su tutto ciò che non è alfabeto fino a quell'indice
        all_names_filtered.append(name)       # e aggiungo la stringa
        
    else:
        name = regex.sub('', name)            # in caso contrario effettuo un controllo su tutto ciò che non è alfabeto
        all_names_filtered.append(name)       # e aggiungo la stringa
        
print(all_names, '\n')
print(all_names_filtered)
# Out:
# ['NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'giorgiblu1976', 'lucabT4099LR', '60lucrezian', 'H510HCfabiop', 'geofilia', 'Pietro L', 'giuly r', 'kris1611', 'micheleamoroso90', 'svurpazz', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'shishisonson r', 'N4501DCchristiana', '58antonellas', 'Mariketta2014', 'Pasqualespada89', 'sabinol926', '232valeriag', 'Lulyna87', 'materano2019', 'Curiosity586849', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'marcodZ2844PI', 'giorgiaf697', 'alessiacC3884IZ', 'beatricebN3464BM', 'calceenzaa', 'Mobile826109', 'V7854EQantoniom', 'VanessaD3308', 'nazza60', 'gennarodifalco', 'annaaM4160YL', 'Clairings', 'Quintino S', 'dorixo', 'vitangelamoscarda', '14ClaudiaAlejandra', 'FABIO S', 'Rosa597', 'Motosega22', 'Dani B', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', '328mariannad', 'carla c', 'fedeinf123', 'Gionfra69', 'carola e', 'Emanuele L', 'marcomF3631OV', 'Damiano71', 'SimIsi7065', 'Giulia B', 'albins882017', 'Y3187XLserenap', 'ylecant', 'ele1961', '496martinav', '362eleonoras', 'Mirco B', 'Saturnina E', 'kiara243', 'manu_pi_2010', 'Salvatore P', 'D4tt4', 'fabion655', 'mamatr63', 'Fabio S', '282marinam', 'AldoMazzi', 'Rego2 M', 'Manuelcomazzi', 'Giacomo P', 'RobertoFr', '186francescag', '610StefanoB610', 'Elisabetta C', '749matteof', 'Filomena C', 'L8563WGdanielem', 'Budavari70', 'Michele M', 'matteobanti8', 'FelicityNapoli', 'Maria Chiara M', 'Francesco Koker... B', 'Barbara F', 'FilippoSkazza', '167vanessau', 'StefanoGatti', 'attilio123', '178matteop', 'LucillaClla', 'MassimoDal', 'Nicla Palmira M', 'Lucia C', 'GiuliaGiuliaC', 'R7132AXriccardor', 'Marco G', 'vincenzo b', 'claire288', 'alei6', 'miriamb801', 'Giadina17', 'Luca T', 'Alessandro C', 'eustachiol2013', '307Roberto', 'pierluigitropian2018', '512matteol', 'ThePassengerIta', 'AlexV2311', 'dario1967', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'francescamS4869OL', 'Luigi T', 'Serenella89bio', '563christianp', 'Mipograssi', 'giggioC7', 'Alessandra M', 'Serena V', 'Ponty80', 'reggiofood93', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'antonio F', 'maunaa3', '24MGB18', 'Siena A', '253myriamp', 'Rosanna N', 'Elisabetta V', 'Michela C', 'lucafree', 'saelu2015', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'NO_NAME', 'Lucasacms', 'martymise', 'Ivano A', 'I3231HDsilviag', 'eustachiol2013', 'Alfafabio', 'ClaudioGiu', 'RaffaeleF494', 'rinof955', 'materano2019', 'Ellebi94', 'tonym720', 'gwilly57', 'Elisabetta R', 'Luca2288', 'strega88', '331matteop', 'marcopA8942QJ', 'Robyyyy83', 'gioemadda1990', 'Ferraro76', 'Gennaro F', 'Ferdinando L', 'JesAle', 'andreapQ5792GA', 'JOENAPLES82', 'GinaFastidia', 'valeriac9595', 'Alessandra87a', 'Francesca C', 'Anto_dap', 'mariagraziac51', 'Raffaele D', 'Marianna M', 'giannid501', 'Pierluigi Ggk R', 'silvia333', 'Marianna R', 'gioluca78', 'giovannidB4845XF', 'Fefax', 'babalaus', 'Maria Stella U', 'MaxPapnik', 'TellinaD', 'Fidelioxx', 'jodo21', 'Federica M', 'TiggyTime', 'Guido M', 'Giovanni84rc', '338vinci', 'VagabondaSa', '_75100tonino', '158yleniam', 'Fausto P', 'manuelt235', 'Lucia G', 'adelanto_tripadv', 'giero', 'Victor B', 'Giuseppe Paolo D', 'katiad987', 'gabriele b', 'ilariaemarco85', 'Katia R', 'Domenico0', 'DiPassaggioNoveZero', 'francescamP601BQ', 'glaucopos88', 'Akiscia', 'Marta A', 'Filippo P', 'Chiaronzola16', 'ScottexA', 'ste67maz', 'Annalisa G', 'doubleci', 'Tongiu T', 'Sergio D', 'nadpsetraveler', 'MassiMassi p', '545assuntap', '974giuseppep', 'adelina s',  ...
#
# ['NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'giorgiblu', 'lucabTLR', 'lucrezian', 'HHCfabiop', 'geofilia', 'Pietro', 'giuly', 'kris', 'micheleamoroso', 'svurpazz', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'shishisonson', 'NDCchristiana', 'antonellas', 'Mariketta', 'Pasqualespada', 'sabinol', 'valeriag', 'Lulyna', 'materano', 'Curiosity', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'marcodZPI', 'giorgiaf', 'alessiacCIZ', 'beatricebNBM', 'calceenzaa', 'Mobile', 'VEQantoniom', 'VanessaD', 'nazza', 'gennarodifalco', 'annaaMYL', 'Clairings', 'Quintino', 'dorixo', 'vitangelamoscarda', 'ClaudiaAlejandra', 'FABIO', 'Rosa', 'Motosega', 'Dani', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'mariannad', 'carla', 'fedeinf', 'Gionfra', 'carola', 'Emanuele', 'marcomFOV', 'Damiano', 'SimIsi', 'Giulia', 'albins', 'YXLserenap', 'ylecant', 'ele', 'martinav', 'eleonoras', 'Mirco', 'Saturnina', 'kiara', 'manupi', 'Salvatore', 'Dtt', 'fabion', 'mamatr', 'Fabio', 'marinam', 'AldoMazzi', 'Rego', 'Manuelcomazzi', 'Giacomo', 'RobertoFr', 'francescag', 'StefanoB', 'Elisabetta', 'matteof', 'Filomena', 'LWGdanielem', 'Budavari', 'Michele', 'matteobanti', 'FelicityNapoli', 'Maria', 'Francesco', 'Barbara', 'FilippoSkazza', 'vanessau', 'StefanoGatti', 'attilio', 'matteop', 'LucillaClla', 'MassimoDal', 'Nicla', 'Lucia', 'GiuliaGiuliaC', 'RAXriccardor', 'Marco', 'vincenzo', 'claire', 'alei', 'miriamb', 'Giadina', 'Luca', 'Alessandro', 'eustachiol', 'Roberto', 'pierluigitropian', 'matteol', 'ThePassengerIta', 'AlexV', 'dario', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'francescamSOL', 'Luigi', 'Serenellabio', 'christianp', 'Mipograssi', 'giggioC', 'Alessandra', 'Serena', 'Ponty', 'reggiofood', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'antonio', 'maunaa', 'MGB', 'Siena', 'myriamp', 'Rosanna', 'Elisabetta', 'Michela', 'lucafree', 'saelu', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Lucasacms', 'martymise', 'Ivano', 'IHDsilviag', 'eustachiol', 'Alfafabio', 'ClaudioGiu', 'RaffaeleF', 'rinof', 'materano', 'Ellebi', 'tonym', 'gwilly', 'Elisabetta', 'Luca', 'strega', 'matteop', 'marcopAQJ', 'Robyyyy', 'gioemadda', 'Ferraro', 'Gennaro', 'Ferdinando', 'JesAle', 'andreapQGA', 'JOENAPLES', 'GinaFastidia', 'valeriac', 'Alessandraa', 'Francesca', 'Antodap', 'mariagraziac', 'Raffaele', 'Marianna', 'giannid', 'Pierluigi', 'silvia', 'Marianna', 'gioluca', 'giovannidBXF', 'Fefax', 'babalaus', 'Maria', 'MaxPapnik', 'TellinaD', 'Fidelioxx', 'jodo', 'Federica', 'TiggyTime', 'Guido', 'Giovannirc', 'vinci', 'VagabondaSa', 'tonino', 'yleniam', 'Fausto', 'manuelt', 'Lucia', 'adelantotripadv', 'giero', 'Victor', 'Giuseppe', 'katiad', 'gabriele', 'ilariaemarco', 'Katia', 'Domenico', 'DiPassaggioNoveZero', 'francescamPBQ', 'glaucopos', 'Akiscia', 'Marta', 'Filippo', 'Chiaronzola', 'ScottexA', 'stemaz', 'Annalisa', 'doubleci', 'Tongiu', 'Sergio', 'nadpsetraveler', 'MassiMassi', 'assuntap', 'giuseppep', 'adelina', 'salvatoreNapoli', 'MaryDTrip', 'EsigenteCatania', 'sangyy', 'IYSriccardod', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'NONAME', 'Ferdicarmen', 'BetelgeuseBeetlej', 'cionim', 'ACPlucam', 'Ignoffo', 'claudiapxx', 'baffibianchi', 'Igor', 'ferdinandop', 'emiliop', 'Mimmijoe', 'magnamagnabloggers', 'Sandracr', 'GiulioTheDoc', 'carla', 'vittorios', 'SunnyDay', 'Roberto', 'vals', 'Silvia', 'angsun', 'cristinagKKO', 'DOMENICA', 'ICBG', 'Luxxx', 'emiliosiracuso', 'MatteoR', 'Jonnytiel', 'DaniloD', 'Sultansalmon', 'TIDfabriziob', 'Occhio', 'LauraB',  ...

# %% [markdown]
# #### Utilizzo gender_guesser
# Infine, posso utilizzare la libreria gender_guesser.
#
# NB: Genderize ti permette di analizzare 1000 nomi al giorno.

# %%
# !pip install gender_guesser
# Out:
# Requirement already satisfied: gender_guesser in /usr/local/lib/python3.6/dist-packages (0.4.0)

# %%
import gender_guesser.detector as gender
d = gender.Detector()

names_with_gender = []

for name in all_names_filtered:
    temp_gender = d.get_gender(name)
    names_with_gender.append(temp_gender)
  
print(names_with_gender)
# Out:
# ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'female', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'female', 'male', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'female', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'female', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'female', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown',  ...

# %%
all_genders = []
i = 0

for guess in names_with_gender:
    if guess == 'male' or guess == 'mostly_male':
        all_genders.append('M')
    elif guess == 'female' or guess == 'mostly_female':
        all_genders.append('F')
    else:
        all_genders.append('UNKNOWN')

    
print(all_genders)
# Out:
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'F', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'F', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'M', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'F', 'UNKNOWN', 'F', 'UNKNOWN', 'M', 'UNKNOWN', 'M', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UN ...

# %% [markdown]
# ---
# ## Salviamo ora i dati ottenuti in una tabella Excel
# Così non dovremo ogni volta rieseguire tutto il codice

# %% [markdown]
# ### Controlliamo che ci siano lo stesso numero di dati
# Potremo così creare una tabella sfruttando Pandas

# %%
print('Nomi: ', len(all_names_filtered))
print('Commenti: ', len(all_reviews_filtered))
print('Voti: ', len(all_ratings))
print('Mobile: ', len(all_mobile))
# Out:
# Nomi:  1128
# Commenti:  1128
# Voti:  1128
# Mobile:  1128

# %% [markdown]
# ### Eliminiamo le recensioni troppo lunghe e quelle di cui non sappiamo il genere del commentatore
# Creo una lista di liste [ ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ['NOME', 'GENERE', 'RECENSIONE', 'VOTO'], ... ]

# %%
complete_list = []

i = len(all_names_filtered)

for indice in range(i):
  if all_genders[indice] != 'UNKNOWN' and all_reviews_filtered[indice] != 'RECENSIONE_TROPPO_LUNGA':
    temp = [all_names_filtered[indice], all_genders[indice], all_reviews_filtered[indice], all_ratings[indice], all_mobile[indice]]
    complete_list.append(temp)
    
print('DATI ANALIZZABILI: ', len(complete_list))
display(complete_list[:5])
# Out:
# DATI ANALIZZABILI:  181
# [['Pietro',
#   'M',
#   'Cibi gustosissimi, una delle poche piadinerie di un livello alto. Merita 5 stelle e più. Consigliatissimo. Pulizia impeccabile, proprietario gentile e cortese.',
#   '5',
#   'Mobile'],
#  ['Quintino',
#   'M',
#   "L'Antico Vinaio sta a Firenze come Quattroquarti sta a Matera. Il simpatico e cordiale titolare di questo piccolo locale sa comporre con amore pucce sostanziose e squisite. Gli ingredienti sono di ottima qualità e la scelta è molto ampia. Consigliato.",
#   '5',
#   'Mobile'],
#  ['Dani',
#   'M',
#   "Siamo rimasti estasiati dalle pucce scelte, molto di più di un panino, con gran passione e disponibilità del titolare L' abbiamo preferito al solito ristorante 2 pucce pezzente e 4 quarti 2 coche, un bicchiere di aglianico 18 euro",
#   '5',
#   'Mobile'],
#  ['Emanuele',
#   'M',
#   'A due passi dalla piazza principale di Matera. Il locale offre tantissimi tipi di puccia, oltre alla possibilità di crearle con ingredienti a scelta. Gentilissimo il proprietario.',
#   '5',
#   'PC'],
#  ['Giulia',
#   'F',
#   'Trovato su tripadvisor e davvero da provare! Moltissime farciture tra cui scegliere..sicuramente possono accontentare tutti! Dopo una puccia sei soddisfatto e pronto a ripartire per i Sassi!\nBuonissimo!',
#   '5',
#   'Mobile']]

# %% [markdown]
# ### Creiamo la tabella

# %%
# !pip install pandas
# !pip install xlsxwriter
import pandas as pd

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame({'Nomi': [elemento[0] for elemento in complete_list], 
                   'Genere': [elemento[1] for elemento in complete_list], 
                   'Recensioni': [elemento[2] for elemento in complete_list],
                   'Voti': [elemento[3] for elemento in complete_list],
                   'Scritta da': [elemento[4] for elemento in complete_list]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('RISTORANTE_1.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
partial_dataframe = pd.read_excel("RISTORANTE_1.xlsx")

display(partial_dataframe)
# Out:
#     Genere        Nomi                                         Recensioni  \
# 0        M      Pietro  Cibi gustosissimi, una delle poche piadinerie ...
# 1        M    Quintino  L'Antico Vinaio sta a Firenze come Quattroquar...
# 2        M        Dani  Siamo rimasti estasiati dalle pucce scelte, mo...
# 3        M    Emanuele  A due passi dalla piazza principale di Matera....
# 4        F      Giulia  Trovato su tripadvisor e davvero da provare! M...
# 5        M       Mirco  Un artista dei sapori ....puccie per tutti i g...
# 6        M   Salvatore  Fantastico posto, peccato le dimensioni. Ottim...
# 7        M       Fabio  Da non mancare la sosta alla pucceria quattro ...
# 8        F  Elisabetta  Locale su una via laterale con ampia scelta di...
# 9        M   Francesco  Posto caratteristico, personale divertente , e...
# 10       F       Nicla  La Puccia è fotonica ed il proprietario simpat...
# 11       M  Alessandro  Consigliato dal ns b&b abbiamo pranzato in que...
# 12       M     Roberto  Pranzo veloce prima del tour a Matera.\nPucce ...
# 13       M       Luigi  + Ottima qualità buono anche come viene servit...
# 14       F  Alessandra  Tappa obbligata nel centro di Matera. Ottima p...
# 15       F     Rosanna  La Puccia ha una combinazione di sapori eccezi...
# 16       F  Elisabetta  Siamo venuti qui su consiglio di tripadvisor e...
# 17       F     Michela  Sarebbe un peccato andare a Matera e non assag...
# 18       F  Elisabetta  Partiamo da Roma, destinazione Matera.....trov...
# 19       M        Luca  Puccia di altissima qualità. Grande varietà di...
# 20       M     Gennaro  Un indispensabile, se passate da queste parti ...
# 21       M  Ferdinando  Ebbene si, lo devo ammettere, la mia tentazion...
# 22       M    Raffaele  Locale molto carino, personale gentilissimo ch...
# 23       F    Marianna  Puccia ottima così come gli ingredienti utiliz...
# 24       M   Pierluigi  Molta scelta x i vari gusti dei clienti, il pe...
# 25       F    Marianna  Da provare e da ritornare sicuramente!\nNoi ab...
# 26       F       Maria  trovato grazie alle recensioni. che dire ....f...
# 27       F    Federica  Piccolo locale con un ampio menù di pucce per ...
# 28       M       Guido  Qualità gastronomica con ampia varietà e servi...
# 29       M      Fausto  Avevo letto recensioni positive su questa pucc...
# ..     ...         ...                                                ...
# 151      F       Paola  è stata un piacevolissima sosta! il locale è p...
# 152      M        Luca  Una sola parola "OTTIMO" cortesia e qualità de...
# 153      M       Fabio  Eravamo in cerca di un posto aperto, buono e a...
# 154      M    Emanuele  Molto bello, pulito, ottimo, si impegnano a ri...
# 155      F      Aurora  È buonissimo , fa delle piadine ottime!\nServi...
# 156      M     Antonio  Eravamo in cinque amici e sbirciando tra le va...
# 157      M   Francesco  Ambiente piccolino ma particolarissimo,siamo s...
# 158      M       Mimmo  Locale piccolo, ma originale nel suo arredamen...
# 159      F      Giulia  Siamo capitati per caso nella via tornando dai...
# 160      M    Giuseppe  Mi sono fidato delle ottime recensioni e non s...
# 161      M    Pasquale  Ottimo per chi va di fretta e vuole comunque m...
# 162      F    Loredana  Si entra in un piccolo locale e presto si rima...
# 163      M     Massimo  Puccia soffice e molto gustoso, devo dire anch...
# 164      F      Angela  Siamo stati accolti con cordialità, abbiamo ma...
# 165      M     Roberto  Ottimo Street food, con tutti i sapori lucani....
# 166      M  Christophe  Abbiamo trovato questo posto per caso. Abbiamo...
# 167      M   Francesco  Il titolare gentilissimo, ha molto gusto nel c...
# 168      F      Teresa  Se volete mangiare la Puccia più buona di Mate...
# 169      F        Dori  Abbiamo gustato due Puccie veramente uniche, l...
# 170      M      Cosimo  Ottime pucce con prodotti locali e genuini. Ra...
# 171      M         Jan  Ci siamo stati per la strada e si è preso take...
# 172      M      Flaviu  Il cibo era molto buono, posizione stupenda e ...
# 173      M   Vencislav  Piccolo negozio di sandwich con uno dei miglio...
# 174      M   Christian  Il mio panino era okay, anche se penso che il ...
# 175      M        Alex  Ottimo servizio, ottimo cibo! Il proprietario ...
# 176      M    Robrecht  Concetto semplice di Veey ma cibo molto ottimi...
# 177      F       Jenny  E' stata una giornata fredda e tempestosa a Ma...
# 178      M       Nenad  Ingredienti freschi, ricette perfette e ancora...
# 179      F     Claudia  Abbiamo aspettato quasi 40 minuti per mangiare...
# 180      M     Prakash  Ho eated un paio di tempo a Quattroquarti,ingr...
#
#     Scritta da  Voti
# 0       Mobile     5
# 1       Mobile     5
# 2       Mobile     5
# 3           PC     5
# 4       Mobile     5
# 5       Mobile     5
# 6           PC     5
# 7       Mobile     5
# 8       Mobile     5
# 9       Mobile     5
# 10      Mobile     5
# 11      Mobile     5
# 12      Mobile     5
# 13      Mobile     4
# 14      Mobile     5
# 15      Mobile     5
# 16      Mobile     5
# 17      Mobile     5
# 18      Mobile     5
# 19      Mobile     5
# 20      Mobile     5
# 21      Mobile     5
# 22      Mobile     5
# 23          PC     5
# 24      Mobile     5
# 25      Mobile     5
# 26          PC     5
# 27      Mobile     5
# 28          PC     5
# 29      Mobile     5
# ..         ...   ...
# 151     Mobile     5
# 152     Mobile     5
# 153     Mobile     4
# 154     Mobile     5
# 155     Mobile     5
# 156         PC     4
# 157     Mobile     5
# 158     Mobile     5
# 159         PC     5
# 160     Mobile     5
# 161         PC     4
# 162         PC     5
# 163     Mobile     5
# 164         PC     5
# 165     Mobile     5
# 166     Mobile     5
# 167     Mobile     5
# 168     Mobile     5
# 169     Mobile     5
# 170     Mobile     5
# 171     Mobile     5
# 172     Mobile     5
# 173         PC     5
# 174     Mobile     3
# 175     Mobile     5
# 176     Mobile     5
# 177     Mobile     5
# 178     Mobile     5
# 179     Mobile     5
# 180         PC     5
#
# [181 rows x 5 columns]
